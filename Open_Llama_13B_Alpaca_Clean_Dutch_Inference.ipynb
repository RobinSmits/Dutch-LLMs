# %% [markdown]
# <a href="https://colab.research.google.com/github/RobinSmits/Dutch-LLMs/blob/main/Open_Llama_13B_Alpaca_Clean_Dutch_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
import os
from google.colab import drive
drive.mount('/content/drive')

# Set Google Drive Folder to use...Copy Val_Data folder from Github into it to be able to reproduce the results.
WORK_DIR = '/content/drive/My Drive/LLM/OpenLlama13BAlpacaCleanDutchQlora/'
os.makedirs(WORK_DIR, exist_ok = True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Install modules
# !pip install -q accelerate
# !pip install -q sentencepiece
# !pip install -q bitsandbytes
# !pip install -q transformers
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q datasets
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
# Import Modules
from datasets import load_dataset, load_from_disk
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#  and submit this information together with your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# bin /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching in backup paths...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 8.0
# CUDA SETUP: Detected CUDA version 118
# CUDA SETUP: Loading binary /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so...
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: /usr/lib64-nvidia did not contain ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] as expected! Searching further paths...
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.28.0.1'), PosixPath('http'), PosixPath('8013')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/gpu-a100-s-3lggtfzohczoz --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true'), PosixPath('--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/env/python')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//ipykernel.pylab.backend_inline'), PosixPath('module')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: Found duplicate ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] files: {PosixPath('/usr/local/cuda/lib64/libcudart.so'), PosixPath('/usr/local/cuda/lib64/libcudart.so.11.0')}.. We'll flip a coin and try one of these, in order to fail forward.
# Either way, this might cause trouble in the future:
# If you get `CUDA error: invalid device function` errors, the above might be the cause and the solution is to make sure only one ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] in the paths that we search based on your env.
#   warn(msg)

# %%
# Set Model Name Constant
model_name = "robinsmits/open_llama_13b_alpaca_clean_dutch_qlora"

# %%
# Create Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name,
                                          use_fast = False,
                                          add_eos_token = True)
tokenizer.pad_token_id = 0

# Max Length
MAX_LEN = 512

# Tokenizer Summary
print(tokenizer)

# Special Tokens
print('pad_token_id: ', tokenizer.pad_token_id)
print('bos_token_id: ', tokenizer.bos_token_id)
print('eos_token_id: ', tokenizer.eos_token_id)
print('pad_token: ', tokenizer.decode(tokenizer.pad_token_id))
print('bos_token: ', tokenizer.decode(tokenizer.bos_token_id))
print('eos_token: ', tokenizer.decode(tokenizer.eos_token_id))
# Out:
# LlamaTokenizer(name_or_path='robinsmits/open_llama_13b_alpaca_clean_dutch_qlora', vocab_size=32000, model_max_length=2048, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'bos_token': AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'eos_token': AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'unk_token': AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'pad_token': '<unk>'}, clean_up_tokenization_spaces=False)
# pad_token_id:  0
# bos_token_id:  1
# eos_token_id:  2
# pad_token:  <unk>
# bos_token:  <s>
# eos_token:  </s>

# %%
# Create PEFT Config
config = PeftConfig.from_pretrained(model_name)

# Create Model
model = AutoModelForCausalLM.from_pretrained(config.base_model_name_or_path,
                                             load_in_8bit = True,
                                             device_map = "auto")
model = PeftModel.from_pretrained(model, model_name)

# Summary
print(model)
# Out:
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(32000, 5120, padding_idx=0)
#         (layers): ModuleList(
#           (0-39): 40 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): Linear8bitLt(
#                 in_features=5120, out_features=5120, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=5120, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): Linear8bitLt(in_features=5120, out_features=5120, bias=False)
#               (v_proj): Linear8bitLt(
#                 in_features=5120, out_features=5120, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=5120, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): Linear8bitLt(in_features=5120, out_features=5120, bias=False)
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear8bitLt(in_features=5120, out_features=13824, bias=False)
#               (down_proj): Linear8bitLt(in_features=13824, out_features=5120, bias=False)
#               (up_proj): Linear8bitLt(in_features=5120, out_features=13824, bias=False)
#               (act_fn): SiLUActivation()
#             )
#             (input_layernorm): LlamaRMSNorm()
#             (post_attention_layernorm): LlamaRMSNorm()
#           )
#         )
#         (norm): LlamaRMSNorm()
#       )
#       (lm_head): Linear(in_features=5120, out_features=32000, bias=False)
#     )
#   )
# )

# %% [markdown]
# I'am using the same validation set as during training of the notebook.
#
# This allows for some further analysis in this Inference notebook without data leakage.
#
# The required train and validation files are stored in my github account. Notice that the original code to generate the train and validation dataset is in the commented out section.

# %%
"""
# Alpaca Translated
datasets = load_dataset('BramVanroy/alpaca-cleaned-dutch')

# Summary
print(datasets)

# Validation size
VAL_SIZE = 2048

# Split in Train and Val datasets
dataset_split = datasets["train"].train_test_split(test_size = VAL_SIZE,
                                                   shuffle = True,
                                                   seed = 42)

# Train and Val datasets
train_data = dataset_split["train"]
val_data = dataset_split["test"]

# Save for later use
val_data.save_to_disk(f'{WORK_DIR}val_data')
train_data.save_to_disk(f'{WORK_DIR}train_data')
"""

# Load Validation set from earlier training run...use code above to generate new train and val datasets if required
val_data = load_from_disk(f'{WORK_DIR}val_data')

# %%
def generate_eval_prompt(item):
    if item["input"]:
        return f"""
### Instructie:
{item["instruction"]}

### Invoer:
{item["input"]}

### Antwoord:"""
    else:
        return f"""
### Instructie:
{item["instruction"]}

### Antwoord:"""

# %%
def generate(instruction, input = None):
    # Generate Prompt
    prompt = generate_eval_prompt({'instruction': instruction, 'input': input})

    # Tokenize
    input_ids = tokenizer(prompt, return_tensors = "pt", truncation = True).input_ids.cuda()

    # Generate output
    outputs = model.generate(input_ids = input_ids,
                             max_new_tokens = MAX_LEN,
                             num_beams = 4,
                             early_stopping = True,
                             forced_eos_token_id = tokenizer.eos_token_id)

    # Decode output
    generated_output = tokenizer.decode(outputs[0], skip_special_tokens = True)

    # Print prompt and answer extracted from generated output
    print(prompt)
    if prompt in generated_output:
        answer = generated_output.split(prompt)[1]
        print(answer)
    else:
      print('<< NO ANSWER GENERATED >>')

# Validation Loop
counter = 0
for item in val_data:
    print(f'\n\n=== Voorbeeld: {counter} ======================================================================================')
    generate(item['instruction'], item['input'])

    counter += 1
    if counter > 50:
        break
# Out:
# === Voorbeeld: 0 ======================================================================================
#
# ### Instructie:
# Wat zijn de drie belangrijkste softwareonderdelen die worden gebruikt bij webontwikkeling?
#
# ### Antwoord:
#  Optional
# 1. HTML
# 2. CSS
# 3. JavaScript
#
#
# === Voorbeeld: 1 ======================================================================================
#
# ### Instructie:
# Genereer een wachtwoord dat aan de volgende eisen voldoet: minimaal 8 tekens, één hoofdletter, één kleine letter, één cijfer en één speciaal teken.
#
# ### Antwoord:
# ...
#
#
# === Voorbeeld: 2 ======================================================================================
#
# ### Instructie:
# Stel vijf activiteiten voor om zelfzorg te bevorderen
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# 1. Maak een dagelijkse routine en houd je eraan.
# 2. Neem regelmatig pauzes tijdens de dag.
# 3. Maak voldoende slaapkwaliteitstijden.
# 4. Beweeg regelmatig.
# 5. Eet gezonde maaltijden.
#
#
# === Voorbeeld: 3 ======================================================================================
#
# ### Instructie:
# Ontdek of een zin sarcastisch is.
#
# ### Invoer:
# Dat is geweldig nieuws.
#
# ### Antwoord:
# ...
#
#
# === Voorbeeld: 4 ======================================================================================
#
# ### Instructie:
# Gegeven een kort stukje tekst, verwijder alle bijwoorden en vervang ze door meer passende woorden.
#
# ### Invoer:
# Hij rende snel naar de winkel om wat eten te kopen.
#
# ### Antwoord:
#  Optional
# Hij rende naar de winkel om wat eten te kopen.
#
#
# === Voorbeeld: 5 ======================================================================================
#
# ### Instructie:
# Geef twee voorbeelden van activiteiten die fysieke kracht vereisen.
#
# ### Antwoord:
# //////////////////////////////////////////////
# 1. Sporten
# 2. Voetbal spelen
#
#
# === Voorbeeld: 6 ======================================================================================
#
# ### Instructie:
# Vind de vergelijking van de lijn die door het gegeven punt gaat en parallel is aan de gegeven vector.
#
# ### Invoer:
# Punt: (2, 1), Vector: (−2, 1)
#
# ### Antwoord:
# ...
#
#
# === Voorbeeld: 7 ======================================================================================
#
# ### Instructie:
# Gegeven een zin en een lijst met bijwoorden, pas de zin aan met behulp van de bijwoorden.
#
# ### Invoer:
# Hij liep langzaam
# Bijwoorden: met tegenzin, aarzelend
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Hij liep langzaam, aarzelend.
#
#
# === Voorbeeld: 8 ======================================================================================
#
# ### Instructie:
# Identificeer alle componenten van een gegeven wetenschappelijke term.
#
# ### Invoer:
# Fotosynthese
#
# ### Antwoord:
# //////////////////////////////////////////////
# Fotosynthese is het proces waarbij planten lichtenergie van de zon omzetten in chemische energie, die vervolgens wordt gebruikt om water en koolstofdioxide om te zetten in glucose.
#
#
# === Voorbeeld: 9 ======================================================================================
#
# ### Instructie:
# Beschrijf de verschillen tussen een asynchrone en synchrone webapplicatie.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Een asynchrone webapplicatie is een webapplicatie die geen synchronisatie nodig heeft tussen de gebruiker en de server. Dit betekent dat de gebruiker zijn interacties met de webapplicatie kan uitvoeren zonder dat de server in staat is om de gebruiker te waarschuwen wanneer de gebruiker zijn interacties heeft voltooid.
#
# Een synchrone webapplicatie is een webapplicatie die synchronisatie nodig heeft tussen de gebruiker en de server. Dit betekent dat de gebruiker zijn interacties met de webapplicatie kan uitvoeren zonder dat de server in staat is om de gebruiker te waarschuwen wanneer de gebruiker zijn interacties heeft voltooid.
#
# Het belangrijkste verschil tussen een asynchrone en synchrone webapplicatie is dat een asynchrone webapplicatie geen synchronisatie nodig heeft tussen de gebruiker en de server, terwijl een synchrone webapplicatie synchronisatie nodig heeft.
#
#
# === Voorbeeld: 10 ======================================================================================
#
# ### Instructie:
# Classificeer deze zin als een gebiedende wijs of een vraag.
#
# ### Invoer:
# Deze salade smaakt heerlijk.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Deze salade smaakt heerlijk.
#
#
# === Voorbeeld: 11 ======================================================================================
#
# ### Instructie:
# Onderzoek en maak een lijst van de gezondheidsvoordelen van het eten van appels.
#
# ### Antwoord:
# //////////////////////////////////////////////
# 1. Appels zijn een geweldige bron van vitamine C.
# 2. Appels zijn een geweldige bron van vitamine A.
# 3. Appels zijn een geweldige bron van vitamine K.
# 4. Appels zijn een geweldige bron van foliumzuur.
# 5. Appels zijn een geweldige bron van kalium.
# 6. Appels zijn een geweldige bron van magnesium.
# 7. Appels zijn een geweldige bron van potassium.
# 8. Appels zijn een geweldige bron van antioxidanten.
# 9. Appels zijn een geweldige bron van fiber.
# 10. Appels zijn een geweldige bron van antioxidanten.
# 11. Appels zijn een geweldige bron van antioxidanten.
# 12. Appels zijn een geweldige bron van antioxidanten.
#
#
# === Voorbeeld: 12 ======================================================================================
#
# ### Instructie:
# Geef een voorbeeld van een technologie die probabilistisch denken gebruikt.
#
# ### Antwoord:
#  Optional:
# Optional:
# Optional:
# Optional:
# Optional:
# Optional:
# Optional:
# Optional:
# Optional:
# Optional:
# Optional:
#
#
# === Voorbeeld: 13 ======================================================================================
#
# ### Instructie:
# Wat zijn de drie kenmerken van een goed argument?
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////////////////////
# Een goed argument heeft drie belangrijke kenmerken:
#
# 1. Een goed argument moet logisch zijn. Dit betekent dat de argumenten die worden gebruikt in het proces van het maken van een goed argument logisch moeten zijn. Dit betekent dat de argumenten die worden gebruikt in het proces van het maken van een goed argument moeten zijn gebaseerd op feiten en bewijs.
#
# 2. Een goed argument moet duidelijk zijn. Dit betekent dat de argumenten die worden gebruikt in het proces van het maken van een goed argument duidelijk moeten zijn. Dit betekent dat de argumenten die worden gebruikt in het proces van het maken van een goed argument duidelijk moeten zijn voor iedereen om te begrijpen.
#
# 3. Een goed argument moet relevant zijn. Dit betekent dat de argumenten die worden gebruikt in het proces van het maken van een goed argument relevant moeten zijn voor het onderwerp. Dit betekent dat de argumenten die worden gebruikt in het proces van het maken van een goed argument relevant moeten zijn voor het onderwerp.
#
#
# === Voorbeeld: 14 ======================================================================================
#
# ### Instructie:
# De functie f heeft de eigenschap dat voor elke reëel getal x in zijn domein, 1/x ook in zijn domein is en f(x) + f(1/x) = x.
# Wat is de grootste verzameling van reële getallen die in het domein van f kan zijn?
#
# (a) {x| x0}
#
# (b) {x| x<0}
#
# (c) {x| x>0}
#
# (d) {x| x-1 en x0 en x1}
#
# (e) {-1,1}
#
# ### Antwoord:
# ...
#
#
# === Voorbeeld: 15 ======================================================================================
#
# ### Instructie:
# Combineer de 2 passages en creëer een nieuw verhaal
#
# ### Invoer:
# Passage 1: Sarah liep naar huis van school toen ze een hard getik in de buurt hoorde.
#
# Passage 2: Ze keek op om een hoge boom te zien met een grote vogel erop, die zijn vleugels in de wind sloeg.
#
# ### Antwoord:
#  Optional:
# Sarah liep naar huis van school toen ze een hard getik in de buurt hoorde. Ze keek op om een hoge boom te zien met een grote vogel erop, die zijn vleugels in de wind sloeg.
#
#
# === Voorbeeld: 16 ======================================================================================
#
# ### Instructie:
# Wat gebeurt er als we 100 ml water mengen met 30 ml azijn?
#
# ### Antwoord:
#  Optional:
# Het mengen van 100 ml water met 30 ml azijn resulteert in 130 ml azijn.
#
#
# === Voorbeeld: 17 ======================================================================================
#
# ### Instructie:
# Waar of niet waar, zelfrijdende auto's zijn haalbaar voor snelwegen.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Waar of niet waar, zelfrijdende auto's zijn haalbaar voor snelwegen.
#
#
# === Voorbeeld: 18 ======================================================================================
#
# ### Instructie:
# Identificeer het hoofdidee van de tekst.
#
# ### Invoer:
# Global warming is de term die wordt gebruikt om een geleidelijke toename van de gemiddelde temperatuur van de atmosfeer en oceanen van de aarde te beschrijven, een verandering die wordt geloofd permanent de klimaat van de aarde te veranderen.
#
# ### Antwoord:
# ...
#
#
# === Voorbeeld: 19 ======================================================================================
#
# ### Instructie:
# Noem drie elementen van cyberbeveiliging.
#
# ### Antwoord:
# //////////////////////////////////////////////
# 1. Firewalls
# 2. Antivirus software
# 3. Encryption
#
#
# === Voorbeeld: 20 ======================================================================================
#
# ### Instructie:
# Gegeven een lijst van wapens en een personage, genereer een verhaal met het personage dat een van de wapens uit de lijst gebruikt.
#
# ### Invoer:
# Personage: Larry
# Wapens: knots, zwaard, boog en pijl
#
# ### Antwoord:
# ...
#
#
# === Voorbeeld: 21 ======================================================================================
#
# ### Instructie:
# Maak een boekomslag voor een fictieve roman.
#
# ### Invoer:
# Genre: Fantasy
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////////////////////
#
# <img src="https://i.imgur.com/qJJJJJJ.jpg" width="100%" height="100%" alt="Boekomslag">
#
# Dit is een boekomslag voor een fictief boek genaamd "De Magie van de Sterren". Het boek is geschreven door een onbekende auteur en vertelt het verhaal van een jong meisje genaamd Elsa die haar magische krachten ontdekt terwijl ze op zoek is naar de oorzaak van haar mysterieuze vermoeidheid.
#
#
# === Voorbeeld: 22 ======================================================================================
#
# ### Instructie:
# Maak een voorbeeld van het soort vragen dat een GPT-model kan beantwoorden.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Wat is de hoofdstad van Frankrijk?
# Parijs
# Wat is de hoofdstad van Duitsland?
# Berlijn
# Wat is de hoofdstad van Spanje?
# Madrid
# Wat is de hoofdstad van Italië?
# Rome
# Wat is de hoofdstad van de Verenigde Staten?
# Washington D.C.
#
#
# === Voorbeeld: 23 ======================================================================================
#
# ### Instructie:
# Genereer een zin die een vergelijking demonstreert.
#
# ### Antwoord:
# ...
#
#
# === Voorbeeld: 24 ======================================================================================
#
# ### Instructie:
# Classificeer de gegeven zin als een metafoor of een vergelijking.
#
# ### Invoer:
# De kamer was een oven.
#
# ### Antwoord:
#  Optional
# De kamer was een oven.
#
#
# === Voorbeeld: 25 ======================================================================================
#
# ### Instructie:
# Herschrijf de zin "Hij rent" in de tegenwoordige progressieve tijd.
#
# ### Antwoord:
#  Optional
# Hij rent.
#
#
# === Voorbeeld: 26 ======================================================================================
#
# ### Instructie:
# Stel een nieuwe rebrandingstrategie voor aan het volgende bedrijf.
#
# ### Invoer:
# Bedrijf: ABC Technologies
#
# ### Antwoord:
# ...
#
#
# === Voorbeeld: 27 ======================================================================================
#
# ### Instructie:
# Identificeer het woordsoort voor het gegeven woord.
#
# ### Invoer:
# Lachen
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Het woord 'lachen' is een bijvoeglijk naamwoord.
#
#
# === Voorbeeld: 28 ======================================================================================
#
# ### Instructie:
# Hoe zou je kunstmatige intelligentie uitleggen aan een leerling in groep 6?
#
# ### Antwoord:
# clockwork orange
# The Clockwork Orange is a 1971 dystopian crime film adapted, produced, and directed by Stanley Kubrick, based on the 1962 novel of the same name by Anthony Burgess. It stars Malcolm McDowell, Patrick Magee, and Michael Bates, and tells the story of a man who undergoes a procedure to make himself into a kind of human guinea pig to test a new form of behaviour modification to cure him of his violent nature. The film is set in a near-future dystopian society that has a youth subculture of ultra-violent "droogs" who roam the streets at night getting into violent confrontations with other gang members, the police, and ordinary people before spending their nights in a discotheque, where they indulge in self-induced violence and rape.
#
# The film was controversial upon release, but has since gained a significant cult following and is often cited as one of the greatest films of all time.
#
# The Clockwork Orange is a 1971 dystopian crime film adapted, produced, and directed by Stanley Kubrick, based on the 1962 novel of the same name by Anthony Burgess. It stars Malcolm McDowell, Patrick Magee, and Michael Bates, and tells the story of a man who undergoes a procedure to make himself into a kind of human guinea pig to test a new form of behaviour modification to cure him of his violent nature. The film is set in a near-future dystopian society that has a youth subculture of ultra-violent "droogs" who roam the streets at night getting into violent confrontations with other gang members, the police, and ordinary people before spending their nights in a discotheque, where they indulge in self-induced violence and rape.
#
# The film was controversial upon release, but has since gained a significant cult following and is often cited as one of the greatest films of all time.
#
#
# === Voorbeeld: 29 ======================================================================================
#
# ### Instructie:
# Noem vijf aspecten van een data science proces
#
# ### Antwoord:
#  Optional
# 1. Data Collection
# 2. Data Cleaning
# 3. Data Preparation
# 4. Data Analysis
# 5. Data Visualization
#
#
# === Voorbeeld: 30 ======================================================================================
#
# ### Instructie:
# Vertaal het woord "person" van Engels naar Spaans.
#
# ### Antwoord:
# ...
#
#
# === Voorbeeld: 31 ======================================================================================
#
# ### Instructie:
# Categoriseer het gegeven object in een passende categorie.
#
# ### Invoer:
# Kaas
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////////////////////
# Kaas is een voedselproduct dat bestaat uit vet, eiwit en water. Het wordt verkocht in verschillende vormen, zoals boter, kaas, gebakken kaas, gefrituurd kaas, gebakken kaas, gebakken kaas, gebakken kaas, gebakken kaas, gebakken kaas, gebakken kaas, gebakken kaas, gebakken kaas, gebakken kaas, gebakken kaas, gebakken kaas, gebakken kaas, gebakken kaas, gebakken kaas en gebakken kaas.
#
#
# === Voorbeeld: 32 ======================================================================================
#
# ### Instructie:
# Converteer 179 centimeter naar voet.
#
# ### Invoer:
# 179 centimeter
#
# ### Antwoord:
#  Optional.
# 179 centimeter is gelijk aan 179 voet.
#
#
# === Voorbeeld: 33 ======================================================================================
#
# ### Instructie:
# Noem 4 methoden om cyberaanvallen te voorkomen.
#
# ### Antwoord:
# //////////////////////////////////////////////
# 1. Gebruik twee wachtwoorden om toegang te krijgen tot uw account.
# 2. Gebruik twee verschillende bronnen voor uw wachtwoorden.
# 3. Gebruik twee verschillende bronnen voor uw wachtwoorden.
# 4. Gebruik twee verschillende bronnen voor uw wachtwoorden.
# 5. Gebruik twee verschillende bronnen voor uw wachtwoorden.
#
#
# === Voorbeeld: 34 ======================================================================================
#
# ### Instructie:
# Reverse engineer de volgende algoritme en leg zijn functie uit in één zin.
#
# ### Invoer:
# def sorteer_getallen(arr):
#     for i in range(len(arr)):
#         for j in range(i):
#             if arr[i] < arr[j]:
#                 arr[i], arr[j] = arr[j], arr[i]
#     return arr
#
# ### Antwoord:
# << NO ANSWER GENERATED >>
#
#
# === Voorbeeld: 35 ======================================================================================
#
# ### Instructie:
# Bewerk deze code om de output "Hello, World!" te maken
#
# ### Invoer:
# console.log("Hi, World!");
#
# ### Antwoord:
# //////////////////////////////////////////////
# console.log("Hello, World!");
#
#
# === Voorbeeld: 36 ======================================================================================
#
# ### Instructie:
# Maak een zin in de derde persoonsperspectief.
#
# ### Antwoord:
# ...
#
#
# === Voorbeeld: 37 ======================================================================================
#
# ### Instructie:
# Doe een voorstel om de beschikbaarheid van wapens in de samenleving te verminderen.
#
# ### Antwoord:
#  Optional
#
# Ik denk dat het belangrijk is om de beschikbaarheid van wapens in de samenleving te verminderen. Er zijn verschillende manieren om dit te doen, zoals het verminderen van de hoeveelheid wapens die in handen zijn van het publiek, het verstrekken van educatieve programma's over het gebruik van wapens en het implementeren van belangrijke wapenwetten.
#
# Het verminderen van de hoeveelheid wapens die in handen zijn van het publiek kan worden bereikt door het verstrekken van educatieve programma's over het gebruik van wapens. Dit kan het verstrekken van informatie over het gebruik van wapens omvatten, zoals hoe ze moeten worden gebruikt en hoe ze moeten worden gecontroleerd. Het kan ook het verstrekken van educatieve programma's omvatten over de gevaren van wapens en hoe ze moeten worden gecontroleerd.
#
# Het verminderen van de hoeveelheid wapens die in handen zijn van het publiek kan ook worden bereikt door het verstrekken van belangrijke wapenwetten. Dit kan het verstrekken van informatie over wapens omvatten, zoals hoe ze moeten worden gebruikt en hoe ze moeten worden gecontroleerd. Het kan ook het verstrekken van belangrijke wapenwetten omvatten, zoals het verstrekken van informatie over de gevaren van wapens en hoe ze moeten worden gecontroleerd.
#
#
# === Voorbeeld: 38 ======================================================================================
#
# ### Instructie:
# Beoordeel de volgende producten op een schaal van 1-10 (1 = Niet goed, 10 = Zeer goed)
#
# ### Invoer:
# iPad Pro, Laptop, Desktop
#
# ### Antwoord:
#  Optional
# iPad Pro: 10/10
# Laptop: 9/10
# Desktop: 8/10
#
#
# === Voorbeeld: 39 ======================================================================================
#
# ### Instructie:
# Noem een beroemde astronaut.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Neil Armstrong, de eerste mens op de maan.
#
#
# === Voorbeeld: 40 ======================================================================================
#
# ### Instructie:
# Schrijf een e-mail naar de manager waarin je vraagt om een wijziging in de vergadertijd.
#
# ### Invoer:
# Er staat een vergadering gepland op dinsdag om 11 uur 's ochtends en twee teamleden kunnen hier niet bij zijn vanwege een conflict in hun werkuren.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Beste Manager,
#
# Ik schrijf u om mijn ontevredenheid uit te spreken over de vergadertijd die gepland is op dinsdag om 11 uur 's ochtends. Mijn teamleden kunnen hier niet bij zijn vanwege een conflict in hun werkuren.
#
# Ik ben ervan overtuigd dat de vergadertijd moet worden verplaatst naar een later tijdstip, zoals 13 uur 's ochtends of 15 uur 's ochtends.
#
# Ik ben ervan overtuigd dat de vergadertijd moet worden verplaatst om ervoor te zorgen dat iedereen bij de vergadering kan zijn.
#
# Bedankt voor uw tijd en overweging.
#
# Met vriendelijke groet,
# [Uw naam]
#
#
# === Voorbeeld: 41 ======================================================================================
#
# ### Instructie:
# Hoe voelt de protagonist zich tegen het einde van het boek?
#
# ### Invoer:
# Josh heeft moeite om betekenis te geven aan wat zijn leven is geworden. Hij heeft veel van zijn oude vrienden verloren en zijn toekomst is onzeker.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Josh had moeite om betekenis te geven aan wat zijn leven was geworden. Hij had veel van zijn oude vrienden verloren en zijn toekomst was onzeker.
#
#
# === Voorbeeld: 42 ======================================================================================
#
# ### Instructie:
# Gebruik de tegenwoordige tijd om de volgende instructies uit te leggen
#
# ### Invoer:
# Bouw een huis
#
# ### Antwoord:
#  Optional:
# Bouw een huis.
#
#
# === Voorbeeld: 43 ======================================================================================
#
# ### Instructie:
# Maak drie vragen die gerelateerd zijn aan de verspreiding van virussen.
#
# ### Antwoord:
# //////////////////////////////////////////////
# 1. Wat zijn de drie belangrijkste soorten virussen?
# 2. Wat zijn de drie belangrijkste soorten virussen?
# 3. Wat zijn de drie belangrijkste soorten virussen?
# 4. Wat zijn de drie belangrijkste soorten virussen?
# 5. Wat zijn de drie belangrijkste soorten virussen?
#
#
# === Voorbeeld: 44 ======================================================================================
#
# ### Instructie:
# Genereer een social media bericht over een nieuwe functie van jouw product.
# Maximaal 140 tekens
#
# ### Invoer:
# SMS notificaties voor klanten
#
# ### Antwoord:
#  Optional
#
# We hebben een nieuwe functie aangekondigd: SMS-notificaties voor klanten! Met deze nieuwe functie kunnen klanten een SMS-notificatie ontvangen wanneer hun bestelling is verzonden of wanneer hun bestelling is verzonden.
#
# Klanten kunnen deze functie aanmaken door hun e-mailadres in hun accountinformatie in te vullen.
#
# We zijn ervan overtuigd dat deze nieuwe functie klanten een gemakkelijkere en efficiëntere ervaring zal bieden.
#
#
# === Voorbeeld: 45 ======================================================================================
#
# ### Instructie:
# Maak een lijst van 3 veelvoorkomende interviewvragen.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# 1. Wat is jouw ervaring in deze functie?
# 2. Wat zijn jouw sterke punten?
# 3. Wat zijn jouw nadelen?
# 4. Wat zijn jouw doelen in deze functie?
# 5. Wat zijn de belangrijkste uitdagingen in deze functie?
# 6. Wat zijn jouw ideeën over hoe deze functie kan worden verbeterd?
# 7. Wat zijn jouw ideeën over hoe deze functie in de toekomst kan worden uitgebreid?
#
#
# === Voorbeeld: 46 ======================================================================================
#
# ### Instructie:
# Genereer een voorbeeld van een bedrijfsplan voor een restaurant.
#
# ### Invoer:
# Restaurantnaam: Bella's Bistro
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Bella's Bistro is een restaurant gevestigd in het centrum van de stad. Het restaurant biedt een verscheidenheid aan klassieke en moderne Amerikaanse gerechten, zoals burgers, salades en pasta's. Bella's Bistro biedt ook een selectie aan dranken, zoals frisdranken, glaswijnen en bier.
#
# Bella's Bistro staat bekend om zijn uitnodigende sfeer en vriendelijke medewerkers. Het restaurant biedt ook een uitgebreide lunch- en dinerbuffet.
#
# Bella's Bistro staat bekend om zijn uitnodigende sfeer en vriendelijke medewerkers. Het restaurant biedt ook een uitgebreide lunch- en dinerbuffet.
#
#
# === Voorbeeld: 47 ======================================================================================
#
# ### Instructie:
# Construeer een bewijs van de volgende stelling:
#
# ### Invoer:
# Stelling: De som van twee oneven getallen is even.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# De som van twee oneven getallen is even.
# De som van twee oneven getallen is even.
# De som van twee oneven getallen is even.
# De som van twee oneven getallen is even.
# De som van twee oneven getallen is even.
#
#
# === Voorbeeld: 48 ======================================================================================
#
# ### Instructie:
# Gebruik de gegeven feiten om een samenvatting van de Zon te genereren.
#
# ### Invoer:
# Het is een ster die zich bevindt in het centrum van ons zonnestelsel, hoofdzakelijk samengesteld uit waterstof en helium, heeft een diameter van 865.000 mijl en een oppervlaktetemperatuur van 10.000 graden Fahrenheit.
#
# ### Antwoord:
# ...
#
#
# === Voorbeeld: 49 ======================================================================================
#
# ### Instructie:
# Maak een overzicht voor een presentatie over de rol van sociale media in de moderne samenleving.
#
# ### Antwoord:
#  Optional
#
# ### Inleiding:
# Sociale media wordt steeds belangrijker in de moderne samenleving. Het wordt gebruikt voor verschillende doeleinden, waaronder communicatie, marketing en entertainment.
#
# ### Inleiding:
# Sociale media wordt steeds belangrijker in de moderne samenleving. Het wordt gebruikt voor verschillende doeleinden, waaronder communicatie, marketing en entertainment.
#
# ### Inleiding:
# Sociale media wordt steeds belangrijker in de moderne samenleving. Het wordt gebruikt voor verschillende doeleinden, waaronder communicatie, marketing en entertainment.
#
# ### Inleiding:
# Sociale media wordt steeds belangrijker in de moderne samenleving. Het wordt gebruikt voor verschillende doeleinden, waaronder communicatie, marketing en entertainment.
#
# ### Inleiding:
# Sociale media wordt steeds belangrijker in de moderne samenleving. Het wordt gebruikt voor verschillende doeleinden, waaronder communicatie, marketing en entertainment.
#
#
# === Voorbeeld: 50 ======================================================================================
#
# ### Instructie:
# Maak een haiku-gedicht met behulp van de gegeven woorden.
#
# ### Invoer:
# Wind, Wolken, Hemel
#
# ### Antwoord:
# ...
