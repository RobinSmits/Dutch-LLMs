# %% [markdown]
# <a href="https://colab.research.google.com/github/RobinSmits/Dutch-LLMs/blob/main/Open_Llama_13B_Alpaca_Clean_Dutch_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
import os
from google.colab import drive
drive.mount('/content/drive')

# Set Google Drive Folder to use...Copy Val_Data folder from Github into it to be able to reproduce the results.
WORK_DIR = '/content/drive/My Drive/LLM/OpenLlama13BAlpacaCleanDutchQlora/'
os.makedirs(WORK_DIR, exist_ok = True)
# Out:
# Mounted at /content/drive

# %%
# Install required packages
# !pip install -q accelerate
# !pip install -q sentencepiece
# !pip install -q bitsandbytes
# !pip install -q transformers
# !pip install -q peft
# !pip install -q datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 19.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 29.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 27.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 74.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.1/519.1 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.5 MB/s eta 0:00:00

# %%
# Import Modules
from datasets import load_dataset, load_from_disk
import torch
from peft import AutoPeftModelForCausalLM
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
# Set Model Name Constant
model_name = "robinsmits/open_llama_13b_alpaca_clean_dutch_qlora"

# %%
# Create Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name,
                                          use_fast = False,
                                          legacy = False,
                                          add_eos_token = True)
tokenizer.pad_token_id = 0

# Max Length
MAX_LEN = 512

# Tokenizer Summary
print(tokenizer)

# Special Tokens
print(f'pad_token_id: {tokenizer.pad_token_id}')
print(f'bos_token_id: {tokenizer.bos_token_id}')
print(f'eos_token_id: {tokenizer.eos_token_id}')
print(f'pad_token: {tokenizer.decode(tokenizer.pad_token_id)}')
print(f'bos_token: {tokenizer.decode(tokenizer.bos_token_id)}')
print(f'eos_token: {tokenizer.decode(tokenizer.eos_token_id)}')
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/699 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/534k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]
# LlamaTokenizer(name_or_path='robinsmits/open_llama_13b_alpaca_clean_dutch_qlora', vocab_size=32000, model_max_length=2048, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'bos_token': AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'eos_token': AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'unk_token': AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'pad_token': '<unk>'}, clean_up_tokenization_spaces=False)
# pad_token_id: 0
# bos_token_id: 1
# eos_token_id: 2
# pad_token: <unk>
# bos_token: <s>
# eos_token: </s>

# %%
# Create Model
model = AutoPeftModelForCausalLM.from_pretrained(model_name,
                                                 device_map = "auto",
                                                 load_in_4bit = True,
                                                 torch_dtype = torch.bfloat16)

# Summary
print(model)
# Out:
# Downloading (…)/adapter_config.json:   0%|          | 0.00/428 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/507 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/33.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00003.bin:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00003.bin:   0%|          | 0.00/9.90G [00:00<?, ?B/s]
# Downloading (…)l-00003-of-00003.bin:   0%|          | 0.00/6.18G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# Downloading adapter_model.bin:   0%|          | 0.00/26.3M [00:00<?, ?B/s]
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(32000, 5120, padding_idx=0)
#         (layers): ModuleList(
#           (0-39): 40 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): Linear4bit(
#                 in_features=5120, out_features=5120, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=5120, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): Linear4bit(in_features=5120, out_features=5120, bias=False)
#               (v_proj): Linear4bit(
#                 in_features=5120, out_features=5120, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=5120, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): Linear4bit(in_features=5120, out_features=5120, bias=False)
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=5120, out_features=13824, bias=False)
#               (up_proj): Linear4bit(in_features=5120, out_features=13824, bias=False)
#               (down_proj): Linear4bit(in_features=13824, out_features=5120, bias=False)
#               (act_fn): SiLUActivation()
#             )
#             (input_layernorm): LlamaRMSNorm()
#             (post_attention_layernorm): LlamaRMSNorm()
#           )
#         )
#         (norm): LlamaRMSNorm()
#       )
#       (lm_head): Linear(in_features=5120, out_features=32000, bias=False)
#     )
#   )
# )

# %% [markdown]
# I'am using the same validation set as during training of the notebook.
#
# This allows for some further analysis in this Inference notebook without data leakage.
#
# The required train and validation files are stored in my github account. Notice that the original code to generate the train and validation dataset is in the commented out section.

# %%
"""
# Alpaca Translated
datasets = load_dataset('BramVanroy/alpaca-cleaned-dutch')

# Summary
print(datasets)

# Validation size
VAL_SIZE = 2048

# Split in Train and Val datasets
dataset_split = datasets["train"].train_test_split(test_size = VAL_SIZE,
                                                   shuffle = True,
                                                   seed = 42)

# Train and Val datasets
train_data = dataset_split["train"]
val_data = dataset_split["test"]

# Save for later use
val_data.save_to_disk(f'{WORK_DIR}val_data')
train_data.save_to_disk(f'{WORK_DIR}train_data')
"""

# Load Validation set from earlier training run...use code above to generate new train and val datasets if required
val_data = load_from_disk(f'{WORK_DIR}val_data')

# %%
def generate_eval_prompt(item):
    if item["input"]:
        return f"""
### Instructie:
{item["instruction"]}

### Invoer:
{item["input"]}

### Antwoord:"""
    else:
        return f"""
### Instructie:
{item["instruction"]}

### Antwoord:"""

# %%
def generate(instruction, input = None):
    # Generate Prompt
    prompt = generate_eval_prompt({'instruction': instruction, 'input': input})

    # Tokenize
    input_ids = tokenizer(prompt, return_tensors = "pt", truncation = True).input_ids.cuda()

    # Generate output
    outputs = model.generate(input_ids = input_ids,
                             max_new_tokens = MAX_LEN,
                             num_beams = 4,
                             early_stopping = True,
                             forced_eos_token_id = tokenizer.eos_token_id)

    # Decode output
    generated_output = tokenizer.decode(outputs[0], skip_special_tokens = True)

    # Print prompt and answer extracted from generated output
    print(prompt)
    if prompt in generated_output:
        answer = generated_output.split(prompt)[1]
        print(answer)
    else:
        print('<< NO ANSWER GENERATED >>')

# Validation Loop
counter = 0
for item in val_data:
    print(f'\n\n=== Voorbeeld: {counter} ======================================================================================')
    generate(item['instruction'], item['input'])

    counter += 1
    if counter > 50:
        break
# Out:
# === Voorbeeld: 0 ======================================================================================
#
# ### Instructie:
# Wat zijn de drie belangrijkste softwareonderdelen die worden gebruikt bij webontwikkeling?
#
# ### Antwoord:
# //////////////////////////////////////////////
# De drie belangrijkste softwareonderdelen die worden gebruikt bij webontwikkeling zijn HTML (Hypertext Markup Language), CSS (Cascading Style Sheets) en JavaScript. HTML is een taal die wordt gebruikt om webpagina's te maken, CSS is een taal die wordt gebruikt om webpagina's te stylen, en JavaScript is een taal die wordt gebruikt om interactieve functies op webpagina's toe te voegen.
#
#
# === Voorbeeld: 1 ======================================================================================
#
# ### Instructie:
# Genereer een wachtwoord dat aan de volgende eisen voldoet: minimaal 8 tekens, één hoofdletter, één kleine letter, één cijfer en één speciaal teken.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
#
# ```
# import java.util.Scanner;
#
# public class Main {
#  public static void main(String[] args) {
#  Scanner scanner = new Scanner(System.in);
#  System.out.print("Enter a number: ");
#  int num = scanner.nextInt();
#  System.out.print("Enter another number: ");
#  int num2 = scanner.nextInt();
#  System.out.print("Enter another number: ");
#  int num3 = scanner.nextInt();
#  System.out.print("Enter another number: ");
#  int num4 = scanner.nextInt();
#  System.out.print("Enter another number: ");
#  int num5 = scanner.nextInt();
#  System.out.print("Enter another number: ");
#  int num6 = scanner.nextInt();
#  System.out.print("Enter another number: ");
#  int num7 = scanner.nextInt();
#  System.out.print("Enter another number: ");
#  int num8 = scanner.nextInt();
#  System.out.print("Enter another number: ");
#  int num9 = scanner.nextInt();
#  System.out.print("Enter another number: ");
#  int num10 = scanner.nextInt();
#  System.out.print("Enter another number: ");
#  int num11 = scanner.nextInt();
#  System.out.print("Enter another number: ");
#  int num12 = scanner.nextInt();
#  System.out.print("Enter another number: ");
#  int num13 = scanner.nextInt();
#  System.out.print("Enter another number: ");
#  int num14 = scanner.nextInt();
#  System.out.print("Enter another number: ");
#  int num15 = scanner.nextInt();
#  System.out.print("Enter another number: ");
#  int num16 = scanner.nextInt();
#  System.out.print("Enter another number: ");
#  int num
#
#
# === Voorbeeld: 2 ======================================================================================
#
# ### Instructie:
# Stel vijf activiteiten voor om zelfzorg te bevorderen
#
# ### Antwoord:
# //////////////////////////////////////////////
# 1. Maak een dagelijkse routine voor zelfzorg.
# 2. Neem regelmatig pauzes in je dagelijkse routine.
# 3. Maak gebruik van voldoende slaap.
# 4. Eet een uitgebalanceerd dieet.
# 5. Beweeg regelmatig.
#
#
# === Voorbeeld: 3 ======================================================================================
#
# ### Instructie:
# Ontdek of een zin sarcastisch is.
#
# ### Invoer:
# Dat is geweldig nieuws.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Deze zin is niet sarcastisch.
#
#
# === Voorbeeld: 4 ======================================================================================
#
# ### Instructie:
# Gegeven een kort stukje tekst, verwijder alle bijwoorden en vervang ze door meer passende woorden.
#
# ### Invoer:
# Hij rende snel naar de winkel om wat eten te kopen.
#
# ### Antwoord:
#  Optional
# Hij rende naar de winkel om wat eten te kopen.
#
#
# === Voorbeeld: 5 ======================================================================================
#
# ### Instructie:
# Geef twee voorbeelden van activiteiten die fysieke kracht vereisen.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# 1. Het verzamelen en analyseren van gegevens om trends en patronen te identificeren.
# 2. Het ontwikkelen en testen van nieuwe technologieën.
# 3. Het ontwikkelen en testen van nieuwe producten.
# 4. Het ontwikkelen en testen van nieuwe marketingstrategieën.
# 5. Het ontwikkelen en testen van nieuwe financiële strategieën.
# 6. Het ontwikkelen en testen van nieuwe organisatiestrategieën.
#
#
# === Voorbeeld: 6 ======================================================================================
#
# ### Instructie:
# Vind de vergelijking van de lijn die door het gegeven punt gaat en parallel is aan de gegeven vector.
#
# ### Invoer:
# Punt: (2, 1), Vector: (−2, 1)
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# x = np.array([1, 2, 3, 4, 5])
# y = np.array([1, 2, 3, 4, 5])
#
# plt.plot(x, y)
# plt.show()
# ```
#
#
# === Voorbeeld: 7 ======================================================================================
#
# ### Instructie:
# Gegeven een zin en een lijst met bijwoorden, pas de zin aan met behulp van de bijwoorden.
#
# ### Invoer:
# Hij liep langzaam
# Bijwoorden: met tegenzin, aarzelend
#
# ### Antwoord:
#  Optional
# Hij liep langzaam, aarzelend met tegenzin.
#
#
# === Voorbeeld: 8 ======================================================================================
#
# ### Instructie:
# Identificeer alle componenten van een gegeven wetenschappelijke term.
#
# ### Invoer:
# Fotosynthese
#
# ### Antwoord:
# //////////////////////////////////////////////
# Fotosynthese is het proces waarbij planten lichtenergie van de zon omzetten in chemische energie. Het omvat het proces waarbij planten lichtenergie van de zon omzetten in chemische energie door middel van fotosynthese.
#
#
# === Voorbeeld: 9 ======================================================================================
#
# ### Instructie:
# Beschrijf de verschillen tussen een asynchrone en synchrone webapplicatie.
#
# ### Antwoord:
#  instanceof Operator in Java
# The instanceof operator in Java is used to check whether an object is an instance of a particular class or interface. It returns true if the object is an instance of the specified class or interface, and false otherwise.
#
# The instanceof operator in Java is used to check whether an object is an instance of a particular class or interface. It returns true if the object is an instance of the specified class or interface, and false otherwise.
#
#
# === Voorbeeld: 10 ======================================================================================
#
# ### Instructie:
# Classificeer deze zin als een gebiedende wijs of een vraag.
#
# ### Invoer:
# Deze salade smaakt heerlijk.
#
# ### Antwoord:
# //////////////////////////////////////////////
# Deze salade smaakt heerlijk.
#
#
# === Voorbeeld: 11 ======================================================================================
#
# ### Instructie:
# Onderzoek en maak een lijst van de gezondheidsvoordelen van het eten van appels.
#
# ### Antwoord:
# //////////////////////////////////////////////
# 1. Appels zijn rijk aan vitamines en mineralen, waaronder vitamine C, vitamine A, vitamine K, vitamine B6, vitamine B1, vitamine B2, vitamine B3, magnesium, calcium en ijzer.
# 2. Appels zijn een geweldige bron van antioxidanten, die helpen om het risico op ziektes zoals hartziekten, beroerte en kanker te verminderen.
# 3. Appels kunnen helpen om het risico op bepaalde soorten kanker, zoals borstkanker, te verminderen.
# 4. Appels kunnen helpen om het risico op bepaalde soorten hartziekten, zoals hartfalen, te verminderen.
# 5. Appels kunnen helpen om het risico op bepaalde soorten beroerte te verminderen.
# 6. Appels kunnen helpen om het risico op bepaalde soorten diabetes te verminderen.
# 7. Appels kunnen helpen om het risico op bepaalde soorten obesitas te verminderen.
#
#
# === Voorbeeld: 12 ======================================================================================
#
# ### Instructie:
# Geef een voorbeeld van een technologie die probabilistisch denken gebruikt.
#
# ### Antwoord:
#  Optional:
# Een voorbeeld van een technologie die probabilistisch denken gebruikt, is machine learning. Machine learning is een type kunstmatige intelligentie (AI) die computers in staat stelt om te leren van ervaringen zonder expliciet geprogrammeerd te worden. Deze technologie maakt gebruik van probabilistische modellen om patronen in data te identificeren en voorspellingen te doen.
#
#
# === Voorbeeld: 13 ======================================================================================
#
# ### Instructie:
# Wat zijn de drie kenmerken van een goed argument?
#
# ### Antwoord:
#  instanceof Operator in Java
# The instanceof operator in Java is used to check whether an object is an instance of a particular class or interface. It returns true if the object is an instance of the specified class or interface and false otherwise.
#
# The instanceof operator in Java is used to check whether an object is an instance of a particular class or interface. It returns true if the object is an instance of the specified class or interface and false otherwise.
#
# The instanceof operator in Java is used to check whether an object is an instance of a particular class or interface. It returns true if the object is an instance of the specified class or interface and false otherwise.
#
#
# === Voorbeeld: 14 ======================================================================================
#
# ### Instructie:
# De functie f heeft de eigenschap dat voor elke reëel getal x in zijn domein, 1/x ook in zijn domein is en f(x) + f(1/x) = x.
# Wat is de grootste verzameling van reële getallen die in het domein van f kan zijn?
#
# (a) {x| x0}
#
# (b) {x| x<0}
#
# (c) {x| x>0}
#
# (d) {x| x-1 en x0 en x1}
#
# (e) {-1,1}
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# (a) {x| x0}
# (b) {x| x<0}
# (c) {x| x>0}
# (d) {x| x-1 en x0 en x1}
# (e) {-1,1}
#
#
# === Voorbeeld: 15 ======================================================================================
#
# ### Instructie:
# Combineer de 2 passages en creëer een nieuw verhaal
#
# ### Invoer:
# Passage 1: Sarah liep naar huis van school toen ze een hard getik in de buurt hoorde.
#
# Passage 2: Ze keek op om een hoge boom te zien met een grote vogel erop, die zijn vleugels in de wind sloeg.
#
# ### Antwoord:
#  Optional:
# Sarah liep naar huis van school toen ze een hard getik in de buurt hoorde. Ze keek op om een hoge boom te zien met een grote vogel erop, die zijn vleugels in de wind sloeg.
#
#
# === Voorbeeld: 16 ======================================================================================
#
# ### Instructie:
# Wat gebeurt er als we 100 ml water mengen met 30 ml azijn?
#
# ### Antwoord:
#
# Als we 100 ml water mengen met 30 ml azijn, krijgen we 130 ml azijn.
#
#
# === Voorbeeld: 17 ======================================================================================
#
# ### Instructie:
# Waar of niet waar, zelfrijdende auto's zijn haalbaar voor snelwegen.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Ja, zelfrijdende auto's zijn haalbaar voor snelwegen.
#
#
# === Voorbeeld: 18 ======================================================================================
#
# ### Instructie:
# Identificeer het hoofdidee van de tekst.
#
# ### Invoer:
# Global warming is de term die wordt gebruikt om een geleidelijke toename van de gemiddelde temperatuur van de atmosfeer en oceanen van de aarde te beschrijven, een verandering die wordt geloofd permanent de klimaat van de aarde te veranderen.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
#
# ### Invoer:
# Global warming is de term die wordt gebruikt om een geleidelijke toename van de gemiddelde temperatuur van de atmosfeer en oceanen van de aarde te beschrijven, een verandering die wordt geloofd permanent de klimaat van de aarde te veranderen.
#
# ### Antwoord:
# Global warming is de term die wordt gebruikt om een geleidelijke toename van de temperatuur van de atmosfeer en oceanen van de aarde te beschrijven, een verandering die wordt geloofd permanent de klimaat van de aarde te veranderen.
#
#
# === Voorbeeld: 19 ======================================================================================
#
# ### Instructie:
# Noem drie elementen van cyberbeveiliging.
#
# ### Antwoord:
# //////////////////////////////////////////////
# 1. Firewalls
# 2. Antivirus software
# 3. Encryption tools
#
#
# === Voorbeeld: 20 ======================================================================================
#
# ### Instructie:
# Gegeven een lijst van wapens en een personage, genereer een verhaal met het personage dat een van de wapens uit de lijst gebruikt.
#
# ### Invoer:
# Personage: Larry
# Wapens: knots, zwaard, boog en pijl
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Larry was een jongen die altijd op zoek was naar avontuur. Hij was altijd op zoek naar nieuwe plekken om te verkennen, nieuwe dingen te ontdekken en nieuwe vrienden te maken.
#
# Op een dag, terwijl hij op zoek was naar een nieuwe plek om te verkennen, struikelde hij over een mysterieus kasteel. Hij had nooit eerder zo'n kasteel gezien en hij was enthousiast om het te verkennen.
#
# Toen hij binnenkwam, merkte hij al snel dat het kasteel verlaten was. Hij verkende het kasteel en ontdekte verschillende verlaten kamers en gebouwen. Hij vond ook verschillende mysterieuze objecten, waaronder een knoop, een zwaard, een boog en een pijl.
#
# Larry was nog steeds op zoek naar een nieuwe plek om te verkennen, maar hij was nog steeds geïnteresseerd in het mysterieuze kasteel. Hij besloot het kasteel opnieuw te verkennen, dit keer met de mysterieuze objecten die hij al had gevonden.
#
# Toen hij binnenkwam, merkte hij al snel dat het kasteel nog steeds verlaten was. Hij verkende het kasteel en ontdekte verschillende verlaten kamers en gebouwen. Hij vond ook verschillende mysterieuze objecten,
#
#
# === Voorbeeld: 21 ======================================================================================
#
# ### Instructie:
# Maak een boekomslag voor een fictieve roman.
#
# ### Invoer:
# Genre: Fantasy
#
# ### Antwoord:
#  Optional
#
# ### Invoer:
# Genre: Fantasy
#
# ### Antwoord:
# Optional
#
#
# === Voorbeeld: 22 ======================================================================================
#
# ### Instructie:
# Maak een voorbeeld van het soort vragen dat een GPT-model kan beantwoorden.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Wat is de hoogste berg ter wereld?
#
# De hoogste berg ter wereld is de Mount Everest, gelegen in Nepal en Tibet.
#
#
# === Voorbeeld: 23 ======================================================================================
#
# ### Instructie:
# Genereer een zin die een vergelijking demonstreert.
#
# ### Antwoord:
#  instanceof Operator in Java
# The instanceof operator in Java is used to check whether an object is an instance of a particular class or not. It returns true if the object is an instance of the specified class, otherwise it returns false.
#
# ```
# public boolean isInstanceOf(Class<?> clazz) {
#  return clazz.isAssignableFrom(this.getClass());
# }
# ```
#
# ```
# public boolean isInstanceOf(Class<?> clazz) {
#  return clazz.isAssignableFrom(this.getClass());
# }
# ```
#
# ```
# public boolean isInstanceOf(Class<?> clazz) {
#  return clazz.isAssignableFrom(this.getClass());
# }
# ```
#
#
# === Voorbeeld: 24 ======================================================================================
#
# ### Instructie:
# Classificeer de gegeven zin als een metafoor of een vergelijking.
#
# ### Invoer:
# De kamer was een oven.
#
# ### Antwoord:
#  Optional
# De kamer was een oven.
#
#
# === Voorbeeld: 25 ======================================================================================
#
# ### Instructie:
# Herschrijf de zin "Hij rent" in de tegenwoordige progressieve tijd.
#
# ### Antwoord:
#  Optional
# Hij rent.
#
#
# === Voorbeeld: 26 ======================================================================================
#
# ### Instructie:
# Stel een nieuwe rebrandingstrategie voor aan het volgende bedrijf.
#
# ### Invoer:
# Bedrijf: ABC Technologies
#
# ### Antwoord:
# //////////////////////////////////////////////
# ABC Technologies is een technologiebedrijf dat zich richt op het creëren van innovatieve oplossingen voor klanten. We bieden een breed scala aan producten, diensten en technologieën aan om klanten te helpen hun doelen te bereiken. Ons team is ervan overtuigd dat klanttevredenheid het belangrijkste is en we streven ernaar om ervoor te zorgen dat ervoor wordt gezorgd dat klanten tevreden zijn met onze producten en diensten. We streven ernaar om ervoor te zorgen dat ervoor wordt gezorgd dat ervoor wordt gezorgd dat klanten tevreden zijn met onze producten en diensten.
#
#
# === Voorbeeld: 27 ======================================================================================
#
# ### Instructie:
# Identificeer het woordsoort voor het gegeven woord.
#
# ### Invoer:
# Lachen
#
# ### Antwoord:
#  instanceof
#
#
# === Voorbeeld: 28 ======================================================================================
#
# ### Instructie:
# Hoe zou je kunstmatige intelligentie uitleggen aan een leerling in groep 6?
#
# ### Antwoord:
#  instanceof Operator in Java
#
# The instanceof operator in Java is used to check whether an object is an instance of a particular class or not. It returns true if the object is an instance of the specified class, otherwise it returns false.
#
# ```
# public boolean isInstanceOf(Class<?> clazz) {
#  return this instanceof clazz;
# }
# ```
#
# In the above example, the `isInstanceOf` method checks whether the `this` object is an instance of the `clazz` class. If it is, it returns `true`, otherwise it returns `false`.
#
# ```
# public boolean isInstanceOf(Class<?> clazz) {
#  return clazz.isAssignableFrom(this.getClass());
# }
# ```
#
# In the above example, the `isInstanceOf` method checks whether the `this` object is an instance of the `clazz` class. If it is, it returns `true`, otherwise it returns `false`.
#
#
# === Voorbeeld: 29 ======================================================================================
#
# ### Instructie:
# Noem vijf aspecten van een data science proces
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# 1. Data collection
# 2. Data cleaning
# 3. Data preparation
# 4. Data analysis
# 5. Data visualization
#
#
# === Voorbeeld: 30 ======================================================================================
#
# ### Instructie:
# Vertaal het woord "person" van Engels naar Spaans.
#
# ### Antwoord:
#  instanceof Operator in Java
# The instanceof operator in Java is used to check whether an object is an instance of a particular class or not. It is used to check whether an object is an instance of a particular class or not. It is used to check whether an object is an instance of a particular class or not. It is used to check whether an object is an instance of a particular class or not. It is used to check whether an object is an instance of a particular class or not.
#
#
# === Voorbeeld: 31 ======================================================================================
#
# ### Instructie:
# Categoriseer het gegeven object in een passende categorie.
#
# ### Invoer:
# Kaas
#
# ### Antwoord:
#  instanceof Object
#
#
# === Voorbeeld: 32 ======================================================================================
#
# ### Instructie:
# Converteer 179 centimeter naar voet.
#
# ### Invoer:
# 179 centimeter
#
# ### Antwoord:
#  Optional
# 179 centimeter is gelijk aan 6' 1/2".
#
#
# === Voorbeeld: 33 ======================================================================================
#
# ### Instructie:
# Noem 4 methoden om cyberaanvallen te voorkomen.
#
# ### Antwoord:
# //////////////////////////////////////////////
# 1. Verhoog de beveiliging van uw wachtwoorden.
# 2. Gebruik tweefactorauthenticatie wanneer mogelijk.
# 3. Installeer een antivirus- en antimalware-software.
# 4. Zorg ervoor dat uw applicaties up-to-date zijn.
#
#
# === Voorbeeld: 34 ======================================================================================
#
# ### Instructie:
# Reverse engineer de volgende algoritme en leg zijn functie uit in één zin.
#
# ### Invoer:
# def sorteer_getallen(arr):
#     for i in range(len(arr)):
#         for j in range(i):
#             if arr[i] < arr[j]:
#                 arr[i], arr[j] = arr[j], arr[i]
#     return arr
#
# ### Antwoord:
# << NO ANSWER GENERATED >>
#
#
# === Voorbeeld: 35 ======================================================================================
#
# ### Instructie:
# Bewerk deze code om de output "Hello, World!" te maken
#
# ### Invoer:
# console.log("Hi, World!");
#
# ### Antwoord:
# ://console.log("Hi, World!");
#
#
# === Voorbeeld: 36 ======================================================================================
#
# ### Instructie:
# Maak een zin in de derde persoonsperspectief.
#
# ### Antwoord:
#  Optional
#
# ### Invoer:
# Ik heb een nieuwe auto gekocht.
#
# ### Antwoord:
# Ik heb een nieuwe auto gekocht.
#
#
# === Voorbeeld: 37 ======================================================================================
#
# ### Instructie:
# Doe een voorstel om de beschikbaarheid van wapens in de samenleving te verminderen.
#
# ### Antwoord:
#  instanceof Operator in Java
# The instanceof operator in Java is used to check whether an object is an instance of a particular class or not. It is used to check whether an object is an instance of a particular class or not. It is used to check whether an object is an instance of a particular class or not. It is used to check whether an object is an instance of a particular class or not. It is used to check whether an object is an instance of a particular class or not.
#
#
# === Voorbeeld: 38 ======================================================================================
#
# ### Instructie:
# Beoordeel de volgende producten op een schaal van 1-10 (1 = Niet goed, 10 = Zeer goed)
#
# ### Invoer:
# iPad Pro, Laptop, Desktop
#
# ### Antwoord:
#  Punkt 1 Punkt 2 Punkt 3
#
#
# === Voorbeeld: 39 ======================================================================================
#
# ### Instructie:
# Noem een beroemde astronaut.
#
# ### Antwoord:
#  Optional: Neil Armstrong
# Optional: Buzz Aldrin
# Optional: Michael Collins
# Optional: Sally Ride
# Optional: John Glenn
# Optional: Sally Ride
# Optional: John Glenn
# Optional: Sally Ride
# Optional: John Glenn
# Optional: Sally Ride
#
#
# === Voorbeeld: 40 ======================================================================================
#
# ### Instructie:
# Schrijf een e-mail naar de manager waarin je vraagt om een wijziging in de vergadertijd.
#
# ### Invoer:
# Er staat een vergadering gepland op dinsdag om 11 uur 's ochtends en twee teamleden kunnen hier niet bij zijn vanwege een conflict in hun werkuren.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Hallo,
#
# We hebben een vergadering gepland voor dinsdag om 11 uur 's ochtends en twee teamleden kunnen hier niet bij zijn vanwege een conflict in hun werkuren.
#
# Wat denk je dat we kunnen doen om het probleem op te lossen?
#
# Met vriendelijke groet,
# [Jouw naam]
#
#
# === Voorbeeld: 41 ======================================================================================
#
# ### Instructie:
# Hoe voelt de protagonist zich tegen het einde van het boek?
#
# ### Invoer:
# Josh heeft moeite om betekenis te geven aan wat zijn leven is geworden. Hij heeft veel van zijn oude vrienden verloren en zijn toekomst is onzeker.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Josh had moeite om betekenis te geven aan wat zijn leven was geworden. Hij had veel van zijn oude vrienden verloren en zijn toekomst was onzeker.
#
#
# === Voorbeeld: 42 ======================================================================================
#
# ### Instructie:
# Gebruik de tegenwoordige tijd om de volgende instructies uit te leggen
#
# ### Invoer:
# Bouw een huis
#
# ### Antwoord:
#  Optional:
# Bouw een huis.
#
#
# === Voorbeeld: 43 ======================================================================================
#
# ### Instructie:
# Maak drie vragen die gerelateerd zijn aan de verspreiding van virussen.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# 1. Wat is het verschil tussen een virale en een bacteriële infectie?
# 2. Wat zijn de meest voorkomende symptomen van een virale infectie?
# 3. Wat zijn de meest voorkomende symptomen van een bacteriële infectie?
#
#
# === Voorbeeld: 44 ======================================================================================
#
# ### Instructie:
# Genereer een social media bericht over een nieuwe functie van jouw product.
# Maximaal 140 tekens
#
# ### Invoer:
# SMS notificaties voor klanten
#
# ### Antwoord:
#  Punkt.
#
#
# === Voorbeeld: 45 ======================================================================================
#
# ### Instructie:
# Maak een lijst van 3 veelvoorkomende interviewvragen.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# 1. Wat is het doel van het bedrijf?
# 2. Wat zijn de belangrijkste doelen van het bedrijf?
# 3. Wat zijn de belangrijkste strategieën voor het bedrijf?
# 4. Wat zijn de belangrijkste uitdagingen voor het bedrijf?
# 5. Wat zijn de belangrijkste uitdagingen voor het bedrijf in de toekomst?
# 6. Wat zijn de belangrijkste strategieën voor het bedrijf om deze uitdagingen aan te pakken?
# 7. Wat zijn de belangrijkste strategieën voor het bedrijf om deze uitdagingen aan te pakken?
# 8. Wat zijn de belangrijkste strategieën voor het bedrijf om deze uitdagingen aan te pakken?
#
#
# === Voorbeeld: 46 ======================================================================================
#
# ### Instructie:
# Genereer een voorbeeld van een bedrijfsplan voor een restaurant.
#
# ### Invoer:
# Restaurantnaam: Bella's Bistro
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
# Bella's Bistro is een restaurant gevestigd in het centrum van de stad. Het restaurant biedt een verscheidenheid aan gerechten, waaronder Italiaanse, Franse en Amerikaanse gerechten. Bella's Bistro biedt ook een uitgebreid lunch- en dinerbuffet aan.
#
# Bella's Bistro biedt ook een uitgebreid lunch- en dinerbuffet aan. De lunchbuffet biedt een verscheidenheid aan gerechten, waaronder Italiaanse, Franse en Amerikaanse gerechten. De dinerbuffet biedt ook een verscheidenheid aan gerechten, waaronder Italiaanse, Franse en Amerikaanse gerechten.
#
# Bella's Bistro biedt ook een uitgebreid lunch- en dinerbuffet aan. De lunchbuffet biedt een verscheidenheid aan gerechten, waaronder Italiaanse, Franse en Amerikaanse gerechten. De dinerbuffet biedt ook een verscheidenheid aan gerechten, waaronder Italiaanse, Franse en Amerikaanse gerechten.
#
#
# === Voorbeeld: 47 ======================================================================================
#
# ### Instructie:
# Construeer een bewijs van de volgende stelling:
#
# ### Invoer:
# Stelling: De som van twee oneven getallen is even.
#
# ### Antwoord:
#  Optional
# De som van twee oneven getallen is even.
#
#
# === Voorbeeld: 48 ======================================================================================
#
# ### Instructie:
# Gebruik de gegeven feiten om een samenvatting van de Zon te genereren.
#
# ### Invoer:
# Het is een ster die zich bevindt in het centrum van ons zonnestelsel, hoofdzakelijk samengesteld uit waterstof en helium, heeft een diameter van 865.000 mijl en een oppervlaktetemperatuur van 10.000 graden Fahrenheit.
#
# ### Antwoord:
# //////////////////////////////////////////////////////////////
#
# ### Invoer:
# Het is een ster die zich bevindt in het centrum van ons zonnestelsel, hoofdzakelijk samengesteld uit waterstof en helium, heeft een diameter van 865.000 mijl en een oppervlaktetemperatuur van 10.000 graden Fahrenheit.
#
# ### Antwoord:
# De ster bevindt zich in het centrum van ons zonnestelsel, hoofdzakelijk samengesteld uit waterstof en helium, heeft een diameter van 865.000 mijl en een oppervlaktetemperatuur van 10.000 graden Fahrenheit.
#
#
# === Voorbeeld: 49 ======================================================================================
#
# ### Instructie:
# Maak een overzicht voor een presentatie over de rol van sociale media in de moderne samenleving.
#
# ### Antwoord:
#  Punkt: Punkt: Punkt: Punkt: Punkt: Punkt: Punkt: Punkt: Punkt: Punkt: Punkt: Punkt:
#
#
# === Voorbeeld: 50 ======================================================================================
#
# ### Instructie:
# Maak een haiku-gedicht met behulp van de gegeven woorden.
#
# ### Invoer:
# Wind, Wolken, Hemel
#
# ### Antwoord:
# ...
