# %% [markdown]
# <a href="https://colab.research.google.com/github/RobinSmits/Dutch-LLMs/blob/main/Open_Llama_7B_Alpaca_Clean_Dutch_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
import os
from google.colab import drive
drive.mount('/content/drive')

# Set Google Drive Folder to use...Copy Val_Data folder from Github into it to be able to reproduce the results.
WORK_DIR = '/content/drive/My Drive/LLM/OpenLlama7BAlpacaCleanDutchQlora/'
os.makedirs(WORK_DIR, exist_ok = True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Install modules
# !pip install -q accelerate
# !pip install -q sentencepiece
# !pip install -q bitsandbytes
# !pip install -q transformers
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q datasets
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
# Import Modules
from datasets import load_dataset, load_from_disk
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#  and submit this information together with your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# bin /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching in backup paths...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 8.0
# CUDA SETUP: Detected CUDA version 118
# CUDA SETUP: Loading binary /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so...
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: /usr/lib64-nvidia did not contain ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] as expected! Searching further paths...
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.28.0.1'), PosixPath('8013'), PosixPath('http')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/gpu-a100-s-sf5dl8xhm2qt --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true'), PosixPath('--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/env/python')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('module'), PosixPath('//ipykernel.pylab.backend_inline')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: Found duplicate ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] files: {PosixPath('/usr/local/cuda/lib64/libcudart.so'), PosixPath('/usr/local/cuda/lib64/libcudart.so.11.0')}.. We'll flip a coin and try one of these, in order to fail forward.
# Either way, this might cause trouble in the future:
# If you get `CUDA error: invalid device function` errors, the above might be the cause and the solution is to make sure only one ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] in the paths that we search based on your env.
#   warn(msg)

# %%
# Set Model Name Constant
model_name = "robinsmits/open_llama_7b_alpaca_clean_dutch_qlora"

# %%
# Create Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name,
                                          use_fast = False,
                                          add_eos_token = True)
tokenizer.pad_token_id = 0

# Max Length
MAX_LEN = 512

# Tokenizer Summary
print(tokenizer)

# Special Tokens
print('pad_token_id: ', tokenizer.pad_token_id)
print('bos_token_id: ', tokenizer.bos_token_id)
print('eos_token_id: ', tokenizer.eos_token_id)
print('pad_token: ', tokenizer.decode(tokenizer.pad_token_id))
print('bos_token: ', tokenizer.decode(tokenizer.bos_token_id))
print('eos_token: ', tokenizer.decode(tokenizer.eos_token_id))
# Out:
# LlamaTokenizer(name_or_path='robinsmits/open_llama_7b_alpaca_clean_dutch_qlora', vocab_size=32000, model_max_length=2048, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'bos_token': AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'eos_token': AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'unk_token': AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'pad_token': '<unk>'}, clean_up_tokenization_spaces=False)
# pad_token_id:  0
# bos_token_id:  1
# eos_token_id:  2
# pad_token:  <unk>
# bos_token:  <s>
# eos_token:  </s>

# %%
# Create PEFT Config
config = PeftConfig.from_pretrained(model_name)

# Create Model
model = AutoModelForCausalLM.from_pretrained(config.base_model_name_or_path,
                                             load_in_8bit = True,
                                             device_map = "auto")
model = PeftModel.from_pretrained(model, model_name)

# Summary
print(model)
# Out:
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(32000, 4096, padding_idx=0)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): Linear8bitLt(
#                 in_features=4096, out_features=4096, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): Linear8bitLt(in_features=4096, out_features=4096, bias=False)
#               (v_proj): Linear8bitLt(
#                 in_features=4096, out_features=4096, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): Linear8bitLt(in_features=4096, out_features=4096, bias=False)
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear8bitLt(in_features=4096, out_features=11008, bias=False)
#               (down_proj): Linear8bitLt(in_features=11008, out_features=4096, bias=False)
#               (up_proj): Linear8bitLt(in_features=4096, out_features=11008, bias=False)
#               (act_fn): SiLUActivation()
#             )
#             (input_layernorm): LlamaRMSNorm()
#             (post_attention_layernorm): LlamaRMSNorm()
#           )
#         )
#         (norm): LlamaRMSNorm()
#       )
#       (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
#     )
#   )
# )

# %% [markdown]
# I'am using the same validation set as during training of the notebook.
#
# This allows for some further analysis in this Inference notebook without data leakage.
#
# The required train and validation files are stored in my github account. Notice that the original code to generate the train and validation dataset is in the commented out section.

# %%
"""
# Alpaca Translated
datasets = load_dataset('BramVanroy/alpaca-cleaned-dutch')

# Summary
print(datasets)

# Validation size
VAL_SIZE = 2048

# Split in Train and Val datasets
dataset_split = datasets["train"].train_test_split(test_size = VAL_SIZE,
                                                   shuffle = True,
                                                   seed = 42)

# Train and Val datasets
train_data = dataset_split["train"]
val_data = dataset_split["test"]

# Save for later use
val_data.save_to_disk(f'{WORK_DIR}val_data')
train_data.save_to_disk(f'{WORK_DIR}train_data')
"""

# Load Validation set from earlier training run...use code above to generate new train and val datasets if required
val_data = load_from_disk(f'{WORK_DIR}val_data')

# %%
def generate_eval_prompt(item):
    if item["input"]:
        return f"""
### Instructie:
{item["instruction"]}

### Invoer:
{item["input"]}

### Antwoord:"""
    else:
        return f"""
### Instructie:
{item["instruction"]}

### Antwoord:"""

# %%
def generate(instruction, input = None):
    # Generate Prompt
    prompt = generate_eval_prompt({'instruction': instruction, 'input': input})

    # Tokenize
    input_ids = tokenizer(prompt, return_tensors = "pt", truncation = True).input_ids.cuda()

    # Generate output
    outputs = model.generate(input_ids = input_ids,
                             max_new_tokens = MAX_LEN,
                             num_beams = 2,
                             early_stopping = True,
                             forced_eos_token_id = tokenizer.eos_token_id)

    # Decode output
    generated_output = tokenizer.decode(outputs[0], skip_special_tokens = True)

    # Print prompt and answer extracted from generated output
    print(prompt)
    if prompt in generated_output:
        answer = generated_output.split(prompt)[1]
        print(answer)
    else:
        print('<< NO ANSWER GENERATED >>')

# Validation Loop
counter = 0
for item in val_data:
    print(f'\n\n=== Voorbeeld: {counter} ======================================================================================')
    generate(item['instruction'], item['input'])

    counter += 1
    if counter > 50:
        break
# Out:
# === Voorbeeld: 0 ======================================================================================
#
# ### Instructie:
# Wat zijn de drie belangrijkste softwareonderdelen die worden gebruikt bij webontwikkeling?
#
# ### Antwoord:
#  </br>
# De drie belangrijkste softwareonderdelen die worden gebruikt bij webontwikkeling zijn HTML, CSS en JavaScript.
#
#
# === Voorbeeld: 1 ======================================================================================
#
# ### Instructie:
# Genereer een wachtwoord dat aan de volgende eisen voldoet: minimaal 8 tekens, één hoofdletter, één kleine letter, één cijfer en één speciaal teken.
#
# ### Antwoord:
#  </br>
# <b>123456789012345</b>
#
#
# === Voorbeeld: 2 ======================================================================================
#
# ### Instructie:
# Stel vijf activiteiten voor om zelfzorg te bevorderen
#
# ### Antwoord:
#  </p>
#
# 1. Houd een slaaproutine.
# 2. Eet een gezond dieet.
# 3. Beweeg regelmatig.
# 4. Zorg voor voldoende slaap.
# 5. Maak tijd voor jezelf.
#
#
# === Voorbeeld: 3 ======================================================================================
#
# ### Instructie:
# Ontdek of een zin sarcastisch is.
#
# ### Invoer:
# Dat is geweldig nieuws.
#
# ### Antwoord:
#  </br>
# Ja, deze zin is sarcastisch.
#
#
# === Voorbeeld: 4 ======================================================================================
#
# ### Instructie:
# Gegeven een kort stukje tekst, verwijder alle bijwoorden en vervang ze door meer passende woorden.
#
# ### Invoer:
# Hij rende snel naar de winkel om wat eten te kopen.
#
# ### Antwoord:
#  </p>
# Hij rende snel naar de winkel om wat eten te kopen.
#
#
# === Voorbeeld: 5 ======================================================================================
#
# ### Instructie:
# Geef twee voorbeelden van activiteiten die fysieke kracht vereisen.
#
# ### Antwoord:
#  </br>
# Twee voorbeelden van activiteiten die fysieke kracht vereisen zijn hardlopen en zwemmen.
#
#
# === Voorbeeld: 6 ======================================================================================
#
# ### Instructie:
# Vind de vergelijking van de lijn die door het gegeven punt gaat en parallel is aan de gegeven vector.
#
# ### Invoer:
# Punt: (2, 1), Vector: (−2, 1)
#
# ### Antwoord:
#  </br>
# De vergelijking van de lijn die door het punt (2, 1) gaat en parallel is aan de vector (−2, 1) is y = 2x + 1.
#
#
# === Voorbeeld: 7 ======================================================================================
#
# ### Instructie:
# Gegeven een zin en een lijst met bijwoorden, pas de zin aan met behulp van de bijwoorden.
#
# ### Invoer:
# Hij liep langzaam
# Bijwoorden: met tegenzin, aarzelend
#
# ### Antwoord:
#  </br> Hij liep langzaam met tegenzin.
#
#
# === Voorbeeld: 8 ======================================================================================
#
# ### Instructie:
# Identificeer alle componenten van een gegeven wetenschappelijke term.
#
# ### Invoer:
# Fotosynthese
#
# ### Antwoord:
#  </br>
# Fotosynthese is het proces waarbij zonlicht wordt gebruikt om zuurstof, water en koolstofdioxide om te zetten in zuurstofgas, water en glucose.
#
#
# === Voorbeeld: 9 ======================================================================================
#
# ### Instructie:
# Beschrijf de verschillen tussen een asynchrone en synchrone webapplicatie.
#
# ### Antwoord:
#  </br>
# Een asynchrone webapplicatie is een webapplicatie die gegevens opnemen en verwerken, terwijl een synchrone webapplicatie gegevens opnemen en verwerken, maar geen gegevens opnemen of verwerken. Asynchrone webapplicaties worden vaak gebruikt om gegevens op te slaan, terwijl synchrone webapplicaties worden gebruikt om gegevens op te slaan en te verwerken.
#
#
# === Voorbeeld: 10 ======================================================================================
#
# ### Instructie:
# Classificeer deze zin als een gebiedende wijs of een vraag.
#
# ### Invoer:
# Deze salade smaakt heerlijk.
#
# ### Antwoord:
#  </span> Gebiedende wijs
#
#
# === Voorbeeld: 11 ======================================================================================
#
# ### Instructie:
# Onderzoek en maak een lijst van de gezondheidsvoordelen van het eten van appels.
#
# ### Antwoord:
#  </br>
# Appels hebben een verscheidenheid aan gezondheidsvoordelen. Ze bevatten vitamine C, vitamine A, vitamine K, vitamine B6, vitamine E, vitamine K, vitamine B1, vitamine B2, vitamine B3, vitamine B5, vitamine B6, vitamine B7, vitamine B9, vitamine C, vitamine D, vitamine K, vitamine E, vitamine K, vitamine B1, vitamine B2, vitamine B3, vitamine B5, vitamine B6, vitamine B7, vitamine B9, vitamine C, vitamine D, vitamine K, vitamine E, vitamine K, vitamine B1, vitamine B2, vitamine B3, vitamine B5, vitamine B6, vitamine B7, vitamine B9, vitamine C, vitamine D, vitamine K, vitamine E, vitamine K, vitamine B1, vitamine B2, vitamine B3, vitamine B5, vitamine B6, vitamine B7, vitamine B9, vitamine C, vitamine D, vitamine K, vitamine E, vitamine K, vitamine B1, vitamine B2, vitamine B3, vitamine B5, vitamine B6, vitamine B7, vitamine B9, vitamine C, vitamine D, vitamine K, vitamine E, vitamine K, vitamine B1, vitamine B2, vitamine B3, vitamine B5, vitamine B6, vitamine B7, vitamine B9, vitamine C, vitamine D, vitamine K, vitamine E, vitamine K, vitamine B1, vitamine B2, vitamine B3, vitamine B5, vitamine B6, vitamine B7, vitamine B9, vitamine C, vitamine D, vitamine K, vitamine E, vitamine K, vitamine B1, vitamine B2, vitamine B3, vitamine B5, vitamine B6, vitamine B7, vitamine B9, vitamine C, vitamine D, vitamine K, vitamine E, vitamine K, vitamine B1, vitamine B2, vitamine B3,
#
#
# === Voorbeeld: 12 ======================================================================================
#
# ### Instructie:
# Geef een voorbeeld van een technologie die probabilistisch denken gebruikt.
#
# ### Antwoord:
#  </br>
# Een voorbeeld van een technologie die probabilistisch denken gebruikt, is Machine Learning. Machine Learning is een vakgebied van Kunstmatige Intelligentie dat zich richt op het ontwikkelen van algoritmen die kunnen leren van gegevens en voorspellen of beslissingen kunnen nemen op basis van de gegevens. Deze algoritmen kunnen worden gebruikt in verschillende toepassingen zoals beeldherkenning, natuurlijke taalverwerking en voorspellende analyse.
#
#
# === Voorbeeld: 13 ======================================================================================
#
# ### Instructie:
# Wat zijn de drie kenmerken van een goed argument?
#
# ### Antwoord:
#  </p>
#
# De drie kenmerken van een goed argument zijn duidelijkheid, bewijs en logica. Duidelijkheid betekent dat het argument duidelijk is geschreven en begrijpelijk is. Bewijs betekent dat het argument bewijs toont dat de theorie waar is. Logica betekent dat het argument logisch is geschreven.
#
#
# === Voorbeeld: 14 ======================================================================================
#
# ### Instructie:
# De functie f heeft de eigenschap dat voor elke reëel getal x in zijn domein, 1/x ook in zijn domein is en f(x) + f(1/x) = x.
# Wat is de grootste verzameling van reële getallen die in het domein van f kan zijn?
#
# (a) {x| x0}
#
# (b) {x| x<0}
#
# (c) {x| x>0}
#
# (d) {x| x-1 en x0 en x1}
#
# (e) {-1,1}
#
# ### Antwoord:
#
#
#
# === Voorbeeld: 15 ======================================================================================
#
# ### Instructie:
# Combineer de 2 passages en creëer een nieuw verhaal
#
# ### Invoer:
# Passage 1: Sarah liep naar huis van school toen ze een hard getik in de buurt hoorde.
#
# Passage 2: Ze keek op om een hoge boom te zien met een grote vogel erop, die zijn vleugels in de wind sloeg.
#
# ### Antwoord:
#  </br> Sarah liep naar huis van school toen ze een hard getik in de buurt hoorde. Ze keek op om een hoge boom te zien met een grote vogel erop, die zijn vleugels in de wind sloeg.
#
#
# === Voorbeeld: 16 ======================================================================================
#
# ### Instructie:
# Wat gebeurt er als we 100 ml water mengen met 30 ml azijn?
#
# ### Antwoord:
#  </br>
# Het resultaat van het mengen van 100 ml water met 30 ml azijn is 130 ml azijn.
#
#
# === Voorbeeld: 17 ======================================================================================
#
# ### Instructie:
# Waar of niet waar, zelfrijdende auto's zijn haalbaar voor snelwegen.
#
# ### Antwoord:
#  </p>
#
# Zelfrijdende auto's zijn momenteel niet haalbaar voor snelwegen, omdat ze nog steeds onvoldoende geavanceerde technologieën hebben om zichzelf te controleren en te voorkomen dat ze te veel rijden.
#
# Zelfrijdende auto's zijn momenteel nog niet haalbaar voor snelwegen, omdat ze nog steeds onvoldoende geavanceerde technologieën hebben om zichzelf te controleren en te voorkomen dat ze te veel rijden.
#
# Zelfrijdende auto's zijn momenteel nog niet haalbaar voor snelwegen, omdat ze nog steeds onvoldoende geavanceerde technologieën hebben om zichzelf te controleren en te voorkomen dat ze te veel rijden.
#
# Zelfrijdende auto's zijn momenteel nog niet haalbaar voor snelwegen, omdat ze nog steeds onvoldoende geavanceerde technologieën hebben om zichzelf te controleren en te voorkomen dat ze te veel rijden.
#
# Zelfrijdende auto's zijn momenteel nog niet haalbaar voor snelwegen, omdat ze nog steeds onvoldoende geavanceerde technologieën hebben om zichzelf te controleren en te voorkomen dat ze te veel rijden.
#
#
# === Voorbeeld: 18 ======================================================================================
#
# ### Instructie:
# Identificeer het hoofdidee van de tekst.
#
# ### Invoer:
# Global warming is de term die wordt gebruikt om een geleidelijke toename van de gemiddelde temperatuur van de atmosfeer en oceanen van de aarde te beschrijven, een verandering die wordt geloofd permanent de klimaat van de aarde te veranderen.
#
# ### Antwoord:
#  </br>
# Het hoofdidee van deze tekst is dat global warming een geleidelijke toename van de gemiddelde temperatuur van de atmosfeer en oceanen van de aarde is.
#
#
# === Voorbeeld: 19 ======================================================================================
#
# ### Instructie:
# Noem drie elementen van cyberbeveiliging.
#
# ### Antwoord:
#  </p>
# Drie elementen van cyberbeveiliging zijn:
# 1. Wachtwoordbeveiliging: Wachtwoorden moeten veilig en complex zijn en moeten worden bijgewerkt op frequente basis.
# 2. Firewalls: Firewalls moeten worden geïnstalleerd om toegang tot ongeautoriseerde bronnen te voorkomen.
# 3. Antivirussoftware: Antivirussoftware moet worden geïnstalleerd om ervoor te zorgen dat het systeem niet wordt beschadigd door malware.
#
#
# === Voorbeeld: 20 ======================================================================================
#
# ### Instructie:
# Gegeven een lijst van wapens en een personage, genereer een verhaal met het personage dat een van de wapens uit de lijst gebruikt.
#
# ### Invoer:
# Personage: Larry
# Wapens: knots, zwaard, boog en pijl
#
# ### Antwoord:
#  </p>
#
# <p>Larry was een dappere ridder die zijn leven op zoek ging naar de moedige strijd. Hij had een knokploeg van vrienden en familieleden die zich bij hem voegden en samen gingen strijden tegen de kwaadaardige krachten van de wereld.</p>
#
# <p>Op een dag besloot Larry zichzelf te verdedigen tegen een groep vijanden die hem achtervolgden. Hij slaagde erin om de vijanden te verslaan, maar in de strijd raakte hij zwaar gewond. Hij werd gedwongen om zichzelf te verdedigen, maar hij slaagde erin om zichzelf te redden.</p>
#
# <p>Na de strijd keerde Larry terug naar huis, maar hij had een nieuwe waardering voor de moedige strijd. Hij had de moedige strijd gewonnen, maar hij had ook de moedige strijd van zijn vrienden en familieleden gewonnen.</p>
#
# <p>Larry was een dappere ridder die zijn leven op zoek ging naar de moedige strijd. Hij had een knokploeg van vrienden en familieleden die zich bij hem voegden en samen gingen strijden tegen de kwaadaardige krachten van de wereld.</p>
#
#
# === Voorbeeld: 21 ======================================================================================
#
# ### Instructie:
# Maak een boekomslag voor een fictieve roman.
#
# ### Invoer:
# Genre: Fantasy
#
# ### Antwoord:
#  </span>
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px;">
# <span style="font-size: 14px
#
#
# === Voorbeeld: 22 ======================================================================================
#
# ### Instructie:
# Maak een voorbeeld van het soort vragen dat een GPT-model kan beantwoorden.
#
# ### Antwoord:
#  </p>
#
# <p>Welk soort voedingsmiddel heeft de hoogste hoeveelheid vitamine B12?</p>
#
# <p>Welk soort voedingsmiddel heeft de hoogste hoeveelheid vitamine B12?</p>
#
# <p>Welk soort voedingsmiddel heeft de hoogste hoeveelheid vitamine B12?</p>
#
# <p>Welk soort voedingsmiddel heeft de hoogste hoeveelheid vitamine B12?</p>
#
# <p>Welk soort voedingsmiddel heeft de hoogste hoeveelheid vitamine B12?</p>
#
# <p>Welk soort voedingsmiddel heeft de hoogste hoeveelheid vitamine B12?</p>
#
# <p>Welk soort voedingsmiddel heeft de hoogste hoeveelheid vitamine B12?</p>
#
# <p>Welk soort voedingsmiddel heeft de hoogste hoeveelheid vitamine B12?
#
#
# === Voorbeeld: 23 ======================================================================================
#
# ### Instructie:
# Genereer een zin die een vergelijking demonstreert.
#
# ### Antwoord:
#  </p>
#
# <p>De zon was zo helder als een diamant.</p>
#
#
# === Voorbeeld: 24 ======================================================================================
#
# ### Instructie:
# Classificeer de gegeven zin als een metafoor of een vergelijking.
#
# ### Invoer:
# De kamer was een oven.
#
# ### Antwoord:
#  </br>
# Metafoor
#
#
# === Voorbeeld: 25 ======================================================================================
#
# ### Instructie:
# Herschrijf de zin "Hij rent" in de tegenwoordige progressieve tijd.
#
# ### Antwoord:
#  </br>Hij rent.
#
#
# === Voorbeeld: 26 ======================================================================================
#
# ### Instructie:
# Stel een nieuwe rebrandingstrategie voor aan het volgende bedrijf.
#
# ### Invoer:
# Bedrijf: ABC Technologies
#
# ### Antwoord:
#  </p>
#
# <p>ABC Technologies is een gerenommeerd bedrijf dat zich bezighoudt met het ontwikkelen en onderhouden van software. Het bedrijf heeft een sterke reputatie van innovatieve ontwikkeling en ondersteuning van zijn klanten. Het bedrijf heeft een sterke focus op klantenservice en ondersteunt zijn klanten met 24/7 ondersteuning. Het bedrijf heeft een sterke focus op klantenservice en ondersteunt zijn klanten met 24/7 ondersteuning. Het bedrijf heeft een sterke focus op klantenservice en ondersteunt zijn klanten met 24/7 ondersteuning. Het bedrijf heeft een sterke focus op klantenservice en ondersteunt zijn klanten met 24/7 ondersteuning. Het bedrijf heeft een sterke focus op klantenservice en ondersteunt zijn klanten met 24/
#
#
# === Voorbeeld: 27 ======================================================================================
#
# ### Instructie:
# Identificeer het woordsoort voor het gegeven woord.
#
# ### Invoer:
# Lachen
#
# ### Antwoord:
#  </p>
# Het woord "lachen" is een zelfstandig naamwoord.
#
#
# === Voorbeeld: 28 ======================================================================================
#
# ### Instructie:
# Hoe zou je kunstmatige intelligentie uitleggen aan een leerling in groep 6?
#
# ### Antwoord:
#  </p>
#
# <p>Kunstmatige intelligentie (KI) is een vakgebied van de informatica dat zich bezighoudt met het ontwikkelen van computersystemen die kunnen denken, leren en reageren zoals mensen. Het omvat het ontwikkelen van algoritmen, software en hardware die kunnen leren van gegevens en beslissingen kunnen nemen op basis van deze gegevens. KI wordt vaak gebruikt in verschillende toepassingen, zoals gezondheidszorg, financiën, onderwijs en autonome voertuigen. Het wordt ook gebruikt in veel andere toepassingen, zoals robotica, natuurlijke taalverwerking en spraakherkenning.</p>
#
# <p>KI wordt vaak gebruikt in vele toepassingen, zoals gezondheidszorg, financiën, onderwijs en autonome voertuigen. Het wordt ook gebruikt in vele andere toepassingen, zoals robotica, natuurlijke taalverwerking en spraakherkenning.</p>
#
# <p>KI wordt vaak gebruikt in vele toepassingen, zoals gezondheidszorg, financiën, onderwijs en autonome voertuigen. Het wordt ook gebruikt in vele andere toepassingen, zoals robotica, natuurlijke taalverwerking en spraakherkenning.</p>
#
#
# === Voorbeeld: 29 ======================================================================================
#
# ### Instructie:
# Noem vijf aspecten van een data science proces
#
# ### Antwoord:
#  </p>
# 1. Data Preprocessing
# 2. Data Mining
# 3. Data Visualization
# 4. Machine Learning
# 5. Data Mining Algorithms
#
#
# === Voorbeeld: 30 ======================================================================================
#
# ### Instructie:
# Vertaal het woord "person" van Engels naar Spaans.
#
# ### Antwoord:
#  </p>
# </div>
#
# <div class="output">
# <p>Person</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
# <div class="output">
# <p>Persona</p>
# </div>
#
#
#
# === Voorbeeld: 31 ======================================================================================
#
# ### Instructie:
# Categoriseer het gegeven object in een passende categorie.
#
# ### Invoer:
# Kaas
#
# ### Antwoord:
#  </br>
# Kaas is een voedselproduct dat bestaat uit de eieren van koeien, schaapsen of varkens. Het wordt vaak gebruikt als voedsel, maar kan ook worden gebruikt als ingrediënt in verschillende gerechten.
#
#
# === Voorbeeld: 32 ======================================================================================
#
# ### Instructie:
# Converteer 179 centimeter naar voet.
#
# ### Invoer:
# 179 centimeter
#
# ### Antwoord:
#  </br> 179 cm
#
#
# === Voorbeeld: 33 ======================================================================================
#
# ### Instructie:
# Noem 4 methoden om cyberaanvallen te voorkomen.
#
# ### Antwoord:
#  DTLS (Datagram Transport Layer Security) is een protocol dat wordt gebruikt om de veiligheid van het netwerk te verbeteren. Het wordt gebruikt bij het verzenden en ontvangen van grote hoeveelheden gegevens, zoals streaming-streams en videoprogramma's. Het wordt ook gebruikt bij het verzenden en ontvangen van grote hoeveelheden gegevens, zoals streaming-streams en videoprogramma's.
#
# Het DTLS-protocol wordt gebruikt bij het verzenden en ontvangen van grote hoeveelheden gegevens, zoals streaming-streams en videoprogramma's. Het DTLS-protocol wordt ook gebruikt bij het verzenden en ontvangen van grote hoeveelheden gegevens, zoals streaming-streams en videoprogramma's.
#
# Het DTLS-protocol wordt gebruikt bij het verzenden en ontvangen van grote hoeveelheden gegevens, zoals streaming-streams en videoprogramma's. Het DTLS-protocol wordt ook gebruikt bij het verzenden en ontvangen van grote hoeveelheden gegevens, zoals streaming-streams en videoprogramma's.
#
# Het DTLS-protocol wordt gebruikt bij het verzenden en ontvangen van grote hoeveelheden gegevens, zoals streaming-streams en videoprogramma's. Het DTLS-protocol wordt ook gebruikt bij het verzenden en ontvangen van grote hoeveelheden gegevens, zoals streaming-streams en videoprogramma's.
#
#
# === Voorbeeld: 34 ======================================================================================
#
# ### Instructie:
# Reverse engineer de volgende algoritme en leg zijn functie uit in één zin.
#
# ### Invoer:
# def sorteer_getallen(arr):
#     for i in range(len(arr)):
#         for j in range(i):
#             if arr[i] < arr[j]:
#                 arr[i], arr[j] = arr[j], arr[i]
#     return arr
#
# ### Antwoord:
# << NO ANSWER GENERATED >>
#
#
# === Voorbeeld: 35 ======================================================================================
#
# ### Instructie:
# Bewerk deze code om de output "Hello, World!" te maken
#
# ### Invoer:
# console.log("Hi, World!");
#
# ### Antwoord:
#  </br>
# console.log("Hello, World!");
#
#
# === Voorbeeld: 36 ======================================================================================
#
# ### Instructie:
# Maak een zin in de derde persoonsperspectief.
#
# ### Antwoord:
#  </p>
#
# <p>Ik ben zo blij om te zien dat jouw werk goed is.</p>
#
# <p>Ik ben zo blij om te zien dat jouw werk goed is.</p>
#
#
# === Voorbeeld: 37 ======================================================================================
#
# ### Instructie:
# Doe een voorstel om de beschikbaarheid van wapens in de samenleving te verminderen.
#
# ### Antwoord:
#  </br>
# Een manier om de beschikbaarheid van wapens in de samenleving te verminderen, is door een wet te schrijven die de verkoop van wapens aan ongewapende individuen verbiedt. Dit zou de beschikbaarheid van wapens in de samenleving verminderen, omdat wapens niet meer aan ongewapende individuen kunnen worden verkocht. Bovendien zou dit de beschikbaarheid van wapens in de samenleving verminderen, omdat wapens niet meer aan ongewapende individuen kunnen worden verkocht.
#
#
# === Voorbeeld: 38 ======================================================================================
#
# ### Instructie:
# Beoordeel de volgende producten op een schaal van 1-10 (1 = Niet goed, 10 = Zeer goed)
#
# ### Invoer:
# iPad Pro, Laptop, Desktop
#
# ### Antwoord:
#  </br>
# iPad Pro: 10
# Laptop: 8
# Desktop: 7
#
#
# === Voorbeeld: 39 ======================================================================================
#
# ### Instructie:
# Noem een beroemde astronaut.
#
# ### Antwoord:
#  </p>
# <p>De beroemde astronaut is Neil Armstrong. Hij was de eerste persoon die op de maan landde en de eerste persoon die op de maan stond. Hij was ook de eerste persoon die de maan bezocht en de eerste persoon die de maan verliet.</p>
#
# <p>Hij werd geboren op 5 augustus 1930 in Wapakoneta, Ohio en overleed op 25 augustus 2012 in Cincinnati, Ohio.</p>
#
# <p>Armstrong was de eerste persoon die op de maan landde en de eerste persoon die op de maan stond. Hij was ook de eerste persoon die de maan verli
#
#
# === Voorbeeld: 40 ======================================================================================
#
# ### Instructie:
# Schrijf een e-mail naar de manager waarin je vraagt om een wijziging in de vergadertijd.
#
# ### Invoer:
# Er staat een vergadering gepland op dinsdag om 11 uur 's ochtends en twee teamleden kunnen hier niet bij zijn vanwege een conflict in hun werkuren.
#
# ### Antwoord:
#  </p>
#
# <p>Beste Manager, </p>
#
# <p>Ik schrijf u om een wijziging in de vergadertijd te vragen. Er staat een vergadering gepland op dinsdag om 11 uur 's ochtends en twee teamleden kunnen hier niet bij zijn vanwege een conflict in hun werkuren. </p>
#
# <p>Ik begrijp dat dit moeilijk kan zijn, maar ik zou het graag willen weten of er iets kan worden gedaan om deze situatie te verbeteren. </p>
#
# <p>Bedankt voor uw tijd en overweging. </p>
#
# <p>Met vriendelijke groet, </p>
#
# <p>[Uw naam] </p>
#
#
# === Voorbeeld: 41 ======================================================================================
#
# ### Instructie:
# Hoe voelt de protagonist zich tegen het einde van het boek?
#
# ### Invoer:
# Josh heeft moeite om betekenis te geven aan wat zijn leven is geworden. Hij heeft veel van zijn oude vrienden verloren en zijn toekomst is onzeker.
#
# ### Antwoord:
#  </span>
# Josh heeft moeite om betekenis te geven aan wat zijn leven is geworden. Hij heeft veel van zijn oude vrienden verloren en zijn toekomst is onzeker.
#
#
# === Voorbeeld: 42 ======================================================================================
#
# ### Instructie:
# Gebruik de tegenwoordige tijd om de volgende instructies uit te leggen
#
# ### Invoer:
# Bouw een huis
#
# ### Antwoord:
#  </br>
# Bouw een huis
#
#
# === Voorbeeld: 43 ======================================================================================
#
# ### Instructie:
# Maak drie vragen die gerelateerd zijn aan de verspreiding van virussen.
#
# ### Antwoord:
#  </p>
#
# 1. Wat zijn de belangrijkste risico's van het ontwikkelen en gebruiken van virussen?
# 2. Wat zijn de belangrijkste veiligheidsmaatregelen om te nemen bij het ontwikkelen en gebruiken van virussen?
# 3. Wat zijn de belangrijkste methoden om virussen te detecteren en te elimineren?
#
#
# === Voorbeeld: 44 ======================================================================================
#
# ### Instructie:
# Genereer een social media bericht over een nieuwe functie van jouw product.
# Maximaal 140 tekens
#
# ### Invoer:
# SMS notificaties voor klanten
#
# ### Antwoord:
#  </br>
# Het nieuwste verschijnsel van ons nieuwe product is de mogelijkheid om SMS notificaties te ontvangen voor klanten. Met deze functie kunnen klanten op de hoogte gehouden worden van belangrijke updates en kunnen ze snel informatie krijgen over hun bestellingen. We zijn verheugd dat onze klanten deze nieuwe functie kunnen gebruiken om snel en gemakkelijk op de hoogte te blijven van belangrijke updates. </br>
#
#
# === Voorbeeld: 45 ======================================================================================
#
# ### Instructie:
# Maak een lijst van 3 veelvoorkomende interviewvragen.
#
# ### Antwoord:
#  </br>
# 1. Wat heeft je gemotiveerd om deel te nemen aan deze baan?
# 2. Wat zijn de belangrijkste uitdagingen die je hebt moeten overwinnen in deze functie?
# 3. Wat zijn de belangrijkste voordelen van deze baan?
#
#
# === Voorbeeld: 46 ======================================================================================
#
# ### Instructie:
# Genereer een voorbeeld van een bedrijfsplan voor een restaurant.
#
# ### Invoer:
# Restaurantnaam: Bella's Bistro
#
# ### Antwoord:
#  </p>
#
# <p>Bella's Bistro is een geweldige keuze voor een restaurant. Het heeft een uitgebreid menu van heerlijke gerechten, een uitstekende service en een geweldige sfeer. Het is een geweldige plek om te genieten van een heerlijke lunch of diner. Het is ook een ideale plek om te genieten van een heerlijke diner met vrienden of familie.</p>
#
# <p>Bella's Bistro is een geweldige keuze voor een restaurant. Het heeft een uitgebreid menu van heerlijke gerechten, een uitstekende service en een geweldige sfeer. Het is een geweldige plek om te genieten van een heerlijke lunch of diner. Het is ook een ideale plek om te genieten van een heerlijke diner met vrienden of familie.</p>
#
# <p>Bella's Bistro is een geweldige keuze voor een restaurant. Het heeft een uitgebreid menu van heerlijke gerechten,
#
#
# === Voorbeeld: 47 ======================================================================================
#
# ### Instructie:
# Construeer een bewijs van de volgende stelling:
#
# ### Invoer:
# Stelling: De som van twee oneven getallen is even.
#
# ### Antwoord:
#  </br>
# De som van twee oneven getallen is even.
#
#
# === Voorbeeld: 48 ======================================================================================
#
# ### Instructie:
# Gebruik de gegeven feiten om een samenvatting van de Zon te genereren.
#
# ### Invoer:
# Het is een ster die zich bevindt in het centrum van ons zonnestelsel, hoofdzakelijk samengesteld uit waterstof en helium, heeft een diameter van 865.000 mijl en een oppervlaktetemperatuur van 10.000 graden Fahrenheit.
#
# ### Antwoord:
#  </br>
# De Zon is een ster die zich bevindt in het centrum van het zonnestelsel. Het heeft een diameter van 865.000 mijl en een oppervlaktetemperatuur van 10.000 graden Fahrenheit.
#
#
# === Voorbeeld: 49 ======================================================================================
#
# ### Instructie:
# Maak een overzicht voor een presentatie over de rol van sociale media in de moderne samenleving.
#
# ### Antwoord:
#  </p>
#
# <p>Dit overzicht is gemaakt voor een presentatie over de rol van sociale media in de moderne samenleving. Het is gemaakt om de belangrijkste punten te benadrukken en het publiek te laten begrijpen hoe sociale media de manier waarop mensen met elkaar omgaan, communiceren en informeren heeft veranderd.</p>
#
# <p>Dit overzicht begint met een introductie van sociale media en de impact die het heeft gehad op de samenleving. Het gaat vervolgens over de verschillende soorten sociale media en hun functies, zoals het bieden van verbondenheid, communicatie en informatie. Het gaat vervolgens naar de impact van sociale media op de manier waarop mensen met elkaar omgaan, communiceren en informeren. Het eindigt met een samenvatting van de belangrijkste punten.</p>
#
# <p>Dit overzicht is gemaakt om de belangrijkste punten te benadrukken en de impact van sociale media op de moderne samenleving te laten zien.</p>
#
#
# === Voorbeeld: 50 ======================================================================================
#
# ### Instructie:
# Maak een haiku-gedicht met behulp van de gegeven woorden.
#
# ### Invoer:
# Wind, Wolken, Hemel
#
# ### Antwoord:
#  </p>
#
# <p>De wind blaast door de wolken,<br>
# Het geluid van de hemel<br>
# Een zachte zoete bries.</p>
#
# <p>De zachte zoete bries,<br>
# Het geluid van de hemel<br>
# Een zachte zoete bries.</p>
