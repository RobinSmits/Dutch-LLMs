# %% [markdown]
# <a href="https://colab.research.google.com/github/RobinSmits/Dutch-LLMs/blob/main/Open_Llama_7B_Alpaca_Clean_Dutch_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
import os
from google.colab import drive
drive.mount('/content/drive')

# Set Google Drive Folder to use...Copy Val_Data folder from Github into it to be able to reproduce the results.
WORK_DIR = '/content/drive/My Drive/LLM/OpenLlama7BAlpacaCleanDutchQlora/'
os.makedirs(WORK_DIR, exist_ok = True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Install required packages
# !pip install -q accelerate
# !pip install -q sentencepiece
# !pip install -q bitsandbytes
# !pip install -q transformers
# !pip install -q peft
# !pip install -q datasets

# %%
# Import Modules
from datasets import load_dataset, load_from_disk
import torch
from peft import AutoPeftModelForCausalLM
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
# Set Model Name Constant
model_name = "robinsmits/open_llama_7b_alpaca_clean_dutch_qlora"

# %%
# Create Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name,
                                          use_fast = False,
                                          legacy = False,
                                          add_eos_token = True)
tokenizer.pad_token_id = 0

# Max Length
MAX_LEN = 512

# Tokenizer Summary
print(tokenizer)

# Special Tokens
print(f'pad_token_id: {tokenizer.pad_token_id}')
print(f'bos_token_id: {tokenizer.bos_token_id}')
print(f'eos_token_id: {tokenizer.eos_token_id}')
print(f'pad_token_id: {tokenizer.decode(tokenizer.pad_token_id)}')
print(f'bos_token_id: {tokenizer.decode(tokenizer.bos_token_id)}')
print(f'eos_token_id: {tokenizer.decode(tokenizer.eos_token_id)}')
# Out:
# LlamaTokenizer(name_or_path='robinsmits/open_llama_7b_alpaca_clean_dutch_qlora', vocab_size=32000, model_max_length=2048, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'bos_token': AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'eos_token': AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'unk_token': AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'pad_token': '<unk>'}, clean_up_tokenization_spaces=False)
# pad_token_id: 0
# bos_token_id: 1
# eos_token_id: 2
# pad_token_id: <unk>
# bos_token_id: <s>
# eos_token_id: </s>

# %%
# Create Model
model = AutoPeftModelForCausalLM.from_pretrained(model_name,
                                                 device_map = "auto",
                                                 load_in_4bit = True,
                                                 torch_dtype = torch.bfloat16)

# Summary
print(model)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(32000, 4096, padding_idx=0)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): Linear4bit(
#                 in_features=4096, out_features=4096, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#               (v_proj): Linear4bit(
#                 in_features=4096, out_features=4096, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#               (down_proj): Linear4bit(in_features=11008, out_features=4096, bias=False)
#               (act_fn): SiLUActivation()
#             )
#             (input_layernorm): LlamaRMSNorm()
#             (post_attention_layernorm): LlamaRMSNorm()
#           )
#         )
#         (norm): LlamaRMSNorm()
#       )
#       (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
#     )
#   )
# )

# %% [markdown]
# I'am using the same validation set as during training of the notebook.
#
# This allows for some further analysis in this Inference notebook without data leakage.
#
# The required train and validation files are stored in my github account. Notice that the original code to generate the train and validation dataset is in the commented out section.

# %%
"""
# Alpaca Translated
datasets = load_dataset('BramVanroy/alpaca-cleaned-dutch')

# Summary
print(datasets)

# Validation size
VAL_SIZE = 2048

# Split in Train and Val datasets
dataset_split = datasets["train"].train_test_split(test_size = VAL_SIZE,
                                                   shuffle = True,
                                                   seed = 42)

# Train and Val datasets
train_data = dataset_split["train"]
val_data = dataset_split["test"]

# Save for later use
val_data.save_to_disk(f'{WORK_DIR}val_data')
train_data.save_to_disk(f'{WORK_DIR}train_data')
"""

# Load Validation set from earlier training run...use code above to generate new train and val datasets if required
val_data = load_from_disk(f'{WORK_DIR}val_data')

# %%
def generate_eval_prompt(item):
    if item["input"]:
        return f"""
### Instructie:
{item["instruction"]}

### Invoer:
{item["input"]}

### Antwoord:"""
    else:
        return f"""
### Instructie:
{item["instruction"]}

### Antwoord:"""

# %%
def generate(instruction, input = None):
    # Generate Prompt
    prompt = generate_eval_prompt({'instruction': instruction, 'input': input})

    # Tokenize
    input_ids = tokenizer(prompt, return_tensors = "pt", truncation = True).input_ids.cuda()

    # Generate output
    outputs = model.generate(input_ids = input_ids,
                             max_new_tokens = MAX_LEN,
                             num_beams = 2,
                             early_stopping = True,
                             forced_eos_token_id = tokenizer.eos_token_id)

    # Decode output
    generated_output = tokenizer.decode(outputs[0], skip_special_tokens = True)

    # Print prompt and answer extracted from generated output
    print(prompt)
    if prompt in generated_output:
        answer = generated_output.split(prompt)[1]
        print(answer)
    else:
        print('<< NO ANSWER GENERATED >>')

# Validation Loop
for index, item in enumerate(val_data):
    print(f'\n\n=== Voorbeeld: {index} ======================================================================================')
    generate(item['instruction'], item['input'])

    if index > 50:
        break
# Out:
# === Voorbeeld: 0 ======================================================================================
#
# ### Instructie:
# Wat zijn de drie belangrijkste softwareonderdelen die worden gebruikt bij webontwikkeling?
#
# ### Antwoord:
#  </br>
# De drie belangrijkste softwareonderdelen die worden gebruikt bij webontwikkeling zijn HTML, CSS en JavaScript. HTML (HyperText Markup Language) wordt gebruikt om tekst, afbeeldingen en links te creëren. CSS (Cascading Style Sheets) wordt gebruikt om tekst, afbeeldingen en lay-outs te veranderen. JavaScript wordt gebruikt om interactieve websites te creëren.
#
#
# === Voorbeeld: 1 ======================================================================================
#
# ### Instructie:
# Genereer een wachtwoord dat aan de volgende eisen voldoet: minimaal 8 tekens, één hoofdletter, één kleine letter, één cijfer en één speciaal teken.
#
# ### Antwoord:
#  </br>
# <b>...
#
#
# === Voorbeeld: 2 ======================================================================================
#
# ### Instructie:
# Stel vijf activiteiten voor om zelfzorg te bevorderen
#
# ### Antwoord:
#  </p>
# 1. Maak een wandeling in de natuur.
# 2. Maak een picknick in de park.
# 3. Maak een wandeling in de stad.
# 4. Maak een picknick in de tuin.
# 5. Maak een wandeling in de haven.
#
#
# === Voorbeeld: 3 ======================================================================================
#
# ### Instructie:
# Ontdek of een zin sarcastisch is.
#
# ### Invoer:
# Dat is geweldig nieuws.
#
# ### Antwoord:
#  </span>Ja, deze zin is sarcastisch.
#
#
# === Voorbeeld: 4 ======================================================================================
#
# ### Instructie:
# Gegeven een kort stukje tekst, verwijder alle bijwoorden en vervang ze door meer passende woorden.
#
# ### Invoer:
# Hij rende snel naar de winkel om wat eten te kopen.
#
# ### Antwoord:
#  </span>
# Hij rende snel naar de winkel om wat eten te kopen.
#
#
# === Voorbeeld: 5 ======================================================================================
#
# ### Instructie:
# Geef twee voorbeelden van activiteiten die fysieke kracht vereisen.
#
# ### Antwoord:
#  </p>
# Twee voorbeelden van activiteiten die fysieke kracht vereisen, zijn het bewegen van een lichtgewicht lichaam en het bewegen van een lichtgewicht lichaam. Het bewegen van een lichtgewicht lichaam vereist meer fysieke kracht dan het bewegen van een lichtgewicht lichaam.
#
#
# === Voorbeeld: 6 ======================================================================================
#
# ### Instructie:
# Vind de vergelijking van de lijn die door het gegeven punt gaat en parallel is aan de gegeven vector.
#
# ### Invoer:
# Punt: (2, 1), Vector: (−2, 1)
#
# ### Antwoord:
#  </br>
# De vergelijking van de lijn die door het punt (2, 1) gaat en parallel is aan de vector (−2, 1) is y = 2x + 1.
#
#
# === Voorbeeld: 7 ======================================================================================
#
# ### Instructie:
# Gegeven een zin en een lijst met bijwoorden, pas de zin aan met behulp van de bijwoorden.
#
# ### Invoer:
# Hij liep langzaam
# Bijwoorden: met tegenzin, aarzelend
#
# ### Antwoord:
#  </br> Hij liep langzaam met tegenzin.
#
#
# === Voorbeeld: 8 ======================================================================================
#
# ### Instructie:
# Identificeer alle componenten van een gegeven wetenschappelijke term.
#
# ### Invoer:
# Fotosynthese
#
# ### Antwoord:
#  </span>
# Fotosynthese is het proces waarbij licht wordt gebruikt om koolstofdioxide en waterstofionen om te zetten in suiker en zuurstof. Het wordt uitgevoerd door planten en andere organismen die zijn aangepast om de energie van licht om te zetten in energie die kan worden gebruikt.
#
#
# === Voorbeeld: 9 ======================================================================================
#
# ### Instructie:
# Beschrijf de verschillen tussen een asynchrone en synchrone webapplicatie.
#
# ### Antwoord:
#  </br>
# Een asynchrone webapplicatie is een webapplicatie die communiceert met een server via een HTTP-verzoek en een HTTP-antwoord. Deze communicatie wordt gebruikt om gegevens te verzenden en te ontvangen. Een synchrone webapplicatie is een webapplicatie die communiceert met een server via een HTTP-verzoek en een HTTP-antwoord, maar de gegevens die worden verzonden en ontvangen, worden verzonden en ontvangen in real-time.
#
# Een asynchrone webapplicatie kan worden gebruikt om gegevens te verzenden en te ontvangen, terwijl een synchrone webapplicatie kan worden gebruikt om real-time gegevens te verzenden en te ontvangen.
#
#
# === Voorbeeld: 10 ======================================================================================
#
# ### Instructie:
# Classificeer deze zin als een gebiedende wijs of een vraag.
#
# ### Invoer:
# Deze salade smaakt heerlijk.
#
# ### Antwoord:
#  </br> Gebiedende wijs
#
#
# === Voorbeeld: 11 ======================================================================================
#
# ### Instructie:
# Onderzoek en maak een lijst van de gezondheidsvoordelen van het eten van appels.
#
# ### Antwoord:
#  </br>
# Appels zijn een geweldige bron van vitamines en mineralen. Ze bevatten vitamine C, vitamine A, vitamine K, vitamine B1, vitamine B2, vitamine B3, vitamine B5, vitamine B6, vitamine B7, vitamine B9, vitamine B12 en vitamine K2. Appels bevatten ook mineralen zoals kalium, magnesium, manganese, niacin, phosphorus, potassium, riboflavin, selenium en thiamin. Appels zijn ook een geweldige bron van antioxidanten, die helpen bij het verminderen van het risico op hartziekten en andere chronische ziekten.
#
#
# === Voorbeeld: 12 ======================================================================================
#
# ### Instructie:
# Geef een voorbeeld van een technologie die probabilistisch denken gebruikt.
#
# ### Antwoord:
#  </p>
# Een voorbeeld van een technologie die probabilistisch denken gebruikt, is Machine Learning. Machine Learning is een vakgebied van de informatica dat gebruik maakt van algoritmen om computers te laten leren van data en patronen te identificeren. Deze algoritmen worden gebruikt om computers te laten leren van data en patronen te identificeren.
#
#
# === Voorbeeld: 13 ======================================================================================
#
# ### Instructie:
# Wat zijn de drie kenmerken van een goed argument?
#
# ### Antwoord:
#  </p>
# De drie kenmerken van een goed argument zijn duidelijkheid, betrouwbaarheid en effectiviteit. Duidelijkheid betekent dat het argument duidelijk is en begrijpelijk is voor de menselijke geest. Betrouwbaarheid betekent dat het argument waar is en dat het correct is. Effectiviteit betekent dat het argument effectief is om te communiceren en te onderhandelen.
#
#
# === Voorbeeld: 14 ======================================================================================
#
# ### Instructie:
# De functie f heeft de eigenschap dat voor elke reëel getal x in zijn domein, 1/x ook in zijn domein is en f(x) + f(1/x) = x.
# Wat is de grootste verzameling van reële getallen die in het domein van f kan zijn?
#
# (a) {x| x0}
#
# (b) {x| x<0}
#
# (c) {x| x>0}
#
# (d) {x| x-1 en x0 en x1}
#
# (e) {-1,1}
#
# ### Antwoord:
#
#
#
# === Voorbeeld: 15 ======================================================================================
#
# ### Instructie:
# Combineer de 2 passages en creëer een nieuw verhaal
#
# ### Invoer:
# Passage 1: Sarah liep naar huis van school toen ze een hard getik in de buurt hoorde.
#
# Passage 2: Ze keek op om een hoge boom te zien met een grote vogel erop, die zijn vleugels in de wind sloeg.
#
# ### Antwoord:
#  </br> Sarah liep naar huis van school toen ze een hard getik in de buurt hoorde. Ze keek op om een hoge boom te zien met een grote vogel erop, die zijn vleugels in de wind sloeg.
#
#
# === Voorbeeld: 16 ======================================================================================
#
# ### Instructie:
# Wat gebeurt er als we 100 ml water mengen met 30 ml azijn?
#
# ### Antwoord:
#  </br>
# Het mengen van 100 ml water met 30 ml azijn resulteert in een totale volume van 130 ml.
#
#
# === Voorbeeld: 17 ======================================================================================
#
# ### Instructie:
# Waar of niet waar, zelfrijdende auto's zijn haalbaar voor snelwegen.
#
# ### Antwoord:
#  </p>
# Waar of niet waar, zelfrijdende auto's zijn haalbaar voor snelwegen.
#
#
# === Voorbeeld: 18 ======================================================================================
#
# ### Instructie:
# Identificeer het hoofdidee van de tekst.
#
# ### Invoer:
# Global warming is de term die wordt gebruikt om een geleidelijke toename van de gemiddelde temperatuur van de atmosfeer en oceanen van de aarde te beschrijven, een verandering die wordt geloofd permanent de klimaat van de aarde te veranderen.
#
# ### Antwoord:
#  </br>
# Het hoofdidee van de tekst is dat de gemiddelde temperatuur van de atmosfeer en oceanen van de aarde wordt gevormd door de toename van de uitstoot van broeikasgassen.
#
#
# === Voorbeeld: 19 ======================================================================================
#
# ### Instructie:
# Noem drie elementen van cyberbeveiliging.
#
# ### Antwoord:
#  </p>
# De drie belangrijkste elementen van cyberbeveiliging zijn:
# 1. Wachtwoordbeheersysteem (WBS): een systeem dat wordt gebruikt om wachtwoorden en andere veiligheidsinformatie te beheren.
# 2. Firewall: een systeem dat wordt gebruikt om de toegang van andere computers of netwerken tot een computer of netwerk te beperken.
# 3. Anti-virussoftware: software die wordt gebruikt om bestanden en andere bronnen te detecteren die kunnen worden gebruikt om een computer te infecteren.
#
#
# === Voorbeeld: 20 ======================================================================================
#
# ### Instructie:
# Gegeven een lijst van wapens en een personage, genereer een verhaal met het personage dat een van de wapens uit de lijst gebruikt.
#
# ### Invoer:
# Personage: Larry
# Wapens: knots, zwaard, boog en pijl
#
# ### Antwoord:
#  </p>
# Larry was een dappere soldaat die in de strijd was geweest. Hij had een knots, een zwaard, een boog en een pijl gekocht. Hij had deze wapens gekocht om te vechten tegen de vijand. Hij had deze wapens gekocht om te vechten tegen de vijand. Hij had deze wapens gekocht om te vechten tegen de vijand.
#
#
# === Voorbeeld: 21 ======================================================================================
#
# ### Instructie:
# Maak een boekomslag voor een fictieve roman.
#
# ### Invoer:
# Genre: Fantasy
#
# ### Antwoord:
#  </br>
# Een boekomslag voor een fictieve roman.
#
# Een boekomslag voor een fictieve roman.
#
# Een boekomslag voor een fictieve roman.
#
# Een boekomslag voor een fictieve roman.
#
# Een boekomslag voor een fictieve roman.
#
# Een boekomslag voor een fictieve roman.
#
# Een boekomslag voor een fictieve roman.
#
# Een boekomslag voor een fictieve roman.
#
# Een boekomslag voor een fictieve roman.
#
#
# === Voorbeeld: 22 ======================================================================================
#
# ### Instructie:
# Maak een voorbeeld van het soort vragen dat een GPT-model kan beantwoorden.
#
# ### Antwoord:
#  </br>
# Wat is de hoofdstad van Frankrijk?
#
#
# === Voorbeeld: 23 ======================================================================================
#
# ### Instructie:
# Genereer een zin die een vergelijking demonstreert.
#
# ### Antwoord:
#  </br> Ik ben zo blij om te zien dat jouw nieuwste foto's goed zijn!
#
#
# === Voorbeeld: 24 ======================================================================================
#
# ### Instructie:
# Classificeer de gegeven zin als een metafoor of een vergelijking.
#
# ### Invoer:
# De kamer was een oven.
#
# ### Antwoord:
#  DT
#
#
# === Voorbeeld: 25 ======================================================================================
#
# ### Instructie:
# Herschrijf de zin "Hij rent" in de tegenwoordige progressieve tijd.
#
# ### Antwoord:
#  </br>Hij rent.
#
#
# === Voorbeeld: 26 ======================================================================================
#
# ### Instructie:
# Stel een nieuwe rebrandingstrategie voor aan het volgende bedrijf.
#
# ### Invoer:
# Bedrijf: ABC Technologies
#
# ### Antwoord:
#  </br>
# ABC Technologies is een gespecialiseerde technologiebedrijf dat zich richt op het ontwikkelen van innovatieve oplossingen voor bedrijven die zich bezighouden met kunstmatige intelligentie en machine learning. De bedrijfstrategie moet worden geïnformeerd door de nieuwe technologieën die worden ontwikkeld, de nieuwe markten die worden bereikt en de nieuwe mogelijkheden die worden geboden door de nieuwe technologieën. De bedrijfstrategie moet ook worden geïnformeerd door de nieuwe markten die worden bereikt, de nieuwe mogelijkheden die worden geboden door de nieuwe technologieën en de nieuwe technologieën die worden ontwikkeld.
#
#
# === Voorbeeld: 27 ======================================================================================
#
# ### Instructie:
# Identificeer het woordsoort voor het gegeven woord.
#
# ### Invoer:
# Lachen
#
# ### Antwoord:
#  DT
#
#
# === Voorbeeld: 28 ======================================================================================
#
# ### Instructie:
# Hoe zou je kunstmatige intelligentie uitleggen aan een leerling in groep 6?
#
# ### Antwoord:
#  </br>
# Kunstmatige intelligentie (AI) is een gebied van de informatica dat zich richt op het creëren van intelligente machines die kunnen denken, handelen en reageren zoals mensen. AI-technologieën worden gebruikt om machines te maken die kunnen leren en zelfstandig kunnen oplossingen vinden voor complexe problemen. AI-technologieën omvatten machine learning, natural language processing en robotica. AI-technologieën worden gebruikt in verschillende industrieën, zoals gezondheidszorg, financiën en transport.
#
#
# === Voorbeeld: 29 ======================================================================================
#
# ### Instructie:
# Noem vijf aspecten van een data science proces
#
# ### Antwoord:
#  </p>
# 1. Data-Ontwikkeling
# 2. Data-Analyse
# 3. Model-Ontwikkeling
# 4. Model-Testing
# 5. Model-Implementatie
#
#
# === Voorbeeld: 30 ======================================================================================
#
# ### Instructie:
# Vertaal het woord "person" van Engels naar Spaans.
#
# ### Antwoord:
#  </p>
# </p>
# </p>
# </p>
# </p>
# </p>
#
#
# === Voorbeeld: 31 ======================================================================================
#
# ### Instructie:
# Categoriseer het gegeven object in een passende categorie.
#
# ### Invoer:
# Kaas
#
# ### Antwoord:
#  </br>
# Kaas is een voedselproduct dat bestaat uit een mengsel van vlees, vleesvriendelijke ingrediënten en zout. Het wordt vaak gebruikt als snack of als ingrediënt in gerechten. Kaas wordt gemaakt van verschillende soorten vlees, zoals schaapsvlees, konijnenvlees, varkensvlees, schaapsvlees en andere soorten vlees.
#
#
# === Voorbeeld: 32 ======================================================================================
#
# ### Instructie:
# Converteer 179 centimeter naar voet.
#
# ### Invoer:
# 179 centimeter
#
# ### Antwoord:
#  </span>
# 179 centimeter is gelijk aan 5'10".
#
#
# === Voorbeeld: 33 ======================================================================================
#
# ### Instructie:
# Noem 4 methoden om cyberaanvallen te voorkomen.
#
# ### Antwoord:
#  </p>
# 1. Verwachte regelmatig je wachtwoorden.
# 2. Gebruik tweefactorauthenticatie om je account te beschermen tegen ongeautoriseerde toegang.
# 3. Verwachte regelmatig je e-mailadressen.
# 4. Gebruik tweefactorauthenticatie om je account te beschermen tegen ongeautoriseerde toegang.
#
#
# === Voorbeeld: 34 ======================================================================================
#
# ### Instructie:
# Reverse engineer de volgende algoritme en leg zijn functie uit in één zin.
#
# ### Invoer:
# def sorteer_getallen(arr):
#     for i in range(len(arr)):
#         for j in range(i):
#             if arr[i] < arr[j]:
#                 arr[i], arr[j] = arr[j], arr[i]
#     return arr
#
# ### Antwoord:
# << NO ANSWER GENERATED >>
#
#
# === Voorbeeld: 35 ======================================================================================
#
# ### Instructie:
# Bewerk deze code om de output "Hello, World!" te maken
#
# ### Invoer:
# console.log("Hi, World!");
#
# ### Antwoord:
#  </code>
# console.log("Hello, World!");
#
#
# === Voorbeeld: 36 ======================================================================================
#
# ### Instructie:
# Maak een zin in de derde persoonsperspectief.
#
# ### Antwoord:
#  </br> Ik ben zo blij dat ik deze nieuwe uitdaging heb gekregen.
#
#
# === Voorbeeld: 37 ======================================================================================
#
# ### Instructie:
# Doe een voorstel om de beschikbaarheid van wapens in de samenleving te verminderen.
#
# ### Antwoord:
#  </br>
# Een manier om de beschikbaarheid van wapens in de samenleving te verminderen is door te investeren in het creëren van een betrouwbare en effectieve beveiligingssysteem. Dit systeem moet in staat zijn om wapens te detecteren en te blokkeren wanneer ze worden gedetecteerd of gebruikt. Dit systeem moet ook in staat zijn om wapens te blokkeren wanneer ze worden gedetecteerd of gebruikt. Het systeem moet ook in staat zijn om wapens te blokkeren wanneer ze worden gedetecteerd of gebruikt. Het systeem moet ook in staat zijn om wapens te blokkeren wanneer ze worden gedetecteerd of gebruikt.
#
#
# === Voorbeeld: 38 ======================================================================================
#
# ### Instructie:
# Beoordeel de volgende producten op een schaal van 1-10 (1 = Niet goed, 10 = Zeer goed)
#
# ### Invoer:
# iPad Pro, Laptop, Desktop
#
# ### Antwoord:
#  </br>
# iPad Pro: 8
# Laptop: 9
# Desktop: 10
#
#
# === Voorbeeld: 39 ======================================================================================
#
# ### Instructie:
# Noem een beroemde astronaut.
#
# ### Antwoord:
#  </br> Buzz Aldrin
#
#
# === Voorbeeld: 40 ======================================================================================
#
# ### Instructie:
# Schrijf een e-mail naar de manager waarin je vraagt om een wijziging in de vergadertijd.
#
# ### Invoer:
# Er staat een vergadering gepland op dinsdag om 11 uur 's ochtends en twee teamleden kunnen hier niet bij zijn vanwege een conflict in hun werkuren.
#
# ### Antwoord:
#  </p>
#
# <p>Beste Manager, </p>
#
# <p>Ik schrijf u om een wijziging in de vergadertijd te vragen. Ik heb een vergadering gepland op dinsdag om 11 uur 's ochtends en twee teamleden kunnen hier niet bij zijn vanwege een conflict in hun werkuren. Ik zou graag een wijziging in de vergadertijd willen vragen, omdat ik moeite heb met deze vergadering. </p>
#
# <p>Ik zou graag uw hulp willen vragen om deze vergadering te laten veranderen. </p>
#
# <p>Beste Manager, </p>
#
# <p>Ik heb een vergadering gepland op dinsdag om 11 uur 's ochtends en twee teamleden kunnen hier niet bij zijn vanwege een conflict in hun werkuren. Ik zou graag een wijziging in de vergadertijd willen vragen, omdat ik moeite heb met deze vergadering. </p>
#
# <p>Ik zou graag uw hulp willen vragen om deze vergadering te laten veranderen. </p>
#
#
# === Voorbeeld: 41 ======================================================================================
#
# ### Instructie:
# Hoe voelt de protagonist zich tegen het einde van het boek?
#
# ### Invoer:
# Josh heeft moeite om betekenis te geven aan wat zijn leven is geworden. Hij heeft veel van zijn oude vrienden verloren en zijn toekomst is onzeker.
#
# ### Antwoord:
#  </span>
# De protagonist van het boek heeft moeite om betekenis te geven aan wat zijn leven is geworden. Hij heeft veel van zijn oude vrienden verloren en zijn toekomst is onzeker.
#
#
# === Voorbeeld: 42 ======================================================================================
#
# ### Instructie:
# Gebruik de tegenwoordige tijd om de volgende instructies uit te leggen
#
# ### Invoer:
# Bouw een huis
#
# ### Antwoord:
#  </br>
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw een huis
#
# Bouw
#
#
# === Voorbeeld: 43 ======================================================================================
#
# ### Instructie:
# Maak drie vragen die gerelateerd zijn aan de verspreiding van virussen.
#
# ### Antwoord:
#  </br>
# 1. Wat zijn de belangrijkste factoren die bijdragen aan de verspreiding van virussen?
# 2. Wat zijn de belangrijkste stappen om te nemen om de verspreiding van virussen te voorkomen?
# 3. Wat zijn de belangrijkste strategieën om de verspreiding van virussen te verminderen?
#
#
# === Voorbeeld: 44 ======================================================================================
#
# ### Instructie:
# Genereer een social media bericht over een nieuwe functie van jouw product.
# Maximaal 140 tekens
#
# ### Invoer:
# SMS notificaties voor klanten
#
# ### Antwoord:
#  </span>
# <span style="font-size: 14pt; font-family: Arial, Helvetica, sans-serif; color: #000000; background-color: #FFFFFF; text-align: center;">
# <span style="font-size: 14pt; font-family: Arial, Helvetica, sans-serif; color: #000000; background-color: #FFFFFF; text-align: center;">
# <span style="font-size: 14pt; font-family: Arial, Helvetica, sans-serif; color: #000000; background-color: #FFFFFF; text-align: center;">
# <span style="font-size: 14pt; font-family: Arial, Helvetica, sans-serif; color: #000000; background-color: #FFFFFF; text-align: center;">
# <span style="font-size: 14pt; font-family: Arial, Helvetica, sans-serif; color: #000000; background-color: #FFFFFF; text-align: center;">
# <span style="font-size: 14pt; font-family: Arial, Helvetica, sans-serif; color: #000000; background-color: #FFFFFF; text-align: center;">
# <span style="font-size: 14pt; font-family: Arial, Helvetica, sans-serif; color: #000000; background-color: #FFFFFF; text-align: center;">
# <span style="font-size: 14pt; font-family: Arial, Helvetica, sans-serif; color: #000000; background-color: #FFFFFF; text-align: center;">
# <span style="font-size: 14pt; font-family: Arial, Helvetica, sans-serif; color: #000000; background-color: #FFFFFF; text-
#
#
# === Voorbeeld: 45 ======================================================================================
#
# ### Instructie:
# Maak een lijst van 3 veelvoorkomende interviewvragen.
#
# ### Antwoord:
#  </br>
# 1. Wat hebben jouw ervaringen bij het werken voor een bedrijf betreft?
# 2. Wat zijn de belangrijkste uitdagingen die je hebt overwogen bij het werken voor een bedrijf?
# 3. Wat zijn de belangrijkste uitdagingen die je hebt overwogen bij het werken voor een bedrijf?
#
#
# === Voorbeeld: 46 ======================================================================================
#
# ### Instructie:
# Genereer een voorbeeld van een bedrijfsplan voor een restaurant.
#
# ### Invoer:
# Restaurantnaam: Bella's Bistro
#
# ### Antwoord:
#  </br>
# Bella's Bistro is een restaurant gelegen in het centrum van de stad. Het heeft een uitgebreid menu met verschillende gerechten, drankjes en desserten. Het restaurant biedt een verscheidenheid aan gerechten en drankjes, zoals pasta's, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillgerechten, gegrilde vleesgerechten, grillge
#
#
# === Voorbeeld: 47 ======================================================================================
#
# ### Instructie:
# Construeer een bewijs van de volgende stelling:
#
# ### Invoer:
# Stelling: De som van twee oneven getallen is even.
#
# ### Antwoord:
#  </br>
# De som van twee oneven getallen is even.
#
#
# === Voorbeeld: 48 ======================================================================================
#
# ### Instructie:
# Gebruik de gegeven feiten om een samenvatting van de Zon te genereren.
#
# ### Invoer:
# Het is een ster die zich bevindt in het centrum van ons zonnestelsel, hoofdzakelijk samengesteld uit waterstof en helium, heeft een diameter van 865.000 mijl en een oppervlaktetemperatuur van 10.000 graden Fahrenheit.
#
# ### Antwoord:
#  </br>
# De zon is een ster die zich bevindt in het centrum van het zonnestelsel, hoofdzakelijk samengesteld uit waterstof en helium. Het heeft een diameter van 865.000 mijl en een oppervlaktetemperatuur van 10.000 graden Fahrenheit.
#
#
# === Voorbeeld: 49 ======================================================================================
#
# ### Instructie:
# Maak een overzicht voor een presentatie over de rol van sociale media in de moderne samenleving.
#
# ### Antwoord:
#  </p>
# <p>Dit overzicht is gemaakt voor een presentatie over de rol van sociale media in de moderne samenleving. Het is gemaakt met de doelstelling om te laten zien hoe sociale media de manier waarop mensen met elkaar omgaan heeft veranderd en hoe de manier waarop mensen met elkaar omgeven heeft veranderd.</p>
#
# <p>Dit overzicht begint met een overzicht van de verschillende soorten sociale media en hun impact op de moderne samenleving. Het gaat vervolgens over de verschillende soorten sociale media en hun impact op de manier waarop mensen met elkaar omgeven. Het gaat vervolgens naar hoe sociale media de manier waarop mensen met elkaar omgeven heeft veranderd en hoe de manier waarop mensen met elkaar omgeven heeft veranderd.</p>
#
# <p>Het eindigt met een samenvatting van hoe sociale media de manier waarop mensen met elkaar omgeven heeft veranderd en hoe de manier waarop mensen met elkaar omgeven heeft veranderd.</p>
#
#
# === Voorbeeld: 50 ======================================================================================
#
# ### Instructie:
# Maak een haiku-gedicht met behulp van de gegeven woorden.
#
# ### Invoer:
# Wind, Wolken, Hemel
#
# ### Antwoord:
#  </span>
# De wind blaasde de wolken
# Hoog boven de hemel
# De zon schijnend
#
#
# === Voorbeeld: 51 ======================================================================================
#
# ### Instructie:
# Noem de namen van de drie staten die grenzen aan Colorado.
#
# ### Antwoord:
#  </br>Colorado is grenzend aan Wyoming, Nebraska en New Mexico.
