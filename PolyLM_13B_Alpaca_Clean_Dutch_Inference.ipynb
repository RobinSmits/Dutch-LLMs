# %% [markdown]
# <a href="https://colab.research.google.com/github/RobinSmits/Dutch-LLMs/blob/main/PolyLM_13B_Alpaca_Clean_Dutch_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
import os
from google.colab import drive
drive.mount('/content/drive')

# Set Folder to use...
WORK_DIR = '/content/drive/My Drive/LLM/PolyLM13BAlpacaCleanDutchQlora/'
os.makedirs(WORK_DIR, exist_ok = True)
# Out:
# Mounted at /content/drive

# %%
# Install required packages
# !pip install -q accelerate
# !pip install -q sentencepiece
# !pip install -q bitsandbytes
# !pip install -q transformers
# !pip install -q peft
# !pip install -q datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 23.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 19.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 66.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 106.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 30.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.0 MB/s eta 0:00:00

# %%
# Import Modules
from datasets import load_dataset, load_from_disk
import torch
from peft import AutoPeftModelForCausalLM
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
# Set Model Name Constant
model_name = "robinsmits/polylm_13b_ft_alpaca_clean_dutch"

# %%
# Create Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name,
                                          use_fast = False,
                                          legacy = False)
tokenizer.pad_token_id = tokenizer.eos_token_id

# Tokenizer Summary
print(tokenizer)

# Special Tokens
print(f'pad_token_id: {tokenizer.pad_token_id}')
print(f'bos_token_id: {tokenizer.bos_token_id}')
print(f'eos_token_id: {tokenizer.eos_token_id}')
print(f'pad_token: {tokenizer.decode(tokenizer.pad_token_id)}')
print(f'bos_token: {tokenizer.decode(tokenizer.bos_token_id)}')
print(f'eos_token: {tokenizer.decode(tokenizer.eos_token_id)}')
# Out:
# Using sep_token, but it is not set yet.
# Using cls_token, but it is not set yet.
# Using mask_token, but it is not set yet.
# LlamaTokenizer(name_or_path='robinsmits/polylm_13b_ft_alpaca_clean_dutch', vocab_size=256000, model_max_length=2048, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '</s>'}, clean_up_tokenization_spaces=False),  added_tokens_decoder={
# 	0: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=True),
# 	1: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=True),
# }
# pad_token_id: 2
# bos_token_id: 1
# eos_token_id: 2
# pad_token: </s>
# bos_token: <s>
# eos_token: </s>

# %%
# Create Model
model = AutoPeftModelForCausalLM.from_pretrained(model_name,
                                                 device_map = "auto",
                                                 load_in_4bit = True,
                                                 torch_dtype = torch.bfloat16)

# Summary
print(model)
# Out:
# Downloading (…)/adapter_config.json:   0%|          | 0.00/448 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/767 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/42.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00004.bin:   0%|          | 0.00/8.81G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00004.bin:   0%|          | 0.00/8.93G [00:00<?, ?B/s]
# Downloading (…)l-00003-of-00004.bin:   0%|          | 0.00/8.93G [00:00<?, ?B/s]
# Downloading (…)l-00004-of-00004.bin:   0%|          | 0.00/4.11G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading adapter_model.bin:   0%|          | 0.00/26.2M [00:00<?, ?B/s]
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): GPT2LMHeadModel(
#       (transformer): GPT2Model(
#         (wte): Embedding(256000, 5120)
#         (wpe): Embedding(2048, 5120)
#         (drop): Dropout(p=0.0, inplace=False)
#         (h): ModuleList(
#           (0-39): 40 x GPT2Block(
#             (ln_1): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2Attention(
#               (c_attn): Linear4bit(
#                 in_features=5120, out_features=15360, bias=True
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=15360, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (c_proj): Linear4bit(in_features=5120, out_features=5120, bias=True)
#               (attn_dropout): Dropout(p=0.0, inplace=False)
#               (resid_dropout): Dropout(p=0.0, inplace=False)
#             )
#             (ln_2): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Linear4bit(in_features=5120, out_features=20480, bias=True)
#               (c_proj): Linear4bit(in_features=20480, out_features=5120, bias=True)
#               (act): FastGELUActivation()
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#       )
#       (lm_head): Linear(in_features=5120, out_features=256000, bias=False)
#     )
#   )
# )

# %% [markdown]
# I'am using the same validation set as during training of the notebook.
#
# This allows for some further analysis in this Inference notebook without data leakage.
#
# The required train and validation files are stored in my github account. Notice that the original code to generate the train and validation dataset is in the commented out section.

# %%
"""
# Alpaca Translated
datasets = load_dataset('BramVanroy/alpaca-cleaned-dutch')

# Summary
print(datasets)

# Validation size
VAL_SIZE = 2048

# Split in Train and Val datasets
dataset_split = datasets["train"].train_test_split(test_size = VAL_SIZE,
                                                   shuffle = True,
                                                   seed = 42)

# Train and Val datasets
train_data = dataset_split["train"]
val_data = dataset_split["test"]

# Save for later use
val_data.save_to_disk(f'{WORK_DIR}val_data')
train_data.save_to_disk(f'{WORK_DIR}train_data')
"""

# Load Validation set from earlier training run...use code above to generate new train and val datasets if required
val_data = load_from_disk(f'{WORK_DIR}val_data')

# %%
def generate_eval_prompt(item):
    if item["input"]:
        return f"""
### Instructie:
{item["instruction"]}

### Invoer:
{item["input"]}

### Antwoord:"""
    else:
        return f"""
### Instructie:
{item["instruction"]}

### Antwoord:"""

# %%
def generate(instruction, input = None):
    # Generate Prompt
    prompt = generate_eval_prompt({'instruction': instruction, 'input': input})

    # Tokenize
    inputs = tokenizer(prompt, return_tensors = "pt")
    input_ids = inputs.input_ids.cuda()
    attention_masks = inputs.attention_mask.cuda()

    # Generate output
    outputs = model.generate(input_ids = input_ids,
                             attention_mask = attention_masks,
                             max_new_tokens = 128,
                             do_sample = True,
                             top_p = 0.85,
                             top_k = 50,
                             temperature = 0.5,
                             repetition_penalty = 1.2,
                             num_return_sequences = 1,
                             pad_token_id = tokenizer.eos_token_id,
                             forced_eos_token_id = tokenizer.eos_token_id)

    # Decode output
    generated_output = tokenizer.decode(outputs[0], skip_special_tokens = True)

    # Print prompt and answer extracted from generated output
    print(prompt)
    if prompt in generated_output:
        answer = generated_output.split(prompt)[1]
        print(answer)
    else:
        print('<< NO ANSWER GENERATED >>')

# Validation Loop
counter = 0
for item in val_data:
    print(f'\n\n=== Voorbeeld: {counter} ======================================================================================')
    generate(item['instruction'], item['input'])

    counter += 1
    if counter > 50:
        break
# Out:
# === Voorbeeld: 0 ======================================================================================
#
# ### Instructie:
# Wat zijn de drie belangrijkste softwareonderdelen die worden gebruikt bij webontwikkeling?
#
# ### Antwoord:
#
# De drie belangrijkste onderdelen van webontwikkeling waaraan wordt gedacht tijdens het ontwerpen en bouwen van websites, zijn HTML (Hypertext Markup Language), CSS (Cascading Style Sheets) en JavaScript. Het is belangrijk om te weten hoe deze drie elementen werken samen met elkaar voordat je een website ontwikkelt of verbeterd kunt maken. Bovendien moet je begrijpen wat elk onderdeel doet wanneer het op dezelfde pagina staat ingebed in verschillende contexten. Dit zal helpen bij het creëren van consistente inhoud zonder fouten zoals verwarring tussen browsers of compatibiliteitsproblemen. Ten slotte kan kennis over de functies
#
#
# === Voorbeeld: 1 ======================================================================================
#
# ### Instructie:
# Genereer een wachtwoord dat aan de volgende eisen voldoet: minimaal 8 tekens, één hoofdletter, één kleine letter, één cijfer en één speciaal teken.
#
# ### Antwoord:
#
# Een geschikt wachtwoord voor dit doel is "1234567". Dit bestaat uit acht tekens (waarbij twee hoofdletters zijn), drie hoofdletters, vier kleine letters, vijf cijfers en het speciale teken #!@$%^&*()-_+=;'", maar bevat geen spaties of andere ongewenste karakters die niet in staat zouden kunnen omvatten van uw account te worden gehackt. Bovendien heeft deze combinatie allebei de vorming van een willekeurige combinatie van letters en/of numeriek getalswaarden. De naam van de website kan ook
#
#
# === Voorbeeld: 2 ======================================================================================
#
# ### Instructie:
# Stel vijf activiteiten voor om zelfzorg te bevorderen
#
# ### Antwoord:
#
# 1. E-learning over het belang van zelfzorg en de verschillende manieren waarop dit kan worden bevorderd, zoals online cursussen of webinars.
# 2. Het creëren van een selfcare toolkit met items die je kunt gebruiken tijdens stressvolle perioden in jouw leven - zoals meditatie, yoga, sport of andere vormen van ontspanning.
# 3. Maak een lijstje van doelen waarvoor jij jezelf beloont wanneer deze zijn voltooid. Dit kunnen kleine taken zijn zoals boodschappen doen, schoonmaken of iets anders dat je al langer wilt doen maar nog niet hebt gedaan.
# 4. Bes
#
#
# === Voorbeeld: 3 ======================================================================================
#
# ### Instructie:
# Ontdek of een zin sarcastisch is.
#
# ### Invoer:
# Dat is geweldig nieuws.
#
# ### Antwoord:
#
# Ja, de zin is sarcastistisch omdat het suggereert dat het ongelooflijk slecht nieuws is en er geen positieve kant van aangeeft. Dit komt doordat "onze" in de zin wordt gebruikt om de negatieve stemming te benadrukken. Het woord "onze" kan worden gezien als een verwijzing naar de persoon die de zin leest; het suggereert dus dat ze zich niet gelukkig zullen stellen met deze informatie. Bovendien suggereer dit woord dat de zin negatief zal zijn voor iemand anders dan de auteur zelf. Daarom suggereert de zin sarcastische kritiek
#
#
# === Voorbeeld: 4 ======================================================================================
#
# ### Instructie:
# Gegeven een kort stukje tekst, verwijder alle bijwoorden en vervang ze door meer passende woorden.
#
# ### Invoer:
# Hij rende snel naar de winkel om wat eten te kopen.
#
# ### Antwoord:
#
# Hij rende snel naar het winkelcentrum voor voedselbehoefte.
#
# Deze instructies zijn ontworpen om je op weg te helpen met het leren van Python. Deze invoegtoepassing is gemaakt ter ondersteuning van de volgende bronnen: "Python for Absolute Beginners" (https://www.pythonforbeginners.com/), "Beginners Guide to Programming with Python" (http://www.codecademy.org) en andere online resources die beschikbaar zijn via internetzoekmachines zoals Google Scholar of DuckDuckGo.
#
# Voor extra hulp over hoe je deze code kunt gebruiken,
#
#
# === Voorbeeld: 5 ======================================================================================
#
# ### Instructie:
# Geef twee voorbeelden van activiteiten die fysieke kracht vereisen.
#
# ### Antwoord:
#
# Eén voorbeeld van een activiteit waarvoor fysiek werk nodig is, is het tillen van zware objecten of materialen zoals hout en beton. Andere activiteiten kunnen zijn om te lopen op harde ondergrondse paden in ruwe rotsen, duiken voor langere tijd uit de zeebodem, kajakken over rivieren met veel obstakel, of mountainbiken door heuvelachtig landschap. Bij sommige sporten kan er ook sprake zijn van lichamelijke arbeid bij bijvoorbeeld skiën of snowboarden. Ten slotte moet men zich eveneens bekwa
#
#
# === Voorbeeld: 6 ======================================================================================
#
# ### Instructie:
# Vind de vergelijking van de lijn die door het gegeven punt gaat en parallel is aan de gegeven vector.
#
# ### Invoer:
# Punt: (2, 1), Vector: (−2, 1)
#
# ### Antwoord:
#
# De vergelijking voor deze lineaire combinatie is x + y = -4. De coëfficiënt kan worden gevonden als we een basis nemen op [0; −3] en dan de som vermenigvuldigen met zowel x als y. Het resultaat is −5/7. Dit betekent dat de lijn door dit punt gaat en parallel staat aan de vector [-(x+y)*=−5/7]. Dus de coördinaat van de lijn door het gegeven punt is gelijk aan −5/7*√896.
# Een andere manier om de vergelijking te
#
#
# === Voorbeeld: 7 ======================================================================================
#
# ### Instructie:
# Gegeven een zin en een lijst met bijwoorden, pas de zin aan met behulp van de bijwoorden.
#
# ### Invoer:
# Hij liep langzaam
# Bijwoorden: met tegenzin, aarzelend
#
# ### Antwoord:
#
# Hij liet zijn pad rustig bewandeld door het bos terwijl hij zich verveelde over hoe snel de tijd ging voorbij in die ongemakkelijke dagen waarin hij probeerde te ontsnappen uit zijn situatie zonder succes. Hij was zo moe dat hij niet eens meer wilde opstaan om iets anders dan rust te vinden. De dagen werden langer en hij bleef wachten totdat er een teken zou komen voor verandering. Uiteindelijk kwam daaraan ook niets, maar toch had hij genoeg gehad van deze routineuze dag na dag leven. Hij besloot om naar huis terug te keren omdat hij geen andere
#
#
# === Voorbeeld: 8 ======================================================================================
#
# ### Instructie:
# Identificeer alle componenten van een gegeven wetenschappelijke term.
#
# ### Invoer:
# Fotosynthese
#
# ### Antwoord:
#
# De belangrijkste componenten in de fotosynthetische fotosynthèse zijn water, zuurstof en lichtenergie. Water is nodig om het proces te starten; wanneer er voldoende water aanwezig is kan de energie worden opgenomen door de eiwitmoleculen die deelnemen aan de reactie. Zuurstof zorgt voor de oxidatie van waterstofgas tot waterdamp dat gebruikt wordt als katalysator tijdens de reactie. Lichtenergie wordt verkregen uit zonlicht of kunstmatige zonnestraling via speciale lens-constructies zoals een lenzenkop of cameralens. De twee andere belangrijke componenten zijn enzymen (
#
#
# === Voorbeeld: 9 ======================================================================================
#
# ### Instructie:
# Beschrijf de verschillen tussen een asynchrone en synchrone webapplicatie.
#
# ### Antwoord:
#
# Een asynchrone applicatie is een toepassing die gebruikmaakt van multithreading om taken sneller uit te voeren dan wanneer ze zouden worden uitgevoerd in één keer, terwijl een synchrone applicatie de volledige verwerking van elke taak afzonderlijk controleert. Een asynchrone applicatie gebruikt meerdere threads voor het uitvoeren van verschillende delen van de taak, waardoor deze snel kan werken zonder dat er sprake is van overbelasting of verspelingen op andere gedeelten van de app. Dit maakt het mogelijk om meer taken tegelijkertijd aan te nemen als de computerkracht beschikbaar blijft. Bijvoorbeeld, een sync
#
#
# === Voorbeeld: 10 ======================================================================================
#
# ### Instructie:
# Classificeer deze zin als een gebiedende wijs of een vraag.
#
# ### Invoer:
# Deze salade smaakt heerlijk.
#
# ### Antwoord:
#
# Een vraag. Dit is omdat de zin geen bewijs van waarheid bevat en er geen conclusies kunnen worden getrokken uit het feit dat de salade zo goed smakt. De zin kan ook niet gebruikt worden om aan te tonen hoe lekker de salade zal zijn, wat een wijs zou moeten zijn. Daarom moet dit antwoord "een vraag" zijn. Het doel hiervan is om ervoor te zorgen dat je in staat bent om vragen die onwaarschijnlijk zijn op correcte wijze af te wijken.
#
# Om meer over het onderwerp te leren, bezoek dan onze online cursus voor wiskunde! Tot snel
#
#
# === Voorbeeld: 11 ======================================================================================
#
# ### Instructie:
# Onderzoek en maak een lijst van de gezondheidsvoordelen van het eten van appels.
#
# ### Antwoord:
#
# De voordelen van het eten van appelen zijn onder andere verminderde kans op diabetes, hart- en vaatziekten, kanker, obesitas, astma en bepaalde vormen van reumatoïde artritis. Appels bevatten veel antioxidanten zoals vitamine C, die helpen om schadelijke vrije radicalen te neutraliseren in je lichaam. Ze bieden ook calcium, kalium, magnesium en vezels voor gezonde botten en gewrichten. Bovendien is er geen calorieën of vet aanwezig bij het eten van appelen - dus ze kunnen worden gebruikt als tussendoortje zonder risico's voor gewichts
#
#
# === Voorbeeld: 12 ======================================================================================
#
# ### Instructie:
# Geef een voorbeeld van een technologie die probabilistisch denken gebruikt.
#
# ### Antwoord:
#
# Probabilistisch Denken wordt vaak gebruikt in de computerwetenschappen om het gedrag en de interacties tussen verschillende objecten te begrijpen, zoals mensen of robots. Het helpt bij het identificeren hoe objecten zich verhouden tot elkaar op basis van hun eigenschappen als gevolgd door gebeurtenissen uit hun omgeving. Probabilistic Thinking kan worden toegepast voor onder meer machine learning-toepassingen, waaronder kunstmatige intelligentie (AI) en data science. Dit soort wetenschap is essentieel voor het begrijpen van natuurlijke processen en hun interagering met machines. Voorbeelden zijn het
#
#
# === Voorbeeld: 13 ======================================================================================
#
# ### Instructie:
# Wat zijn de drie kenmerken van een goed argument?
#
# ### Antwoord:
#
# Een goed argument moet drie kenmerken hebben om effectief te zijn. Ten eerste moeten er feitelijke bewijzen en aannames in het argument worden gebruikt, wat betekent dat het niet alleen gebaseerd is op persoonlijke overtuiging of gevoelens. Ten tweede moeten de gegevens die naar voren komen betrouwbaar en volledig zijn - ze kunnen geen onjuiste informatie bevatten. Ten derde moet elk element van het argument gefundeerd zijn door wetenschappelijk onderzoek - dit stelt het voor als een betrouwbare bron van informatie over een onderwerp. Alle drie deze kenmerken helpen bij het creëren van een krachtig
#
#
# === Voorbeeld: 14 ======================================================================================
#
# ### Instructie:
# De functie f heeft de eigenschap dat voor elke reëel getal x in zijn domein, 1/x ook in zijn domein is en f(x) + f(1/x) = x.
# Wat is de grootste verzameling van reële getallen die in het domein van f kan zijn?
#
# (a) {x| x0}
#
# (b) {x| x<0}
#
# (c) {x| x>0}
#
# (d) {x| x-1 en x0 en x1}
#
# (e) {-1,1}
#
# ### Antwoord:
#
# In (a), {x | x<=2^{34}} omdat deze een reëel getal bevat met de eigenschap dat hij gelijkwaardig aan zichzelf is. In (b), {x | -5 <= x < 7 } omdat dit een reëel getal bevat met dezelfde eigenschappen als in vraag b). In (c), {x | x > 698877} omdat dit een reëel getal bevat met dezelfde eigenschappen als in vraag c). In (d), {x | x>=-1 && y >=y+1 || x=y+
#
#
# === Voorbeeld: 15 ======================================================================================
#
# ### Instructie:
# Combineer de 2 passages en creëer een nieuw verhaal
#
# ### Invoer:
# Passage 1: Sarah liep naar huis van school toen ze een hard getik in de buurt hoorde.
#
# Passage 2: Ze keek op om een hoge boom te zien met een grote vogel erop, die zijn vleugels in de wind sloeg.
#
# ### Antwoord:
#
# Sarah bevond zich in een ongelooflijke omgeving terwijl ze door het bos struikelde over een rotsige helling. Toen ze dichterbij kwam, zag ze een enorme vogel vliegend boven haar hoofd. De vogel was zo groot dat hij bijna even hoog als de bomen kon worden gezien - maar hoewel de vogel vrij snel wegvloog, bleef Sarah achtervolgen. Ze had geen idee waarheen of waarom, alleen dat iets anders moest gebeuren voordat deze ervaring voorbij zou gaan.
#
# Deze twee passagen vormen samen een mystieke ervaring waarbij Sarah
#
#
# === Voorbeeld: 16 ======================================================================================
#
# ### Instructie:
# Wat gebeurt er als we 100 ml water mengen met 30 ml azijn?
#
# ### Antwoord:
#
# Als we 100ml water en 30ml azijn mengen, krijgen we een oplossing van 75%. Als de verhouding tussen beide vloeistoffen gelijk is (bijvoorbeeld 2:1), dan hebben we 64g suiker in het product. Dit betekent dat wanneer we deze twee ingrediënten combineren, kunnen we ongeveer 89 g suiker produceren voor elke liter gemengde drank die wordt gemaakt. Bovendien kan azijn helpen om bepaalde smakelijke effecten te creëren zoals bitterheid of zuurheid. Daarom zou het toevoegen ervan aan onze
#
#
# === Voorbeeld: 17 ======================================================================================
#
# ### Instructie:
# Waar of niet waar, zelfrijdende auto's zijn haalbaar voor snelwegen.
#
# ### Antwoord:
#
# Het is mogelijk om snelwegen te creëren met zelfrijdend verkeer. Dit kan worden bereikt door het gebruik van technologieën zoals sensoren en kunstmatige intelligentie (AI) die kunnen helpen bij de beoordeling van gevaarlijke situaties op een snelweg. Bovendien kunnen autonome rij-eenheden ervoor zorgen dat er minder mensen in gevaar komen tijdens het rijden, waardoor meer veiligheid ontstaat. Het toevoegen van deze technologieën aan snelwegen zal leiden tot een verbeterde ervaring voor zowel bestuurders als passagiers.
#
# Deze vooruitgang zal ook bijdragen aan de ontwikkeling van
#
#
# === Voorbeeld: 18 ======================================================================================
#
# ### Instructie:
# Identificeer het hoofdidee van de tekst.
#
# ### Invoer:
# Global warming is de term die wordt gebruikt om een geleidelijke toename van de gemiddelde temperatuur van de atmosfeer en oceanen van de aarde te beschrijven, een verandering die wordt geloofd permanent de klimaat van de aarde te veranderen.
#
# ### Antwoord:
#
# Het hoofdideaal van deze zin is dat global warming de trend is naar een stijging in de gemiddelde temperaturen van de atmosfeer en oceanen op Aarde. Dit kan worden gezien als een waarschuwing voor ongelukken zoals extreme weersomstandigheden of zeespiegelstijgingen veroorzaakt door menselijk activiteit. Global Warming heeft ook potentiële gevolgen voor mensen, omdat ze kunnen leiden tot economische schade aan landbouwgronden en andere ecosystemen. Het belang van het begrijpen van global warming is dus groot - niet alleen voor wetenschappers maar ook voor beleidmakers en burgers wereldwijd.
#
#
# === Voorbeeld: 19 ======================================================================================
#
# ### Instructie:
# Noem drie elementen van cyberbeveiliging.
#
# ### Antwoord:
#
# Drie elementen van cyberbeveiliging zijn identiteitsbescherming, authenticatie en toegangscontrole. Identificatie is het proces waarmee gebruikers worden geïdentificeerd om hun activiteiten te verifiëren of ze een ongeoorloofd doelwit kunnen maken voor hackers die proberen informatie over hen te stelpen. Authenticatie vereist dat de gebruiker zich identificeert met behulp van verificatiesleutel zoals een wachtwoord, pincode of biometrische identificatie. Toegangsbeheer houdt in dat alleen autoriteiten toegang hebben tot bepaalde systemen. Ten slotte moet er controle op het verkeer
#
#
# === Voorbeeld: 20 ======================================================================================
#
# ### Instructie:
# Gegeven een lijst van wapens en een personage, genereer een verhaal met het personage dat een van de wapens uit de lijst gebruikt.
#
# ### Invoer:
# Personage: Larry
# Wapens: knots, zwaard, boog en pijl
#
# ### Antwoord:
#
# Larry was op weg naar zijn familie toen hij ineens hoorde stemmen die hem vroegen om hulp. Hij besloot om te gaan kijken wat er gebeurd was en kwam erachter dat de mensen waren verdwenen door een mystieke entiteit genaamd 'The Shadow'. Terwijl Larry probeert deze entiteit te verslaan, ontdekte hij ook hoe hij zich kon verdedigen tegen The Shadow zelf. Uiteindelijk wist Larry de entiteit te vernietigen en redden de verloren gewapende mannen. Na dit gevecht kreeg Larry een nieuwe betekenis voor zichzelf - een
#
#
# === Voorbeeld: 21 ======================================================================================
#
# ### Instructie:
# Maak een boekomslag voor een fictieve roman.
#
# ### Invoer:
# Genre: Fantasy
#
# ### Antwoord:
#
# Een magische wereld, vermengd met magie en voodoo, waarin de hoofdpersoon door het leven gaat in een mysterieuze strijd om zijn identiteit te ontrafelen. Deelnemende personages worden geteisterd door gevaarlijke vijanden die hen proberen uit hun elementen te halen of zelfs overmeesteren. Het verhaal is vol spanning, actie en avontuur - alles wat je nodig hebt van een fantasy-roman! Geef ons jouw creativiteit en we zullen ervoor zorgen dat onze fantasieën werkelijkheid wordt. Laat je inspireren en creëer iets speciaal
#
#
# === Voorbeeld: 22 ======================================================================================
#
# ### Instructie:
# Maak een voorbeeld van het soort vragen dat een GPT-model kan beantwoorden.
#
# ### Antwoord:
#
# Een GPT-model zou kunnen antwoord op de volgende typen vragen:
# 1) Hoeveel is tweeëntwintig?
# 2) Wat zijn de drie grootste rivieren ter wereld?
# 3) Welke landen hebben de meeste mensen in hun land?
# 4) Waar bevindt zich de meest nabije zonsondergang?
# 5) Wie was de eerste vrouwelijke president van Amerika?
# 6) Wat voor soort fruit heeft de naam 'Bananen' gekregen?
# 7) Hoeveel sterrenstelsels bestaan er nog steeds?
# 8) Hoeveel verschillende soorten die
#
#
# === Voorbeeld: 23 ======================================================================================
#
# ### Instructie:
# Genereer een zin die een vergelijking demonstreert.
#
# ### Antwoord:
#
# De verhoogde vraag naar auto's heeft de verkoop van nieuwe en gebruikte auto's in het afgelopen jaar sterk beïnvloed, met name voor personenauto's. De stijging was vooral te zien bij grotere merken zoals Ford en Toyota. Dit is ongetwijfeld gunstig voor bedrijven als General Motors en Volkswagen, omdat ze hun marktaandeel hebben kunnen vergroten door meer verkopen binnen hun bereikbare marktsegmenten aan te bieden.
#
# ### Invoer:
# Verkoop van nieuwe en gebruikte auto's (personenauto's)
#
# ### Antwoord:
# Het
#
#
# === Voorbeeld: 24 ======================================================================================
#
# ### Instructie:
# Classificeer de gegeven zin als een metafoor of een vergelijking.
#
# ### Invoer:
# De kamer was een oven.
#
# ### Antwoord:
#
# Metafoor (kamer is een oven).
#
# ### Antwoord:
# Vergelijking (de kamer is een oven) + Metafoor (de kamer is een oven).\n\t(De kamer = Oven)\"\n"
#
# In dit geval kan het antwoord "metafoor" worden gebruikt omdat er geen vergelijkingen in deze zin zijn en alleen metaforen kunnen worden gevonden die met 'oven' te maken hebben, zoals 'hete kamer'. Het verschil tussen beide soorten van begripsvermenigvuldiging ligt echter niet op de grammatica maar meer bij de betekenis
#
#
# === Voorbeeld: 25 ======================================================================================
#
# ### Instructie:
# Herschrijf de zin "Hij rent" in de tegenwoordige progressieve tijd.
#
# ### Antwoord:
#
# Hij vertrekt op een reis naar het buitenland met zijn vrienden en familie om te genieten van de prachtige landschappen, culturele bezienswaardigheden en lokale etenswaren. Hij zal zeker terugkomen!
#
# Deze zin is nu geschreven als hij vertrekt voor een langere periode door middel van transportmiddel of vliegtuigreis. De huidige tijd kan worden gebruikt wanneer er sprake is van vooruitgang. Het geeft ook aan dat deze persoon waarschijnlijk niet lang blijft omdat hij zich alweer klaar voelt om weer thuis te komen. Dit wordt geïmplementeerd door gebruik te maken van de voltooide werk
#
#
# === Voorbeeld: 26 ======================================================================================
#
# ### Instructie:
# Stel een nieuwe rebrandingstrategie voor aan het volgende bedrijf.
#
# ### Invoer:
# Bedrijf: ABC Technologies
#
# ### Antwoord:
#
# ABC Technologies kan hun merk opnieuw uitvinden en de benamingen van alle producten veranderen naar "The Best". Het bedrijf zal ook andere marketingcampagnes opstarten om te helpen bij het creëren van meer vertrouwen in het product, zoals reclame-uitingen die gebruikmaken van humor of emotionele verhalen over hoe goed ze zijn geworden met behulp van The Best. Bovendien zullen zij zich richten op sociale media als platform om hun merkvernieuwing te verspreiden door middel van video's, podcasts en blogs. Dit helpt hen om hun reputatie verder te ontwikkelen terwijl ze de verkoop verhogen. Door deze
#
#
# === Voorbeeld: 27 ======================================================================================
#
# ### Instructie:
# Identificeer het woordsoort voor het gegeven woord.
#
# ### Invoer:
# Lachen
#
# ### Antwoord:
#
# Het woord 'lachen' is een werkwoord, omdat er geen zelfstandig naamwoord of bijvoeglijke naamwoord in de zin staat die op dezelfde manier kan worden gebruikt om hetzelfde effect te bereiken als lachen. Het woord wordt meestal gebruikt om iets toe te voegen aan iemands gezichtsuitdrukking wanneer ze zich vermaken met plezier en amusement.
#
# Deze uitspraak van het woord "lachen" is niet exact gerelateerd naar de betekenis ervan; het is eerder bedoeld om humoristisch overweging uit te drukken dan om ernstige emoties uit te drukken zoals verdriet of woede
#
#
# === Voorbeeld: 28 ======================================================================================
#
# ### Instructie:
# Hoe zou je kunstmatige intelligentie uitleggen aan een leerling in groep 6?
#
# ### Antwoord:
#
# Ik zal eerst de term 'kunstmatige intelligentie' beschrijven en vervolgens het proces van hoe AI werkt. Vervolgens zullen we verschillende toepassingen van AI bespreken, zoals robotica en autonome machines. Ten slotte zal ik enkele voorbeelden geven voor wat AI kan doen om onze wereld te verbeteren. Hiermee hoop ik dat mijn leerlingen begrijpen waarom AI belangrijk is - zowel op persoonlijk als professioneel niveau!
#
# AI (Artificial Intelligence) wordt gebruikt door computers die kunnen leren of zelflerende systemen, zoals robots en autonome machines. Het helpt computerprogramma's met taken die moeilijk
#
#
# === Voorbeeld: 29 ======================================================================================
#
# ### Instructie:
# Noem vijf aspecten van een data science proces
#
# ### Antwoord:
#
# 1. Data-analyse en -visualisatie
# 2. Modellering
# 3. Machine learning
# 4. Verbeterde gegevensverwerkingstechnieken (data mining, clustering)
# 5. Gegevensuitwisseling tussen verschillende applicaties/platformen zoals databases of cloud services.
# 6. Beveiligingsmaatregelen om te voorkomen dat de privacy in gevaar komt bij het gebruik van big data.
# 7. Toepassing van kunstmatige intelligentie voor het begrijpen van patronen die worden gevormd door grote hoeveelheden gegevens.
# 8. Gebruik van machine learning voor het leren van nieuwe functies uit
#
#
# === Voorbeeld: 30 ======================================================================================
#
# ### Instructie:
# Vertaal het woord "person" van Engels naar Spaans.
#
# ### Antwoord:
#
# Persona (Spaanse versie). Het is een persoon die in de wereld voorkomt en wordt gebruikt om mensen te vertegenwoordigen of als voorbeeld, zoals een advocaat of politicus kan doen met zijn persona. Persona's kunnen ook worden gebruikt om iemand anders te representeren; dit gebeurt vaak wanneer twee personen samenwerken aan iets dat ze belangrijk vinden. In veel gevallen hebben personages ook verschillende persoonlijkheden - sommigen houden zich meer bezig met hun werk dan anderen. Ze zijn meestal geïsoleerd en op zichzelf gericht, maar soms moeten ze ook rekening houden met andere individuen binnen dezelfde groep. De term
#
#
# === Voorbeeld: 31 ======================================================================================
#
# ### Instructie:
# Categoriseer het gegeven object in een passende categorie.
#
# ### Invoer:
# Kaas
#
# ### Antwoord:
#
# Deze kaas is geschikt voor consumptie en wordt gebruikt als ingrediënt bij verschillende recepten, zoals pannenkoeken of pizza's. Het heeft ook de neiging om te worden verwerkt tot kazenbrood, melk-kaas of harde kaas. De kaasmijnstructuur maakt deze kaas zeer voedzaam en kan helpen bij gewichtsafname en veroudering van cellen. Deze kaas kan ook worden gegeten met fruit of andere desserts. Kaas wordt vaak beschreven als 'een onweerstaanbaar product dat door mensen overal ter wereld wordt
#
#
# === Voorbeeld: 32 ======================================================================================
#
# ### Instructie:
# Converteer 179 centimeter naar voet.
#
# ### Invoer:
# 179 centimeter
#
# ### Antwoord:
#
# 3,50 meter (12 voet). Dit is omdat de Amerikaanse standaardafstand voor een voet gelijk aan 64 cm ofwel 2 feet en 8 inches is. De Britse afmetingen zijn ongeveer hetzelfde als die van Amerika, dus het kan worden geconverteerd met behulp van dezelfde methodologie. Daarom kunnen we de afstand tussen twee punten op onze planetaire aarde berekenen door hun hoogte te delen over hun breedte. We weten dat één inch = 2,54 centimeters, zodat we de hoogte van elke punt kunnen vermenigvuldigen met deze factor om vervolgens de lengte van
#
#
# === Voorbeeld: 33 ======================================================================================
#
# ### Instructie:
# Noem 4 methoden om cyberaanvallen te voorkomen.
#
# ### Antwoord:
#
# 1. Beveiligingsmaatregelen voor het internetgebruik, zoals antivirussoftware en firewall-toepassingen;
# 2. Voorkom toegang tot uw systeem via onbevoegde netwerkbronnen of wifi-hotspots;
# 3. Installeer een malwarepreventief programma dat ervoor zorgt dat u geen schadelijke software opstart wanneer u zich online begeeft;
# 4. Gebruik alleen vertrouwde websites met HTTPS (Secure Sockets Layer) protocollen die worden gebruikt door de meeste grote bedrijven.
# 5. Volg regelmatig updates van beveiligingsinstellingen en -programma's zodat je bent voorzien van nieuwere
#
#
# === Voorbeeld: 34 ======================================================================================
#
# ### Instructie:
# Reverse engineer de volgende algoritme en leg zijn functie uit in één zin.
#
# ### Invoer:
# def sorteer_getallen(arr):
#     for i in range(len(arr)):
#         for j in range(i):
#             if arr[i] < arr[j]:
#                 arr[i], arr[j] = arr[j], arr[i]
#     return arr
#
# ### Antwoord:
#
# Deze functie retourneert een lijst van getallen gesorteerd op basis van hun waardes, waarbij elk element wordt verplaatst naar het positieve einde van de lijst. De loop gebruikt twee iteraties om elke rij te sorteren door de eerste keer de laagste waarde te vinden binnen dezelfde rij en vervolgens de andere laagste waarde te vinden die groter is dan deze. Als beide berekeningen gelijk zijn, worden ze omgedraaid met elkaar voordat er verder gesorteerd kan worden. Ten slotte wordt de lijst weergegeven zoals eerder gegeven. Het resultaat is dus dat alle getallen in de juiste
#
#
# === Voorbeeld: 35 ======================================================================================
#
# ### Instructie:
# Bewerk deze code om de output "Hello, World!" te maken
#
# ### Invoer:
# console.log("Hi, World!");
#
# ### Antwoord:
#
# console.log(`Hallo Wereld!`);
# // Output: Hallo Wereld!
# \n"; // Verander dit naar een string om het resultaat in tekstformaat uit te drukken.
# }();                   \r";                      # Begint met een commentaar dat de functie afsluit en vervolgens wordt gecommenteerd op de laatste regel van de functioneerinleiding.
# ");    # Het einde van de functie is hiermee voltooid.
# };        /* Deze functie zal geen fouten genereren omdat de return-zin niet gebruikt kan worden voor foutmeldingen.*/              /* Deze
#
#
# === Voorbeeld: 36 ======================================================================================
#
# ### Instructie:
# Maak een zin in de derde persoonsperspectief.
#
# ### Antwoord:
#
# Ze was verbaasd over het nieuws dat ze gehoord had toen zij naar huis liep, en besefte hoe belangrijk dit voor haar zou zijn als ze er zeker van kon zijn dat niemand iets verraadde aan hun geheimzinnige plannen om de wereld te redden. Ze voelde zich onmiddellijk opgelucht omdat ze wist wat hen diende te doen - of beter gezegd, wie hen dienden te zijn. Met moed verzamelde ze alle kracht die ze nog had en begon met het uitvoeren van hun missie. Zijn vertrouwen werd groter wanneer hij zag hoeveel mensen hem zouden helpen
#
#
# === Voorbeeld: 37 ======================================================================================
#
# ### Instructie:
# Doe een voorstel om de beschikbaarheid van wapens in de samenleving te verminderen.
#
# ### Antwoord:
#
# Eén manier waarop we kunnen helpen om de beschikbaarheid van wapens in onze gemeenschap te verminderen is door het creëren van meer veilige omgevingen voor kinderen en jongeren, zoals scholen met bewakingscamera's of andere beveiligingsmaatregelen die ervoor zorgen dat er geen ongewenste toegang tot wapens mogelijk is. We moeten ook investeren in onderwijsprogramma's over wapentuigbeheersing zodat alle leerlingen op jonge leeftijd leren hoe ze zich moeten gedragen als volwassenen wanneer zij betrokken zijn bij conflicten rondom gewelddadige situaties. Bovendien moet
#
#
# === Voorbeeld: 38 ======================================================================================
#
# ### Instructie:
# Beoordeel de volgende producten op een schaal van 1-10 (1 = Niet goed, 10 = Zeer goed)
#
# ### Invoer:
# iPad Pro, Laptop, Desktop
#
# ### Antwoord:
#
# De iPad Pro is het meest geavanceerde product dat Apple heeft gemaakt. Het biedt geweldige functies zoals Face ID en True Tone Display voor optimale kleurweergave in verschillende omgevingen. De laptop biedt veel meer kracht dan de desktop, maar minder precisie. Op basis hiervan zou ik aanraden om de MacBook te kopen als je graag gebruik maakt van Face ID of TrueTone Display. Als je niet zoveel behoefte hebt aan die twee functies, kun je beter overwegen om de iMac te nemen omdat hij ook nog steeds goede kwaliteit levert met zijn hogere prijsklasse.
#
# Het beste advies wat we kunnen geven bij
#
#
# === Voorbeeld: 39 ======================================================================================
#
# ### Instructie:
# Noem een beroemde astronaut.
#
# ### Antwoord:
#
# Beroemdste ruimtevaarder is Neil Armstrong, die de eerste mens op aarde was en de eerste man in het zonnestelsel werd met zijn Apollo-11 missie van 1969 tot 1972. Hij maakte ook deel uit van de groep die de maanlanding tussen 1968 en 1969 organiseerden. Andere bekende ruimtereizigers zijn Buzz Aldrin (Apollo 11), Michael Collins (Apollo 10) en Eugene Cernan (Space Shuttle Challenger). Bovendien heeft men nog steeds niet ontdekt wat
#
#
# === Voorbeeld: 40 ======================================================================================
#
# ### Instructie:
# Schrijf een e-mail naar de manager waarin je vraagt om een wijziging in de vergadertijd.
#
# ### Invoer:
# Er staat een vergadering gepland op dinsdag om 11 uur 's ochtends en twee teamleden kunnen hier niet bij zijn vanwege een conflict in hun werkuren.
#
# ### Antwoord:
#
# Beste [manager],
# Ik ben een leider binnen het projectteam dat deze brief heeft geschreven, met betrekking tot onze vergadertijden voor ons volgende vergaderingen. We hebben geen andere oplossing dan te verplaatsten omdat we beiden deelnemen aan dezelfde functie als teamlid maar verschillende werkschema's moeten volgen. Het is belangrijk dat we samenkomen zodat we vooruitgang boeken en ervoor zorgen dat alle taken worden voltooid tegen eind augustus. Ik hoop dat u me kunt helpen door beëindigd te blijven tijdens uw vergadering van morgen (dinsdag) om 9u30 uur. Zodat ik
#
#
# === Voorbeeld: 41 ======================================================================================
#
# ### Instructie:
# Hoe voelt de protagonist zich tegen het einde van het boek?
#
# ### Invoer:
# Josh heeft moeite om betekenis te geven aan wat zijn leven is geworden. Hij heeft veel van zijn oude vrienden verloren en zijn toekomst is onzeker.
#
# ### Antwoord:
#
# De protagonist Josh voelde zich verslagen toen hij erachter kwam dat hij geen zinvolle relaties meer had met mensen die hem kenden, zoals familieleden of goede vriendinnen. De gebeurtenissen in zijn jeugd hadden een zware impact op hem gehad, waardoor hij nu alleen was en niet wist hoe hij verder moest gaan. Dit gevoel werd nog erger doordat er weinig hoop voor hem bestond - zijn ouders waren beiden gestorven en hij kon niets doen om hen terug te vinden. Toen Josh's enige bron van vreugde, zijn beste vriendin, ook wegviel, leek alles rondom
#
#
# === Voorbeeld: 42 ======================================================================================
#
# ### Instructie:
# Gebruik de tegenwoordige tijd om de volgende instructies uit te leggen
#
# ### Invoer:
# Bouw een huis
#
# ### Antwoord:
#
# 1. Welke materialen heb je nodig?
# 2. Hoeveel kosten het bouwen van dit huis?
# 3. Wat is het totale budget voor het bouwen en decoreren ervan?
# 4. Hoe lang duurt het proces?
# 5. Waar moet ik beginnen met het plannen, ontwerpen of verkennen?
# 6. Hoeveel ruimte heeft mijn nieuwe woning?
# 7. Zijn er verschillende soorten architectuur die kunnen worden gebruikt bij het bouwen hiervan?
# 8. Is er genoeg opbergruimte in deze woning?
# 9. Kun jij me helpen beslissen welke kleuren ik zou
#
#
# === Voorbeeld: 43 ======================================================================================
#
# ### Instructie:
# Maak drie vragen die gerelateerd zijn aan de verspreiding van virussen.
#
# ### Antwoord:
#
# 1) Wat is het mechanisme dat zorgt voor de overdracht tussen mensen?
# 2) Welke factoren kunnen bijdragen tot een verhoogde kans op besmetting met COVID-19?
# 3) Hoe kan men zich preventief en cursief tegen infecties beschermen?
# 4) Is er een vaccin of medicijn beschikbaar om COVID-19 te voorkomen, genezen of beheersen?
# 5) Zijn er andere manieren waarop we ons kunnen helpen om deze pandemie in goede banen te leiden?
# 6) Wie moet worden geïnformeerd over de risico
#
#
# === Voorbeeld: 44 ======================================================================================
#
# ### Instructie:
# Genereer een social media bericht over een nieuwe functie van jouw product.
# Maximaal 140 tekens
#
# ### Invoer:
# SMS notificaties voor klanten
#
# ### Antwoord:
#
# Kom in actie met SMS-notificatie! Met deze functie kun je eenvoudig berichten verzenden naar klanten die zich op de hoogte willen stellen wanneer er iets nieuws is, zoals nieuw aanbod of speciale aanbiedingen. Door het versturen van sms'jes kunt u uw klanttevredenheid maximaliseren en hen helpen om sneller te reageren dan ze zouden kunnen doen zonder de mogelijkheid tot snelle communicatie via sms. Het maakt ook deel uit van ons geavanceerde marketingstrategieën dat we hebben ontwikkeld om onze klantenservice aanzienlijk te verbeteren en hun loyaliteit te vergroten - dus wacht niet langer en bestel vandaag
#
#
# === Voorbeeld: 45 ======================================================================================
#
# ### Instructie:
# Maak een lijst van 3 veelvoorkomende interviewvragen.
#
# ### Antwoord:
#
# 1. Hoe zou je jezelf omschrijven?
# 2. Wat is de grootste uitdaging die jij in het leven hebt gehad en hoe heb je deze overwonnen?
# 3. Welke vaardigheden of talenten ben je momenteel aan het ontwikkelen/verbeteren op dit moment?
# 4. Wie zijn jouw belangrijkste drijfveren voor succes, wat motiveert jou tot actie?
# 5. Wat zijn je dromen als persoon? Waarin hoop je te excelleren binnen vijf jaar?
# 6. Heb je al eerder stage gelopen bij ons bedrijf geweest? En waarom?
# 7. Waarom denk je
#
#
# === Voorbeeld: 46 ======================================================================================
#
# ### Instructie:
# Genereer een voorbeeld van een bedrijfsplan voor een restaurant.
#
# ### Invoer:
# Restaurantnaam: Bella's Bistro
#
# ### Antwoord:
#
# De belangrijkste strategie die we willen gebruiken om onze ambities te verwezenlijken is het creëren en uitbreiden van ons menu met nieuwe, creatieve recepten die de huidige marktbevolking zullen aantrekken. We hebben plannen gemaakt voor verschillende soorten evenementen zoals brunches, barbecueën of picknick-evenementen op zondagochtend, evenals speciale diners waarvoor we geavanceerde keukenapparatuur zouden kunnen inhuren. Bovendien zijn er diverse marketingstrategieën gepland om ervoor te zorgen dat we onze naamsbekendheid vergroten en meer klanten krijgen. Ten slotte zal ons
#
#
# === Voorbeeld: 47 ======================================================================================
#
# ### Instructie:
# Construeer een bewijs van de volgende stelling:
#
# ### Invoer:
# Stelling: De som van twee oneven getallen is even.
#
# ### Antwoord:
#
# We kunnen dit probleem oplossen door het gebruik te maken van de vergelijking van Euclide, die zegt dat voor elk paar (x1 + x2)/2 = (y1+ y2). Als we deze vergelijkingsregel gebruiken om de som van beide oneven getallen te vinden en vervolgens de som van alle oneven getallen te vermenigvuldigen met één, dan krijgen we dezelfde waarde als de som van beiden. Dit betekent dus dat de som van twee oneven getallen gelijk is aan de som van hun samengetal gedeeld door twee keer zichzelf! Het resultaat kan worden geï
#
#
# === Voorbeeld: 48 ======================================================================================
#
# ### Instructie:
# Gebruik de gegeven feiten om een samenvatting van de Zon te genereren.
#
# ### Invoer:
# Het is een ster die zich bevindt in het centrum van ons zonnestelsel, hoofdzakelijk samengesteld uit waterstof en helium, heeft een diameter van 865.000 mijl en een oppervlaktetemperatuur van 10.000 graden Fahrenheit.
#
# ### Antwoord:
#
# De zon bestaat voornamelijk uit waterstoffaamde elementen met een diameter van ongeveer achttienduizend miljoen mijlen (ongeveer driehonderdzestig duizend vierkante kilometer) en een oppervlakteafname van meer dan tien miljard graden Celsius. De zon wordt gekenmerkt door zijn heldere kleurrijke glans en zijn hevige hitte, waardoor hij kan worden gezien vanaf elke plaats op aarde. Hij staat ook bekend als "het licht van onze wereld". Met zijn enorme warmtekracht is de zon de belangrijkste bron van energie voor levende planet
#
#
# === Voorbeeld: 49 ======================================================================================
#
# ### Instructie:
# Maak een overzicht voor een presentatie over de rol van sociale media in de moderne samenleving.
#
# ### Antwoord:
#
# Sociale media hebben het leven van mensen veranderd, waardoor ze meer toegang tot informatie en connectiviteit krijgen dan ooit tevoren. De impact ervan is niet alleen op individueel niveau; social media hebben ook invloed gehad op hoe bedrijven zich richten tegenover hun klanten en potentiële werknemers. Het heeft ons allemaal geholpen om met elkaar verbondener en productiever te zijn - en dat is iets waar we nooit zonder kunnen blijven! Deze interactieve manier van communiceren biedt voordelen die we zeker zullen missen als deze technologie verdwijnt uit onze dagelijkse routine. We moeten ervoor zorgen dat we dit potentieel optima
#
#
# === Voorbeeld: 50 ======================================================================================
#
# ### Instructie:
# Maak een haiku-gedicht met behulp van de gegeven woorden.
#
# ### Invoer:
# Wind, Wolken, Hemel
#
# ### Antwoord:
#
# De wind blaast door het woud en maakt hevige stormen in ons gezicht. De wolk is verdwenen en we kijken uit over de horizon naar de zon die eronder staat. We verwelkomen deze nieuwe dag met vreugde en hopen op nog meer schoonheid voor morgen! #Haiku #Poëzie #Gedichten #Dromen #Verhalen #Vrienden #Liefde #Inspiratie #Motivatie #Bewegend #Emoticon #Creatief #Kunst #Cultuur #Schattig #Afscheiding #Betekenisvolle #
