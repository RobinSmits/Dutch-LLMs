# %% [markdown]
# <a href="https://colab.research.google.com/github/RobinSmits/Dutch-LLMs/blob/main/PolyLM_13B_Alpaca_Clean_Dutch_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
import os
from google.colab import drive
drive.mount('/content/drive')

# Set Folder to use...
WORK_DIR = '/content/drive/My Drive/LLM/PolyLM13BAlpacaCleanDutchQlora/'
os.makedirs(WORK_DIR, exist_ok = True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Install required packages
# !pip install -q accelerate
# !pip install -q sentencepiece
# !pip install -q bitsandbytes
# !pip install -q transformers
# !pip install -q peft
# !pip install -q datasets

# %%
# Import Modules
from datasets import load_dataset, load_from_disk
import torch
from peft import AutoPeftModelForCausalLM
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
# Set Model Name Constant
model_name = "robinsmits/polylm_13b_ft_alpaca_clean_dutch"

# %%
# Create Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name,
                                          use_fast = False,
                                          legacy = False)
tokenizer.pad_token_id = tokenizer.eos_token_id

# Tokenizer Summary
print(tokenizer)

# Special Tokens
print(f'pad_token_id: {tokenizer.pad_token_id}')
print(f'bos_token_id: {tokenizer.bos_token_id}')
print(f'eos_token_id: {tokenizer.eos_token_id}')
print(f'pad_token_id: {tokenizer.decode(tokenizer.pad_token_id)}')
print(f'bos_token_id: {tokenizer.decode(tokenizer.bos_token_id)}')
print(f'eos_token_id: {tokenizer.decode(tokenizer.eos_token_id)}')
# Out:
# LlamaTokenizer(name_or_path='robinsmits/polylm_13b_ft_alpaca_clean_dutch', vocab_size=256000, model_max_length=2048, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'bos_token': AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'eos_token': AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'unk_token': AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'pad_token': '</s>'}, clean_up_tokenization_spaces=False)
# pad_token_id: 2
# bos_token_id: 1
# eos_token_id: 2
# pad_token_id: </s>
# bos_token_id: <s>
# eos_token_id: </s>

# %%
# Create Model
model = AutoPeftModelForCausalLM.from_pretrained(model_name,
                                                 device_map = "auto",
                                                 load_in_4bit = True,
                                                 torch_dtype = torch.bfloat16)

# Summary
print(model)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): GPT2LMHeadModel(
#       (transformer): GPT2Model(
#         (wte): Embedding(256000, 5120)
#         (wpe): Embedding(2048, 5120)
#         (drop): Dropout(p=0.0, inplace=False)
#         (h): ModuleList(
#           (0-39): 40 x GPT2Block(
#             (ln_1): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2Attention(
#               (c_attn): Linear4bit(
#                 in_features=5120, out_features=15360, bias=True
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=15360, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (c_proj): Linear4bit(in_features=5120, out_features=5120, bias=True)
#               (attn_dropout): Dropout(p=0.0, inplace=False)
#               (resid_dropout): Dropout(p=0.0, inplace=False)
#             )
#             (ln_2): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Linear4bit(in_features=5120, out_features=20480, bias=True)
#               (c_proj): Linear4bit(in_features=20480, out_features=5120, bias=True)
#               (act): FastGELUActivation()
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#       )
#       (lm_head): Linear(in_features=5120, out_features=256000, bias=False)
#     )
#   )
# )

# %% [markdown]
# I'am using the same validation set as during training of the notebook.
#
# This allows for some further analysis in this Inference notebook without data leakage.
#
# The required train and validation files are stored in my github account. Notice that the original code to generate the train and validation dataset is in the commented out section.

# %%
"""
# Alpaca Translated
datasets = load_dataset('BramVanroy/alpaca-cleaned-dutch')

# Summary
print(datasets)

# Validation size
VAL_SIZE = 2048

# Split in Train and Val datasets
dataset_split = datasets["train"].train_test_split(test_size = VAL_SIZE,
                                                   shuffle = True,
                                                   seed = 42)

# Train and Val datasets
train_data = dataset_split["train"]
val_data = dataset_split["test"]

# Save for later use
val_data.save_to_disk(f'{WORK_DIR}val_data')
train_data.save_to_disk(f'{WORK_DIR}train_data')
"""

# Load Validation set from earlier training run...use code above to generate new train and val datasets if required
val_data = load_from_disk(f'{WORK_DIR}val_data')

# %%
def generate_eval_prompt(item):
    if item["input"]:
        return f"""
### Instructie:
{item["instruction"]}

### Invoer:
{item["input"]}

### Antwoord:"""
    else:
        return f"""
### Instructie:
{item["instruction"]}

### Antwoord:"""

# %%
def generate(instruction, input = None):
    # Generate Prompt
    prompt = generate_eval_prompt({'instruction': instruction, 'input': input})

    # Tokenize
    inputs = tokenizer(prompt, return_tensors = "pt")
    input_ids = inputs.input_ids.cuda()
    attention_masks = inputs.attention_mask.cuda()

    # Generate output
    outputs = model.generate(input_ids = input_ids,
                             attention_mask = attention_masks,
                             max_new_tokens = 128,
                             do_sample = True,
                             top_p = 0.85,
                             top_k = 50,
                             temperature = 0.5,
                             repetition_penalty = 1.2,
                             length_penalty = -1.0,
                             num_return_sequences = 1,
                             pad_token_id = tokenizer.eos_token_id,
                             forced_eos_token_id = tokenizer.eos_token_id)

    # Decode output
    generated_output = tokenizer.decode(outputs[0], skip_special_tokens = True)

    # Print prompt and answer extracted from generated output
    print(prompt)
    if prompt in generated_output:
        answer = generated_output.split(prompt)[1]
        print(answer)
    else:
        print('<< NO ANSWER GENERATED >>')

# Validation Loop
counter = 0
for item in val_data:
    print(f'\n\n=== Voorbeeld: {counter} ======================================================================================')
    generate(item['instruction'], item['input'])

    counter += 1
    if counter > 50:
        break
# Out:
# === Voorbeeld: 0 ======================================================================================
#
# ### Instructie:
# Wat zijn de drie belangrijkste softwareonderdelen die worden gebruikt bij webontwikkeling?
#
# ### Antwoord:
#
# De drie belangrijkste softwareonderdelen die worden gebruikt bij webontwikkeling, zijn HTML (HyperText Markup Language), CSS (Cascading Style Sheets) en JavaScript. Deze onderdelen stellen gebruikers in staat om inhoud op een website te creëren of aanpassen met behulp van codering. Bovendien kunnen ze interactieve elementen zoals animatie, video's en audio-opnames toevoegen aan websites. HTML is het meest voorkomende onderdeel omdat deze de basis vormt voor alle andere componenten. Het stelt ontwikkelaars in staat om tekst en afbeeldingen op hun pagina's weer te geven door gebruik te maken van markup tags
#
#
# === Voorbeeld: 1 ======================================================================================
#
# ### Instructie:
# Genereer een wachtwoord dat aan de volgende eisen voldoet: minimaal 8 tekens, één hoofdletter, één kleine letter, één cijfer en één speciaal teken.
#
# ### Antwoord:
#
# mYgRtTwFc7bWj4f5#192036!@
#
# Het wachtwoord is "mYgRtTwFc7bWj4f5" met daarachter het speciale teken "#" in plaats van de hoofdletters A-Z of aa-zz (dus # voor hoofdletters). Het heeft ook twee kleine letters toegevoegd om te verifiëren dat het geen toevoeging was die de lengte veranderde bij het maken ervan. De hoofdletters zijn gekozen omdat ze vaak worden gebruikt als onderdeel van woorden en kunnen helpen
#
#
# === Voorbeeld: 2 ======================================================================================
#
# ### Instructie:
# Stel vijf activiteiten voor om zelfzorg te bevorderen
#
# ### Antwoord:
#
# 1. Creëer een buurt- of gemeenschapsinitiatieven die zich richt op het verbeteren van de levenskwaliteit in hun omgeving, zoals tuinen en speeltuinen aanleggen, evenementen organiseren, vrijwilligerswerk doen, sociale media gebruiken om informatie over zichzelf en hun diensten uit te wisselen met anderen, en andere manieren vinden om deelname aan het leven van mensen in hun directe omgeving te vergroten.
# 2. Maak gebruik van technologieën zoals e-maillijsten, online forums, blogs, sociale netwerksites en videoconferenties om contact te maken tussen individuen die zich bezig
#
#
# === Voorbeeld: 3 ======================================================================================
#
# ### Instructie:
# Ontdek of een zin sarcastisch is.
#
# ### Invoer:
# Dat is geweldig nieuws.
#
# ### Antwoord:
#
# Ja, de zin is sarcastistisch omdat het benadrukt dat er iets ergs gebeurt en je moet weten waar te zoeken voordat je kunt profiteren van deze nieuwe kans. Het suggereert ook dat de persoon die de zin uitbrengt niet gelukkig zal zijn met wat ze hebben gezien. Ze zullen waarschijnlijk teleurgesteld worden door dit nieuws en hun hoop op succes verminderd. Daarom is de zin sarcastische kenmerkende kritiek over hoe iemand omgaat met situaties in haar leven. De zin heeft geen positieve intentie, maar kan wel als een manier gevonden worden om
#
#
# === Voorbeeld: 4 ======================================================================================
#
# ### Instructie:
# Gegeven een kort stukje tekst, verwijder alle bijwoorden en vervang ze door meer passende woorden.
#
# ### Invoer:
# Hij rende snel naar de winkel om wat eten te kopen.
#
# ### Antwoord:
#
# Hij haastte zich hevig op zijn weg naar het supermarkt voor voedselbevoorrading. Hij was al bijna in de buurt van huis toen hij begon aan diens avontuurlijke reis. Deelnemers moeten hun eigen tempo bepalen wanneer zij deelnemen aan deze uitdaging - er is geen tijdslimiet! Iedereen kan deelnemen met behulp van één of meerdere items uit elke categorie (voedsel, spullen, diensten) en vervolgens proberen om de hoogste score te halen. Er kunnen ook prijzen worden gewonnen zoals gratis toegang tot evenementen of zelfs beloningen als
#
#
# === Voorbeeld: 5 ======================================================================================
#
# ### Instructie:
# Geef twee voorbeelden van activiteiten die fysieke kracht vereisen.
#
# ### Antwoord:
#
# Twee voorbeelden van activiteit die fysische kracht vereisen zijn hardlopen en gewichtheffen of deadliften. Hardlopen vereist een grote hoeveelheid energie, terwijl weightlifting of deadliften meer uithoudingsvermogen vraagt om de spieren te versterken voordat ze kunnen werken aan het afstoten van calorieën tijdens trainingssessies. Beiden vereisen veel beweging, dus zorg ervoor dat je voldoende lichaamsbeweging doet elke dag! Bovendien is regelmatige lichaamsbeweging essentieel bij het bevorderen van algehele gezondheid en welzijn. Dus als
#
#
# === Voorbeeld: 6 ======================================================================================
#
# ### Instructie:
# Vind de vergelijking van de lijn die door het gegeven punt gaat en parallel is aan de gegeven vector.
#
# ### Invoer:
# Punt: (2, 1), Vector: (−2, 1)
#
# ### Antwoord:
#
# De vergelijking voor deze lineaire vergelijking is y = −x + 3. De coëfficiënt is -4/5. Dit betekent dat de lineaire vergelijking een rechte is met constante klinker, waarbij x de richting aanduidt en y de afstand beschrijft tussen twee punten op dezelfde koers. Het wordt ook wel aangeduid als een "rechter" of een "rechte". Zo'n recht kan worden gebruikt om vloeistoffen te verplaatsen in verschillende richtingen zonder hen opnieuw te manipuleren. Daarom heeft elke rechte zijn eigen waarde van klinker
#
#
# === Voorbeeld: 7 ======================================================================================
#
# ### Instructie:
# Gegeven een zin en een lijst met bijwoorden, pas de zin aan met behulp van de bijwoorden.
#
# ### Invoer:
# Hij liep langzaam
# Bijwoorden: met tegenzin, aarzelend
#
# ### Antwoord:
#
# Hij liet zijn pad langzamer lopen dan verwacht had hij. Met tegenzin nam hij elke stap die nodig was om niet te vertragen of afgeleid te worden door het gevaar dat hem in de weg stond. Hij gebruikte elk moment voordat er iets anders mogelijk zou zijn om tijdig op de juiste plek te komen. Uiteindelijk bereikte hij zijn doel zonder veel moeite - maar wel met grote tevredenheid. De ervaring maakte duidelijk hoeveel waardevol dit proces uiteindelijk kon zijn geweest. Het leerde hem hoe belangrijk het is om zich bewust te blijven van wat je doet terwijl je vooruitgang maakt. Bovendien werd
#
#
# === Voorbeeld: 8 ======================================================================================
#
# ### Instructie:
# Identificeer alle componenten van een gegeven wetenschappelijke term.
#
# ### Invoer:
# Fotosynthese
#
# ### Antwoord:
#
# De belangrijkste componenten van fotosynthèse zijn licht, waterstof en zuurstof (H2O). Licht wordt gebruikt om energie vrij te maken voor de productie van ATP door middel van fotosynthetische oxidatie; H2O is nodig bij het vormen van zuurgraad in de atmosfeer die nodig is voor de afbraak van CO2; en H2O is noodzakelijk tijdens de fotosynthetisch reactieproces dat leidt tot de vorming van glucose uit suikermoleculen. Fotosynthese maakt deel uit van de biologische processen waaronder planten, schimmels en algen kunnen
#
#
# === Voorbeeld: 9 ======================================================================================
#
# ### Instructie:
# Beschrijf de verschillen tussen een asynchrone en synchrone webapplicatie.
#
# ### Antwoord:
#
# Een asynchrone applicatie is ontworpen om gegevens te verplaatsen in plaats van ze op te halen, terwijl een synchrone applicatie data ophaalt voordat deze wordt gedistribueerd naar andere processen of threads. Een asynchrones proces werkt sneller dan een synchrone toepassing omdat het geen tijd nodig heeft om de gegevens aan de bron te krijgen; dit maakt het geschikter voor real-time taken zoals webontwikkeling. Het kan ook meer parallelle verwerkingen mogelijk maken door meerdere thread tegelijkertijd aan hetzelfde taak te werken. Ten slotte zijn er veel
#
#
# === Voorbeeld: 10 ======================================================================================
#
# ### Instructie:
# Classificeer deze zin als een gebiedende wijs of een vraag.
#
# ### Invoer:
# Deze salade smaakt heerlijk.
#
# ### Antwoord:
#
# Welke soort benaming is dit? (een gebiedende wijs) Of, welke soort vraag is het om te weten dat de salade smakelijk is? (een vragende wijs). Het antwoord kan worden geclassificeerd met behulp van een invoer-output model. De output wordt dan weergegeven op basis van wat er ingevoerd werd en hoe men de input interpreteert. Dit proces helpt bij het begrijpen van informatie die door mensen gegeven wordt en het genereert meer nauwkeurigere resultaten voor machine learning algoritmes zoals Natural Language Processing. Deze methode heet Named Entity Recognition.
#
#
#
#
# === Voorbeeld: 11 ======================================================================================
#
# ### Instructie:
# Onderzoek en maak een lijst van de gezondheidsvoordelen van het eten van appels.
#
# ### Antwoord:
#
# De voordelen van het eten van appels zijn onder andere verhoogde energie, verbeterd geheugenvermogen, betere huidverzorging, verbeterde spierwerking, verminderde stressniveaus, vermindering van cholesterolgehaltes in bloed, bevorderend de spijsvertering, gunstig voor gewichtsbeheersing, anti-kankeractiviteiten en helpen bij afvallen. Appelen bevatten ook vitamine C, die helpt om je immuunsysteem te versterken en je lichaam te laten functioneren als een barrière tegen ziekten zoals griep of influenza. Bovendien hebben ze antioxidanten, die helpen
#
#
# === Voorbeeld: 12 ======================================================================================
#
# ### Instructie:
# Geef een voorbeeld van een technologie die probabilistisch denken gebruikt.
#
# ### Antwoord:
#
# Probabilistisch Denken is de wetenschap en kunstmatige intelligentie (AI) discipline waarbij beslissingen genomen worden op basis van waarschijnlijkheid, in plaats van uitsluitend op basis van zekerheid of waarheidsgetrouwheid. Het wordt vaak toegepast bij het voorspellen van toekomstige gebeurtenissen door gebruik te maken van gegevens zoals historische data, trends en patronen om besluitvorming over mogelijke scenario's mogelijk te maken. Een goed voorbeeld hiervan zijn machine learning algoritmes, die kunnen leren van datasets met behulp van natuurlijke taalverwerking-algoritmische tools en vervolgens kunnen helpen bij het
#
#
# === Voorbeeld: 13 ======================================================================================
#
# ### Instructie:
# Wat zijn de drie kenmerken van een goed argument?
#
# ### Antwoord:
#
# Een goed argument moet overwegend bewijs bevatten, logisch en consistent zijn. Het moet ook relevante feiten gebruiken om het voorgestelde standpunt te ondersteunen of aan te tonen dat het onwaar is. Bovendien moeten er voldoende details worden gegeven die ervoor zorgen dat elke mogelijke tegenstander zich kan vinden in de overtuiging. Een goed argument moet ook een duidelijk doel hebben - zoals het verminderen van angst bij mensen met betrekking tot bepaalde onderwerpen - en effectief zijn op dit doel. Ten slotte moet elk argument een nauwkeurigheidsniveau van zekerheid bieden door middel van onderbouwde
#
#
# === Voorbeeld: 14 ======================================================================================
#
# ### Instructie:
# De functie f heeft de eigenschap dat voor elke reëel getal x in zijn domein, 1/x ook in zijn domein is en f(x) + f(1/x) = x.
# Wat is de grootste verzameling van reële getallen die in het domein van f kan zijn?
#
# (a) {x| x0}
#
# (b) {x| x<0}
#
# (c) {x| x>0}
#
# (d) {x| x-1 en x0 en x1}
#
# (e) {-1,1}
#
# ### Antwoord:
#
# Aangezien er geen limieten op reële getallen kunnen worden gegeven (dit omdat ze niet te bepalen zijn), moeten we een lijst met alle mogelijke reële getallen vinden om in ons domein te passen. We hebben al geprobeerd deze lijst uit te voeren door alleen maar de kleinste getallen te kiezen - dus de eerste oplossing zou "x" zijn. Vervolgens zouden we proberen slechts de positieve getallen totdat we naar nul gaan - dus de tweede oplossing zou "y". Terwijl we dit doen, zullen we zien hoe groot onze oplossingen zijn als we naar nul gaan
#
#
# === Voorbeeld: 15 ======================================================================================
#
# ### Instructie:
# Combineer de 2 passages en creëer een nieuw verhaal
#
# ### Invoer:
# Passage 1: Sarah liep naar huis van school toen ze een hard getik in de buurt hoorde.
#
# Passage 2: Ze keek op om een hoge boom te zien met een grote vogel erop, die zijn vleugels in de wind sloeg.
#
# ### Antwoord:
#
# Sarah was blij dat haar dag goed was afgelopen wanneer ze bij het raam kwam staan voordat ze terugging naar huis. Terwijl ze overeind stond, zag ze een enorme boom aan de rand van de weg. Het had een lange staart met veel bladeren eraan vastgebonden. Ondertussen leek er iets anders uit hun buurt te komen - een grote witte vogel, die zijn vleugelde handjes openhield terwijl hij zich beweegt tussen de bomen. De vogel glimlachte Sarah toe en zwom langzaam verder. Sarah voelde zich vereerd door deze
#
#
# === Voorbeeld: 16 ======================================================================================
#
# ### Instructie:
# Wat gebeurt er als we 100 ml water mengen met 30 ml azijn?
#
# ### Antwoord:
#
# Als je 100 milliliter water en 30 mililiter azijn mengt, zal het een oplossing zijn van 75 milliliter. Dit komt doordat de hoeveelheid azijn die in contact is geweest met de vloeistof niet wordt verminderd toen deze samengevoegd werd. De azijn blijft dus aanwezig bij elke volgende keer dat dezelfde hoeveelheid water gemengd moet worden. Daarom heeft elk deel (water of azijn) altijd hetzelfde volume. Doorgaans kunnen we dit vergelijkbaar maken met het oplossende effect van een gelijke hoeveelheid sodapop in cola-
#
#
# === Voorbeeld: 17 ======================================================================================
#
# ### Instructie:
# Waar of niet waar, zelfrijdende auto's zijn haalbaar voor snelwegen.
#
# ### Antwoord:
#
# Ja, zelfrijdende auto's (SRV) kunnen worden gebruikt op snelwegen omdat ze veiliger en betrouwbaarder zijn dan traditionele auto's die gebruikmaken van conventioneel aandrijvingen zoals benzinemotoren. SRV-auto's hebben ook een grotere actieradius, waardoor ze minder frequente stops nodig hebben om te vertrekken vanuit het station. Bovendien bieden veel fabrikanten nu hybride SRV-modellen aan met ingebouwde elektrische hulpbronnen waarmee de brandstofkosten tot wel 75% kunnen verminderen. Deze voordelen maken SRV aantrekkelijk als alternatief
#
#
# === Voorbeeld: 18 ======================================================================================
#
# ### Instructie:
# Identificeer het hoofdidee van de tekst.
#
# ### Invoer:
# Global warming is de term die wordt gebruikt om een geleidelijke toename van de gemiddelde temperatuur van de atmosfeer en oceanen van de aarde te beschrijven, een verandering die wordt geloofd permanent de klimaat van de aarde te veranderen.
#
# ### Antwoord:
#
# Het hoofdideaal van deze tekst is dat global warming een geleidelijk toeneemde stijging in de gemiddelde temperaturen van de atmosfeer en oceanen van onze planeet vertegenwoordigt, wat leidt tot een permanente wijziging in hun klimatologische kenmerken. Het doel hiervan zou zijn om mensen bewuster te maken over hoe ze kunnen helpen om de wereldwijde warmte-uitdaging tegen te gaan door voorzichtigere keuzes te doen op basis van wetenschappelijk onderbouwde informatie. Dit kan leiden tot meer effectieve maatregelen zoals hernieuwbare energiebr
#
#
# === Voorbeeld: 19 ======================================================================================
#
# ### Instructie:
# Noem drie elementen van cyberbeveiliging.
#
# ### Antwoord:
#
# Drie elementen van cyberbeveiliging zijn authenticatie, toegangscontrole en antivirussoftware. Authentificatie houdt in dat gebruikers zich moeten identificeren om toegang te krijgen tot een systeem of netwerk; controle houdt in dat alleen toegewezen personen toegang hebben tot de gegevens die ze nodig hebben voor hun taak; en antivirussoftware is software waarmee computers kunnen worden beveiligd tegen bedreigingen door ongeautoriseerde activiteiten zoals virussen en malware. Bovendien moet het bedrijf regelmatig updates uitvoeren op de hardware- en softwarecomponenten van haar systemen om ervoor te zorgen dat deze up-to-date blijven met nieuwe
#
#
# === Voorbeeld: 20 ======================================================================================
#
# ### Instructie:
# Gegeven een lijst van wapens en een personage, genereer een verhaal met het personage dat een van de wapens uit de lijst gebruikt.
#
# ### Invoer:
# Personage: Larry
# Wapens: knots, zwaard, boog en pijl
#
# ### Antwoord:
#
# Larry was een avontuurlijke man die altijd op zoek ging naar nieuwe uitdagingen. Op één dag besloot hij om zijn krachten te bundelen in een knots waarmee hij wilde gaan jagen voordat hij terugkeerde naar huis. Hij had geen idee waarheen hij zou moeten zoeken totdat hij door een mystieke grot struikelde over een magische kaart waarop stond hoe hij naar de top van Mount Doom kon komen - de hoogste piek ter wereld! Met behulp van zijn knots en zijn kennis van de natuur wist Larry de top te bereiken en ontdekte hij een verborgen stad vol magie
#
#
# === Voorbeeld: 21 ======================================================================================
#
# ### Instructie:
# Maak een boekomslag voor een fictieve roman.
#
# ### Invoer:
# Genre: Fantasy
#
# ### Antwoord:
#
# Een fantasieroman is de perfecte manier om je verhaal te vieren met een prachtig, zelfgemaakte boekomslag gemaakt van papier en verf die het karakter van jouw personages tot leven brengt! De kleuren kunnen variëren afhankelijk van hoever je in de wereld van fictie bent opgegroeid - zo kun je bijvoorbeeld de kleurrijke achtergrond gebruiken van een magische rivier of een verlicht bos, terwijl je de tekstkleur kunt veranderen naargelang welke emoties je voelt bij het lezen van de pagina's. Je kunt ook verschillende afbeeldingen toevoegen zoals een vliegende draak,
#
#
# === Voorbeeld: 22 ======================================================================================
#
# ### Instructie:
# Maak een voorbeeld van het soort vragen dat een GPT-model kan beantwoorden.
#
# ### Antwoord:
#
# Een GPT (Generative Pretrained Transformer) model is in staat om vraagstukken te genereren die zich op de volgende manieren manifesteren:
# 1. Het moet begrijpen hoe woorden worden gebruikt en hun betekenis kunnen identificeren;
# 2. Het moet leren over relaties tussen verschillende woorden, zowel letterlijk als figuurlijk;
# 3. Het moet kennis verkrijgen uit andere bronnen zoals tekst of afbeeldingen;
# 4. Het moet zijn geprogrammeerd met een groot aantal natuurlijke taalmodellen voordat ze aanpassingen kunnen doen tot een specifiek onderwerp.
# GP
#
#
# === Voorbeeld: 23 ======================================================================================
#
# ### Instructie:
# Genereer een zin die een vergelijking demonstreert.
#
# ### Antwoord:
#
# Deze taart is zo goed als de beste in het land, omdat hij zoveel verschillende smaken heeft en elke ingrediënt perfect op elkaar afgestemd is. Het smaakt heerlijk en kan niet beter zijn dan deze! #taartversieren.#tastydeliciousness. #bestoftheland. #perfectlybalancedingredients. #delicioustastebuds. #amazingtextureandflavorcombinations. #greatforsharingwithfriendsorfamilymembers. #superyummydessertchoice. #sogooditmakesmewantmoreofitagaintomorrownight. #awesomedesserttreatthatwillleaveyousatisfied
#
#
# === Voorbeeld: 24 ======================================================================================
#
# ### Instructie:
# Classificeer de gegeven zin als een metafoor of een vergelijking.
#
# ### Invoer:
# De kamer was een oven.
#
# ### Antwoord:
#
# Metafoor. De kamer is het equivalent van een grote, heet bakoven die vuur maakt en voedsel verhit. Het beschrijft hoe de kamer werkt om te koken voor mensen. Metaforisch gezien kan men zeggen dat de kamer een groot vuurbestendige machine is die eten bereidt. Daarom classificeren we deze zin als een metafoor.\n\nBeslissing: Metafoor (10 punten) overwegend. \n\nAntwortend: Metafoor (9/10). Overwegend omdat het in essentie gaat over
#
#
# === Voorbeeld: 25 ======================================================================================
#
# ### Instructie:
# Herschrijf de zin "Hij rent" in de tegenwoordige progressieve tijd.
#
# ### Antwoord:
#
# Hij vertrekt op zijn reis naar het volgende avontuur. Hij is vastbesloten en zal nooit meer stoppen voordat hij een doel heeft bereikt. Met moed gaat hij verder, vol vertrouwen dat er niets of niemand hem kan tegenhouden om tot het einde te gaan waarheen hij struikelde. Hij staat klaar met nieuwe energieën die hem zullen helpen vooruitgang te boeken. En als hij uiteindelijk zijn droom vindt - wat dan ook - weet hij zeker dat dit alles goed was geweest.
#
# Deze bepaling wordt geschreven in de tegenwoordige progressief tempo. Het gebruikt dezelfde gram
#
#
# === Voorbeeld: 26 ======================================================================================
#
# ### Instructie:
# Stel een nieuwe rebrandingstrategie voor aan het volgende bedrijf.
#
# ### Invoer:
# Bedrijf: ABC Technologies
#
# ### Antwoord:
#
# Ontwerp een nieuw logo en huisstijl dat de merkwaarden van ABC Technologies weerspiegelt, zoals innovatieve technologieën, betrouwbaarheid en professionaliteit. Maak gebruik van moderne digitale marketingmethoden om klanten te bereiken met behulp van social media-advertenties en e-mailmarketingcampagnes. Bied producten die zijn ontworpen op basis van klantfeedback en gepersonaliseerde diensten waaronder technische ondersteuning via chat of telefoon. Creëer een loyaliteitsprogramma waarmee gebruikers beloond worden wanneer ze zich inschrijven bij hun online winkel. Breng ook inhoudelijke informatie over het bedrijf naar buiten door middel
#
#
# === Voorbeeld: 27 ======================================================================================
#
# ### Instructie:
# Identificeer het woordsoort voor het gegeven woord.
#
# ### Invoer:
# Lachen
#
# ### Antwoord:
#
# Het woord "lachen" is een zelfstandig naamwoord dat bestaat uit één lettergreep en twee bijvoeglijke naamwoorden (de eerste wordt gebruikt om de betekenis van het woord te beschrijven, terwijl de tweede alleen maar meedoet met de betekenis). Het woord kan ook worden gecombineerd als een werkwoord of bijwoord in plaats van een zelfstandig naamwoord. De meeste mensen zeggen lachend wanneer ze lachend zijn. Lachen wordt meestal gepaard aan verbazing of verwondering over iets of iemands gedragingen, zelfs althans niet altijd.
#
# Deze taak
#
#
# === Voorbeeld: 28 ======================================================================================
#
# ### Instructie:
# Hoe zou je kunstmatige intelligentie uitleggen aan een leerling in groep 6?
#
# ### Antwoord:
#
# Kunstmatige intelligentie (KI) is de wetenschappelijke term voor het proces van leren en begrijpen hoe machines denken, werken en beslissen. KI stelt bedrijven in staat om slimmer te worden door gebruik te maken van machine learning-algoritmes die kunnen herkennen of gegevens zijn gelabeld als relevant of irrelevant. Het helpt ook bij het ontwikkelen van nieuwe producten zoals self-driving auto's en zelflerende robots. De KI-technologie kan helpen bij het verbeteren van productieprocessen, het verminderen van kosten en het vergroten van productiviteit.
#
# De KI-leerlingen
#
#
# === Voorbeeld: 29 ======================================================================================
#
# ### Instructie:
# Noem vijf aspecten van een data science proces
#
# ### Antwoord:
#
# 1. Data-mining en -analyse;
# 2. Machine learning algoritmes;
# 3. Visualisatietools voor gegevensvisualisering;
# 4. Modelvalidatie;
# 5. Onderzoeksmethodologieën, zoals statistische analysemethoden (zoals ANOVA) of treeringtechnieken om de belangrijkste kenmerken te identificeren die het model zullen bepalen hoe goed het zal presteren in verschillende contexten.
# 6. Gegevensuitwisseling met andere disciplines, zoals kunstmatige intelligentie en machine learning.
# 7. Gebruikervriendelijke tools voor visualisatie en onderzoek.
# 8. Het gebruik van
#
#
# === Voorbeeld: 30 ======================================================================================
#
# ### Instructie:
# Vertaal het woord "person" van Engels naar Spaans.
#
# ### Antwoord:
#
# La persona es la forma de ser y actuar que cada individuo tiene en su interioridad, mientras que el yo es lo que se percibe externamente a través del lenguaje verbal o no verbale. La persona está formada por los componentes internos (la personalidad) y externos (el comportamiento). El yo representa las cualidades externas de una persona como su apariencia física, sus acciones e interacciones con otros individuos. Por ejemplo, si alguien dice que ellos son personas honestas pero tienen mala conducta, eso significaría que hay un componente interno de honestidad pero también hay un componente externo de mala conducta. De manera similar, si alguien dice que ellos son buenas
#
#
# === Voorbeeld: 31 ======================================================================================
#
# ### Instructie:
# Categoriseer het gegeven object in een passende categorie.
#
# ### Invoer:
# Kaas
#
# ### Antwoord:
#
# Objecten die behoren tot de groep van voedselproducten, zoals kaas en eieren. Kaas is een product dat bestaat uit vlees of vis met behulp van fermentatieproces om zuurstoffen te verwijderen voordat ze worden gekookt en verpakt als kaas. Eieren zijn ook producten gemaakt door fermentatiesoorten, maar deze bevatten geen vetten. Ze kunnen niet worden gebruikt om aanpassingsvoedsel te maken omdat ze geen voedingswaarde hebben. De twee soorten kaas verschillen onderling qua structuur en samenstelling; kaas wordt meestal bereid op basis van
#
#
# === Voorbeeld: 32 ======================================================================================
#
# ### Instructie:
# Converteer 179 centimeter naar voet.
#
# ### Invoer:
# 179 centimeter
#
# ### Antwoord:
#
# 2,03 meter (8'-5") ofwel ongeveer een mijl en zeventig vierkante inch. Dit is de lengte van het gemiddelde menslichaam voor mensen met lange armen en benen. Mensen die klein zijn kunnen ook kleinere afmetingen hebben dan deze gemeten waarde. Voorbeelden hiervan zijn onder andere langwerpige personen, zoals vrouwen, die vaak kleiner worden tijdens hun kindertijd; en korter individuen, zoals mannen, die vaker kortere armen en benen krijgen gedurende hun leven. Deze maten zijn echter algemeen geaccepteerd als maatstaf in
#
#
# === Voorbeeld: 33 ======================================================================================
#
# ### Instructie:
# Noem 4 methoden om cyberaanvallen te voorkomen.
#
# ### Antwoord:
#
# 1. Beveiligingsmaatregelen voor computers en netwerkapparatuur, zoals firewalls en antivirussoftware.
# 2. Implementeer een authenticatiebeleid dat gebruikersauthenticiteit vereist bij het verkrijgen van toegang tot de computer of netwerk.
# 3. Gebruik alleen vertrouwde applicaties die zijn getest op hun betrouwbaarheid en veiligheid.
# 4. Maak gebruik van beveiligingsstrategieën zoals encryptie en codering om gegevensbeveiliging te garanderen. Zorg ervoor dat alle werknemers zich bewust zijn van mogelijke risico's en hoe ze deze kunnen beheren wanneer zij betrokken zijn bij activiteiten met
#
#
# === Voorbeeld: 34 ======================================================================================
#
# ### Instructie:
# Reverse engineer de volgende algoritme en leg zijn functie uit in één zin.
#
# ### Invoer:
# def sorteer_getallen(arr):
#     for i in range(len(arr)):
#         for j in range(i):
#             if arr[i] < arr[j]:
#                 arr[i], arr[j] = arr[j], arr[i]
#     return arr
#
# ### Antwoord:
#
# Deze functie retourneert een lijst van getallen gesorteerd op basis van hun som. Het begint met het sorteren van alle elementen door ze af te wisselen, waarbij elk element wordt verplaatst naar de positie waarin hij voorkomt (dus datgene wat kleiner is dan hem). Vervolgens houdt deze functie zich bezig met het herhalen van dit proces totdat elke waarde is geplaatst volgens zijn juiste plek. De outputlijst zal vervolgens de nieuwe rangorde weerspiegeld hebben. Deze methode kan worden gebruikt om snel de grootste of kleinste elementen terug te vinden. Voorbeeldcode hierboven
#
#
# === Voorbeeld: 35 ======================================================================================
#
# ### Instructie:
# Bewerk deze code om de output "Hello, World!" te maken
#
# ### Invoer:
# console.log("Hi, World!");
#
# ### Antwoord:
#
# console.log(“Hallo Wereld!”); // Hallo Wereld! wordt weergegeven als resultaat
# // console.warn("Er is iets fout gegaan"); // Er is iets vreemds gebeurd (fout)
# // console.error("Een probleem met het systeem");// Een probleem met het systeem heeft zich voorgedaan (probleem).
#
# Deze code maakt gebruik van JavaScript's `console`-functie die elk teken dat in een string wordt geschreven, printt op de standaardoutput. De functie geeft ook feedback over hoelang het proces zal duren en wat er precies misging tijdens
#
#
# === Voorbeeld: 36 ======================================================================================
#
# ### Instructie:
# Maak een zin in de derde persoonsperspectief.
#
# ### Antwoord:
#
# Ik liep naar het park om te ontspannen en mijn gedachteën uit te drukken. Ik voelde me opgeladen totdat ik er was, maar al snel begon ik aan de schoonheid van de natuur te genieten terwijl ik door de bomen wandelde. Het was als een rustgevend moment voor mijzelf waarin ik kon reflecteren over wat belangrijk is in mijn leven. De zon kwam op en begroef zich onder de wolken met zijn helder licht. Zo'n uitzicht kan je niet missen! Tot slot keerde ik terug naar huis vol vreugde en dankbaarheid dat
#
#
# === Voorbeeld: 37 ======================================================================================
#
# ### Instructie:
# Doe een voorstel om de beschikbaarheid van wapens in de samenleving te verminderen.
#
# ### Antwoord:
#
# Eén manier waarop we kunnen helpen bij het verlagen van de hoeveelheid wapens die door mensen worden gebruikt, is door meer bewustzijn over hun risico's en potentieel gevaar voor anderen op te bouwen. We moeten ook meer aandacht besteden aan het bieden van training of cursussen met betrekking tot wapenbeheersing en -gebruik. Daarnaast moet er meer onderzoek gedaan worden naar hoe ongewenste effecten van geweld en misbruik van wapens voorkomen kan worden. Ten slotte zouden beleidsmakers zich richten op het creëren van veiligere omgevingen waarin minder gebruik gemaakt wordt
#
#
# === Voorbeeld: 38 ======================================================================================
#
# ### Instructie:
# Beoordeel de volgende producten op een schaal van 1-10 (1 = Niet goed, 10 = Zeer goed)
#
# ### Invoer:
# iPad Pro, Laptop, Desktop
#
# ### Antwoord:
#
# De iPad Pro is een zeer goede product met een score van 9.5/10 en het laptopmodel heeft een score van 8.7/10 terwijl het desktop model slechts 6.3/10 scoort. De iPad Pro biedt veel betere functies dan zijn tegenhangers; het beschikt over een groter scherm voor multitasking en multimediadoeleinden, meer krachtige processors om sneller te werken, verbeterde camera's die foto's kunnen maken in minder lichtomstandigheden, en meer geheugenruimte zodat je kunt blijven spelen totdat je klaar bent. Het laptopmodel biedt dezelfde capacit
#
#
# === Voorbeeld: 39 ======================================================================================
#
# ### Instructie:
# Noem een beroemde astronaut.
#
# ### Antwoord:
#
# Neil Armstrong is de eerste mens die op het maanland kwam en het ruimtevaartprogramma van de Verenigde Staten heeft gestart, waardoor hij wordt beschouwd als een beroemd geworden astronaut. Hij was ook de eerste persoon die voeten maakte op de Maan in 1969 tijdens zijn Apollo-missie. In totaal heeft Neil Armstrong vijf keer naar de Maan gevlogen voor wetenschappelijk onderzoek of om te studeren over hoe we kunnen leven daarin. Zijn missies hebben hem erkenning veroverd door landen wereldwijd.\n\nZijn Apollo-missie werd
#
#
# === Voorbeeld: 40 ======================================================================================
#
# ### Instructie:
# Schrijf een e-mail naar de manager waarin je vraagt om een wijziging in de vergadertijd.
#
# ### Invoer:
# Er staat een vergadering gepland op dinsdag om 11 uur 's ochtends en twee teamleden kunnen hier niet bij zijn vanwege een conflict in hun werkuren.
#
# ### Antwoord:
#
# Beste [manager],
# Ik ben het verbijsterd over uw plan voor ons projectteam's vergadering die morgen zal plaatsvinden tussen 9 uur - 10 uur 's avonds. We hebben echter geen andere mogelijkheid om te komen, omdat we beiden verplicht moeten werken totdat onze contracten aflopen eind deze maand. Ik zou graag meer informatie krijgen over hoe u denkt dat dit probleem kan worden opgelost of wanneer er alternatieven zouden kunnen bestaan? Met vriendelijke groet, [naam] <[emailadres].
#
# Bedankt alvast!
# Met vriendelijke groeten,
#
#
# === Voorbeeld: 41 ======================================================================================
#
# ### Instructie:
# Hoe voelt de protagonist zich tegen het einde van het boek?
#
# ### Invoer:
# Josh heeft moeite om betekenis te geven aan wat zijn leven is geworden. Hij heeft veel van zijn oude vrienden verloren en zijn toekomst is onzeker.
#
# ### Antwoord:
#
# De protagonist voelt zich wanhopig, eenzaam en verlaten toen hij erachter komt dat alles waarvoor hij zo hard werkt op niets uitdraait. Ze hebben allemaal hun eigen reden waarom ze verdwenen zijn - sommigen waren niet goed voor hem of hadden geen tijd meer voor elkaar - maar Josh was nog steeds gebroken na deze verliezen. Het gevoel van leegheid en afwezigheid die hij voelde tijdens dit proces werd alleen maar groter naarmate er minder mensen overbleven met wie hij kon praten en delen in zijn ervaringen konden bespreken. Toen hij uiteindelijk de conclusies
#
#
# === Voorbeeld: 42 ======================================================================================
#
# ### Instructie:
# Gebruik de tegenwoordige tijd om de volgende instructies uit te leggen
#
# ### Invoer:
# Bouw een huis
#
# ### Antwoord:
#
# Deze instructie moet worden uitgevoerd in één maand. Het huis zal moeten zijn ontworpen en voltooid binnen drie maanden, met de bouw van het huis beginnend op vijf mei en eindigend op tien augustus. De kosten voor het bouwen zullen ongeveer $250.000 bedragen, waarbij er rekening wordt gehouden met materialen die nodig zijn voor de constructie. De architectuur is vrijstaand en kan worden aangepast aan de behoeften van elke familie. Alle materialen moeten voldoen aan alle lokale codes en regelgevingen. Ten slotte moet het gebouw gerenoveerd worden gedurende
#
#
# === Voorbeeld: 43 ======================================================================================
#
# ### Instructie:
# Maak drie vragen die gerelateerd zijn aan de verspreiding van virussen.
#
# ### Antwoord:
#
# 1. Wat is het belangrijkste verschil tussen een bacterie en een virus?
# 2. Welke factoren kunnen leiden tot infecties door virussen?
# 3. Hoe beïnvloeden we onze natuurlijke vijandigheden tegen virale ziekten?
# 4. Welk type vaccinatie biedt de beste kans op succes bij het voorkomen of genezen van virale ziekten?
# 5. Welke strategieën kan ik gebruiken om mijn eigen veiligheid te vergroten tijdens COVID-19 pandemie?
# 6. Zijn er nog andere manieren waarop ik mezelf kan verdedigen tegen
#
#
# === Voorbeeld: 44 ======================================================================================
#
# ### Instructie:
# Genereer een social media bericht over een nieuwe functie van jouw product.
# Maximaal 140 tekens
#
# ### Invoer:
# SMS notificaties voor klanten
#
# ### Antwoord:
#
# Het is nu mogelijk om de nieuwste updates en aankondigingen direct op je telefoon te ontvangen! Met onze SMS-notificatieservice kun je elke belangrijke update, promo of nieuwigheid direct op je telefoon krijgen - zonder zorgen dat je het kunt missen. Je ontvangt ook gepersonaliseerde berichten die specifiek zijn afgestemd op jou. #BeterBlijfInContact met Jouw Klanten! #StayConnectedWithYourCustomers #NewFeatureOfOurProduct #SocialMediaPost #TweetableContent #TextMarketing #SMSNotificationsForCustomers #SMSNotifcationService #SMSNotificationService #
#
#
# === Voorbeeld: 45 ======================================================================================
#
# ### Instructie:
# Maak een lijst van 3 veelvoorkomende interviewvragen.
#
# ### Antwoord:
#
# 1. Wat is je motivatie voor deze functie?
# 2. Welke ervaring heb je met het vakgebied en hoe heeft dit bijgedragen aan jouw ontwikkeling als professional?
# 3. Hoe ga jij te werk om de doelen van ons bedrijf te bereiken?
# 4. Hebt u enige vragen over onze organisatie of projecten die we momenteel uitvoeren?
# 5. Hoe zou u uw huidige rol in vergelijking stellen met andere taken waaraan u hebt deelgenomen gedurende uw carrière?
# 6. Heeft u nog enkele vragen over ons team, product of dienstverleningsproces dat we aanbieden
#
#
# === Voorbeeld: 46 ======================================================================================
#
# ### Instructie:
# Genereer een voorbeeld van een bedrijfsplan voor een restaurant.
#
# ### Invoer:
# Restaurantnaam: Bella's Bistro
#
# ### Antwoord:
#
# Bella's Bistro is gestart met het creëren van een unieke en authentiek Italiaans-Amerikaanse keuken, die zich richt op de beste ingrediënten uit beide landen. Het menu zal worden samengesteld door chef-kok Andrea, die zijn eigen creatieve recepten combineert om heerlijke maaltijden te serveren. De bistro biedt ook een breed scala aan drankjes, waaronder craft bier en artisanale wijnen. Bovendien zullen ze regelmatig evenementen organiseren zoals live muziek, brunches en andere speciale gelegenheden. Met behulp van hun sterke lokale aanwezigheid in de nabijgelegen
#
#
# === Voorbeeld: 47 ======================================================================================
#
# ### Instructie:
# Construeer een bewijs van de volgende stelling:
#
# ### Invoer:
# Stelling: De som van twee oneven getallen is even.
#
# ### Antwoord:
#
# We hebben dat elk ongelijk deel van (x + y)/2 = x -y, dus we krijgen het resultaat terug als volgt: ((x+y)+(-y))=x-y. Door deze vergelijking te vereenvoudigen en uit te drukken op beide zijden, krijgen we hetzelfde resultaat in dezelfde vorm: (((x^2)+((-1)*x)))=(0). Dus, de som van twee oneven getallen is gelijk aan nul. Daarom is de som van twee oneven getallen ook ongelijk. We kunnen dit proces herhalen om alle ongelijke maten te
#
#
# === Voorbeeld: 48 ======================================================================================
#
# ### Instructie:
# Gebruik de gegeven feiten om een samenvatting van de Zon te genereren.
#
# ### Invoer:
# Het is een ster die zich bevindt in het centrum van ons zonnestelsel, hoofdzakelijk samengesteld uit waterstof en helium, heeft een diameter van 865.000 mijl en een oppervlaktetemperatuur van 10.000 graden Fahrenheit.
#
# ### Antwoord:
#
# De zon is een ster die bestaat uit waterstof en helium met een gemiddelde leeftijd van ongeveer 4 miljard jaar. Het is gelegen op aarde's hemellichamen, wat betekent dat we allemaal geïoniseerde gassen zijn geweest totdat onze planeet was geboren. De zon heeft een diameter van meer dan achthonderdvijfenzeventig miljoen kilometer en haar warmste punt bereikt een temperatuur van ruim tienduizend graden Celsius. We weten niet zeker hoe lang deze periode zal duren voordat de zon uiteindelijk vernietigbaar wordt door interne krachten of
#
#
# === Voorbeeld: 49 ======================================================================================
#
# ### Instructie:
# Maak een overzicht voor een presentatie over de rol van sociale media in de moderne samenleving.
#
# ### Antwoord:
#
# I. Inleiding en context
# A. De huidige tijdperken van het internet, technologieën en communicatie
# B. Het belang van social media als onderdeel van onze moderne samenleving
# II. Sociale media-inzichten
# 1. Definitie van sociaal netwerking
# 2. Gebruiksdoelstellingen van sociale media
# 3. Voordelen en nadelen van sociale media
# IV. Conclusie
# V. Bijsluiter
# Deze presentatie zal een diepgaande analyse geven van hoe we vandaag de dag worden geconfronteerd met de impact van sociale media op ons dagelijks leven. We
#
#
# === Voorbeeld: 50 ======================================================================================
#
# ### Instructie:
# Maak een haiku-gedicht met behulp van de gegeven woorden.
#
# ### Invoer:
# Wind, Wolken, Hemel
#
# ### Antwoord:
#
# De wind blaast door de wolken heen en weer,
# Eerst in het zand en dan overal waar hij kan gaan.
# Zijn vleugels zijn als dunne takken die zich uitstrekken naar boven,
# En weven hun vreugde omhoog totdat ze verdwijnen achter de horizon.
# Misschien is er geen plaats voor hem op aarde meer, maar toch blijft zijn vreugde altijd bestaan.
# Hij brengt ons elke dag opnieuw bij elkaar zoals hij dat doet -
# Het licht van de zon en de schaduw van de nacht.
